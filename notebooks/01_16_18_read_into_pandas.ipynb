# %%
import numpy as np
import pandas as pd

# %%
test = open('/home/ubuntu/test2.csv')

# %%
linetest = 'test'
counter = 0
while linetest != 'Data starts here.\n':
    linetest = test.readline()
    counter = counter + 1

# %%
data = pd.read_csv('/home/ubuntu/test2.csv', skiprows=counter)

# %%
data.sort_values(['Track_ID', 'Frame'], ascending=[1, 1])
# Out:
#     Track_ID  Spot_ID  Frame           X          Y    Quality  SN_Ratio  \
# 0          0        0    0.0   64.004101   3.957069  24.714836  0.794872
# 5          0        8    1.0   63.964040   6.043398  24.059998  0.758085
# 9          0       12    2.0   63.948480  10.058321  22.987091  0.823398
# 3          0        4    3.0   63.577542  12.507112  26.234367  0.960968
# 12         0       16    4.0   62.491559  16.482119  23.339684  1.088002
# 13         0       20    5.0   59.543395  19.490053  26.068222  0.975181
# 19         0       28    6.0   59.559181  19.488304  25.713448  0.940018
# 16         0       24    7.0   57.549366  21.525983  25.187050  0.969962
# 25         0       37    8.0   57.500666  22.518669  26.455109  0.967230
# 21         0       32    9.0   61.453791  25.436927  24.641197  0.942897
# 28         0       42   10.0   62.514693  29.504908  24.252396  0.963090
# 31         0       47   11.0   62.603432  33.511610  26.015182  1.011470
# ...
