# %% [markdown]
# ## Importing and prepping data

# %%
import pandas as pd
import numpy as np
import diff_classifier.aws as aws
import diff_classifier.pca as pca

# %%
features = []
featofvar = 'Type and Serum'

remote_folder = 'Tissue_Studies/10_23_18_corona_tissue' #Folder in AWS S3 containing files to be analyzed
bucket = 'ccurtis.data'
vids = 10
types = ['PEG_cor', 'PEG', 'PS_cor', 'PS']
pups = ['P1', 'P2']
slices = ['S1', 'S2']

counter = 0
for typ in types:
    for pup in pups:
        for slic in slices:
            for num in range(1, vids+1):
                try:
                    filename = 'features_{}_{}_{}_XY{}.csv'.format(typ, pup, slic, '%02d' % num)
                    print(filename)
                    aws.download_s3('{}/{}'.format(remote_folder, filename), filename, bucket_name=bucket)
                    fstats = pd.read_csv(filename, encoding = "ISO-8859-1", index_col='Unnamed: 0')
                    print('{} size: {}'.format(filename, fstats.shape))
                    fstats['Type and Serum'] = pd.Series(fstats.shape[0]*[typ], index=fstats.index)
                    if 'cor' in typ:
                        fstats['Serum'] = pd.Series(fstats.shape[0]*['serum'], index=fstats.index)
                    else:
                        fstats['Serum'] = pd.Series(fstats.shape[0]*['no serum'], index=fstats.index)
                    if 'PS' in typ:
                        fstats['Type'] = pd.Series(fstats.shape[0]*['COOH'], index=fstats.index)
                    else:
                        fstats['Type'] = pd.Series(fstats.shape[0]*['PEG'], index=fstats.index)
                    fstats['Video Number'] = pd.Series(fstats.shape[0]*[num], index=fstats.index)
                    fstats['Pup Number'] = pd.Series(fstats.shape[0]*[pup], index=fstats.index)
                    fstats['Slice Number'] = pd.Series(fstats.shape[0]*[slic], index=fstats.index)
                    counter = counter + 1
                    if counter == 1:
                        fstats_tot = fstats
                    else:
                        fstats_tot = fstats_tot.append(fstats, ignore_index=True)
                except:
                    print('Skipped!: {}'.format(filename))
# Out:
# features_PEG_cor_P1_S1_XY01.csv
# features_PEG_cor_P1_S1_XY01.csv size: (6550, 67)
# features_PEG_cor_P1_S1_XY02.csv
# features_PEG_cor_P1_S1_XY02.csv size: (5744, 67)
# features_PEG_cor_P1_S1_XY03.csv
# features_PEG_cor_P1_S1_XY03.csv size: (3721, 67)
# features_PEG_cor_P1_S1_XY04.csv
# features_PEG_cor_P1_S1_XY04.csv size: (5052, 67)
# features_PEG_cor_P1_S1_XY05.csv
# features_PEG_cor_P1_S1_XY05.csv size: (3002, 67)
# features_PEG_cor_P1_S1_XY06.csv
# features_PEG_cor_P1_S1_XY06.csv size: (2192, 67)
# features_PEG_cor_P1_S1_XY07.csv
# features_PEG_cor_P1_S1_XY07.csv size: (4272, 67)
# features_PEG_cor_P1_S1_XY08.csv
# features_PEG_cor_P1_S1_XY08.csv size: (4302, 67)
# features_PEG_cor_P1_S1_XY09.csv
# features_PEG_cor_P1_S1_XY09.csv size: (4488, 67)
# features_PEG_cor_P1_S1_XY10.csv
# features_PEG_cor_P1_S1_XY10.csv size: (3780, 67)
# features_PEG_cor_P1_S2_XY01.csv
# features_PEG_cor_P1_S2_XY01.csv size: (5288, 67)
# features_PEG_cor_P1_S2_XY02.csv
# features_PEG_cor_P1_S2_XY02.csv size: (11818, 67)
# features_PEG_cor_P1_S2_XY03.csv
# features_PEG_cor_P1_S2_XY03.csv size: (6936, 67)
# features_PEG_cor_P1_S2_XY04.csv
# features_PEG_cor_P1_S2_XY04.csv size: (3588, 67)
# features_PEG_cor_P1_S2_XY05.csv
# features_PEG_cor_P1_S2_XY05.csv size: (1252, 67)
# features_PEG_cor_P1_S2_XY06.csv
# features_PEG_cor_P1_S2_XY06.csv size: (2655, 67)
# features_PEG_cor_P1_S2_XY07.csv
# features_PEG_cor_P1_S2_XY07.csv size: (3255, 67)
# features_PEG_cor_P1_S2_XY08.csv
# features_PEG_cor_P1_S2_XY08.csv size: (2534, 67)
# features_PEG_cor_P1_S2_XY09.csv
# features_PEG_cor_P1_S2_XY09.csv size: (2040, 67)
# features_PEG_cor_P1_S2_XY10.csv
# features_PEG_cor_P1_S2_XY10.csv size: (906, 67)
# features_PEG_cor_P2_S1_XY01.csv
# features_PEG_cor_P2_S1_XY01.csv size: (9721, 67)
# features_PEG_cor_P2_S1_XY02.csv
# features_PEG_cor_P2_S1_XY02.csv size: (4092, 67)
# features_PEG_cor_P2_S1_XY03.csv
# features_PEG_cor_P2_S1_XY03.csv size: (938, 67)
# features_PEG_cor_P2_S1_XY04.csv
# features_PEG_cor_P2_S1_XY04.csv size: (2329, 67)
# features_PEG_cor_P2_S1_XY05.csv
# features_PEG_cor_P2_S1_XY05.csv size: (4603, 67)
# features_PEG_cor_P2_S1_XY06.csv
# features_PEG_cor_P2_S1_XY06.csv size: (14554, 67)
# features_PEG_cor_P2_S1_XY07.csv
# features_PEG_cor_P2_S1_XY07.csv size: (14344, 67)
# features_PEG_cor_P2_S1_XY08.csv
# features_PEG_cor_P2_S1_XY08.csv size: (11853, 67)
# features_PEG_cor_P2_S1_XY09.csv
# features_PEG_cor_P2_S1_XY09.csv size: (8842, 67)
# features_PEG_cor_P2_S1_XY10.csv
# features_PEG_cor_P2_S1_XY10.csv size: (7234, 67)
# features_PEG_cor_P2_S2_XY01.csv
# features_PEG_cor_P2_S2_XY01.csv size: (3108, 67)
# features_PEG_cor_P2_S2_XY02.csv
# features_PEG_cor_P2_S2_XY02.csv size: (1711, 67)
# features_PEG_cor_P2_S2_XY03.csv
# features_PEG_cor_P2_S2_XY03.csv size: (824, 67)
# features_PEG_cor_P2_S2_XY04.csv
# features_PEG_cor_P2_S2_XY04.csv size: (895, 67)
# features_PEG_cor_P2_S2_XY05.csv
# features_PEG_cor_P2_S2_XY05.csv size: (4054, 67)
# features_PEG_cor_P2_S2_XY06.csv
# features_PEG_cor_P2_S2_XY06.csv size: (3441, 67)
# features_PEG_cor_P2_S2_XY07.csv
# features_PEG_cor_P2_S2_XY07.csv size: (3875, 67)
# features_PEG_cor_P2_S2_XY08.csv
# features_PEG_cor_P2_S2_XY08.csv size: (4884, 67)
# features_PEG_cor_P2_S2_XY09.csv
# features_PEG_cor_P2_S2_XY09.csv size: (3246, 67)
# features_PEG_cor_P2_S2_XY10.csv
# features_PEG_cor_P2_S2_XY10.csv size: (1151, 67)
# features_PEG_P1_S1_XY01.csv
# features_PEG_P1_S1_XY01.csv size: (2129, 67)
# features_PEG_P1_S1_XY02.csv
# features_PEG_P1_S1_XY02.csv size: (5808, 67)
# features_PEG_P1_S1_XY03.csv
# features_PEG_P1_S1_XY03.csv size: (544, 67)
# features_PEG_P1_S1_XY04.csv
# features_PEG_P1_S1_XY04.csv size: (382, 67)
# features_PEG_P1_S1_XY05.csv
# features_PEG_P1_S1_XY05.csv size: (547, 67)
# features_PEG_P1_S1_XY06.csv
# features_PEG_P1_S1_XY06.csv size: (304, 67)
# features_PEG_P1_S1_XY07.csv
# features_PEG_P1_S1_XY07.csv size: (775, 67)
# features_PEG_P1_S1_XY08.csv
# features_PEG_P1_S1_XY08.csv size: (231, 67)
# features_PEG_P1_S1_XY09.csv
# features_PEG_P1_S1_XY09.csv size: (134, 67)
# features_PEG_P1_S1_XY10.csv
# features_PEG_P1_S1_XY10.csv size: (776, 67)
# features_PEG_P1_S2_XY01.csv
# features_PEG_P1_S2_XY01.csv size: (1912, 67)
# features_PEG_P1_S2_XY02.csv
# features_PEG_P1_S2_XY02.csv size: (2802, 67)
# features_PEG_P1_S2_XY03.csv
# features_PEG_P1_S2_XY03.csv size: (3655, 67)
# features_PEG_P1_S2_XY04.csv
# features_PEG_P1_S2_XY04.csv size: (3375, 67)
# features_PEG_P1_S2_XY05.csv
# features_PEG_P1_S2_XY05.csv size: (2043, 67)
# features_PEG_P1_S2_XY06.csv
# features_PEG_P1_S2_XY06.csv size: (3576, 67)
# features_PEG_P1_S2_XY07.csv
# features_PEG_P1_S2_XY07.csv size: (2253, 67)
# features_PEG_P1_S2_XY08.csv
# features_PEG_P1_S2_XY08.csv size: (5591, 67)
# features_PEG_P1_S2_XY09.csv
# features_PEG_P1_S2_XY09.csv size: (3782, 67)
# features_PEG_P1_S2_XY10.csv
# features_PEG_P1_S2_XY10.csv size: (1641, 67)
# features_PEG_P2_S1_XY01.csv
# features_PEG_P2_S1_XY01.csv size: (807, 67)
# features_PEG_P2_S1_XY02.csv
# features_PEG_P2_S1_XY02.csv size: (731, 67)
# features_PEG_P2_S1_XY03.csv
# features_PEG_P2_S1_XY03.csv size: (692, 67)
# features_PEG_P2_S1_XY04.csv
# features_PEG_P2_S1_XY04.csv size: (378, 67)
# features_PEG_P2_S1_XY05.csv
# features_PEG_P2_S1_XY05.csv size: (684, 67)
# features_PEG_P2_S1_XY06.csv
# features_PEG_P2_S1_XY06.csv size: (523, 67)
# features_PEG_P2_S1_XY07.csv
# features_PEG_P2_S1_XY07.csv size: (1468, 67)
# features_PEG_P2_S1_XY08.csv
# features_PEG_P2_S1_XY08.csv size: (1988, 67)
# features_PEG_P2_S1_XY09.csv
# features_PEG_P2_S1_XY09.csv size: (1199, 67)
# features_PEG_P2_S1_XY10.csv
# features_PEG_P2_S1_XY10.csv size: (656, 67)
# features_PEG_P2_S2_XY01.csv
# features_PEG_P2_S2_XY01.csv size: (262, 67)
# features_PEG_P2_S2_XY02.csv
# features_PEG_P2_S2_XY02.csv size: (659, 67)
# features_PEG_P2_S2_XY03.csv
# features_PEG_P2_S2_XY03.csv size: (795, 67)
# features_PEG_P2_S2_XY04.csv
# features_PEG_P2_S2_XY04.csv size: (965, 67)
# features_PEG_P2_S2_XY05.csv
# features_PEG_P2_S2_XY05.csv size: (835, 67)
# features_PEG_P2_S2_XY06.csv
# features_PEG_P2_S2_XY06.csv size: (1167, 67)
# features_PEG_P2_S2_XY07.csv
# features_PEG_P2_S2_XY07.csv size: (1866, 67)
# features_PEG_P2_S2_XY08.csv
# features_PEG_P2_S2_XY08.csv size: (1304, 67)
# features_PEG_P2_S2_XY09.csv
# features_PEG_P2_S2_XY09.csv size: (790, 67)
# features_PEG_P2_S2_XY10.csv
# features_PEG_P2_S2_XY10.csv size: (920, 67)
# features_PS_cor_P1_S1_XY01.csv
# features_PS_cor_P1_S1_XY01.csv size: (1004, 67)
# features_PS_cor_P1_S1_XY02.csv
# features_PS_cor_P1_S1_XY02.csv size: (702, 67)
# features_PS_cor_P1_S1_XY03.csv
# features_PS_cor_P1_S1_XY03.csv size: (1811, 67)
# features_PS_cor_P1_S1_XY04.csv
# features_PS_cor_P1_S1_XY04.csv size: (892, 67)
# features_PS_cor_P1_S1_XY05.csv
# features_PS_cor_P1_S1_XY05.csv size: (1039, 67)
# features_PS_cor_P1_S1_XY06.csv
# features_PS_cor_P1_S1_XY06.csv size: (1399, 67)
# features_PS_cor_P1_S1_XY07.csv
# features_PS_cor_P1_S1_XY07.csv size: (1300, 67)
# features_PS_cor_P1_S1_XY08.csv
# features_PS_cor_P1_S1_XY08.csv size: (1319, 67)
# features_PS_cor_P1_S1_XY09.csv
# features_PS_cor_P1_S1_XY09.csv size: (1732, 67)
# features_PS_cor_P1_S1_XY10.csv
# features_PS_cor_P1_S1_XY10.csv size: (1728, 67)
# features_PS_cor_P1_S2_XY01.csv
# features_PS_cor_P1_S2_XY01.csv size: (5127, 67)
# features_PS_cor_P1_S2_XY02.csv
# features_PS_cor_P1_S2_XY02.csv size: (2768, 67)
# features_PS_cor_P1_S2_XY03.csv
# features_PS_cor_P1_S2_XY03.csv size: (2060, 67)
# features_PS_cor_P1_S2_XY04.csv
# features_PS_cor_P1_S2_XY04.csv size: (1657, 67)
# features_PS_cor_P1_S2_XY05.csv
# features_PS_cor_P1_S2_XY05.csv size: (14050, 67)
# features_PS_cor_P1_S2_XY06.csv
# features_PS_cor_P1_S2_XY06.csv size: (11465, 67)
# features_PS_cor_P1_S2_XY07.csv
# features_PS_cor_P1_S2_XY07.csv size: (11019, 67)
# features_PS_cor_P1_S2_XY08.csv
# features_PS_cor_P1_S2_XY08.csv size: (12163, 67)
# features_PS_cor_P1_S2_XY09.csv
# features_PS_cor_P1_S2_XY09.csv size: (10690, 67)
# features_PS_cor_P1_S2_XY10.csv
# features_PS_cor_P1_S2_XY10.csv size: (9860, 67)
# features_PS_cor_P2_S1_XY01.csv
# features_PS_cor_P2_S1_XY01.csv size: (10370, 67)
# features_PS_cor_P2_S1_XY02.csv
# features_PS_cor_P2_S1_XY02.csv size: (9737, 67)
# features_PS_cor_P2_S1_XY03.csv
# features_PS_cor_P2_S1_XY03.csv size: (10174, 67)
# features_PS_cor_P2_S1_XY04.csv
# features_PS_cor_P2_S1_XY04.csv size: (11744, 67)
# features_PS_cor_P2_S1_XY05.csv
# features_PS_cor_P2_S1_XY05.csv size: (6804, 67)
# features_PS_cor_P2_S1_XY06.csv
# features_PS_cor_P2_S1_XY06.csv size: (12029, 67)
# features_PS_cor_P2_S1_XY07.csv
# features_PS_cor_P2_S1_XY07.csv size: (8299, 67)
# features_PS_cor_P2_S1_XY08.csv
# features_PS_cor_P2_S1_XY08.csv size: (10757, 67)
# features_PS_cor_P2_S1_XY09.csv
# features_PS_cor_P2_S1_XY09.csv size: (7796, 67)
# features_PS_cor_P2_S1_XY10.csv
# features_PS_cor_P2_S1_XY10.csv size: (12945, 67)
# features_PS_cor_P2_S2_XY01.csv
# features_PS_cor_P2_S2_XY01.csv size: (9603, 67)
# features_PS_cor_P2_S2_XY02.csv
# features_PS_cor_P2_S2_XY02.csv size: (9070, 67)
# features_PS_cor_P2_S2_XY03.csv
# features_PS_cor_P2_S2_XY03.csv size: (12207, 67)
# features_PS_cor_P2_S2_XY04.csv
# features_PS_cor_P2_S2_XY04.csv size: (3878, 67)
# features_PS_cor_P2_S2_XY05.csv
# features_PS_cor_P2_S2_XY05.csv size: (6658, 67)
# features_PS_cor_P2_S2_XY06.csv
# features_PS_cor_P2_S2_XY06.csv size: (18070, 67)
# features_PS_cor_P2_S2_XY07.csv
# features_PS_cor_P2_S2_XY07.csv size: (4277, 67)
# features_PS_cor_P2_S2_XY08.csv
# features_PS_cor_P2_S2_XY08.csv size: (6223, 67)
# features_PS_cor_P2_S2_XY09.csv
# features_PS_cor_P2_S2_XY09.csv size: (9849, 67)
# features_PS_cor_P2_S2_XY10.csv
# features_PS_cor_P2_S2_XY10.csv size: (7028, 67)
# features_PS_P1_S1_XY01.csv
# features_PS_P1_S1_XY01.csv size: (4712, 67)
# features_PS_P1_S1_XY02.csv
# features_PS_P1_S1_XY02.csv size: (5974, 67)
# features_PS_P1_S1_XY03.csv
# features_PS_P1_S1_XY03.csv size: (4730, 67)
# features_PS_P1_S1_XY04.csv
# features_PS_P1_S1_XY04.csv size: (2659, 67)
# features_PS_P1_S1_XY05.csv
# features_PS_P1_S1_XY05.csv size: (4792, 67)
# features_PS_P1_S1_XY06.csv
# features_PS_P1_S1_XY06.csv size: (7840, 67)
# features_PS_P1_S1_XY07.csv
# features_PS_P1_S1_XY07.csv size: (3760, 67)
# features_PS_P1_S1_XY08.csv
# features_PS_P1_S1_XY08.csv size: (6013, 67)
# features_PS_P1_S1_XY09.csv
# features_PS_P1_S1_XY09.csv size: (8353, 67)
# features_PS_P1_S1_XY10.csv
# features_PS_P1_S1_XY10.csv size: (2516, 67)
# features_PS_P1_S2_XY01.csv
# features_PS_P1_S2_XY01.csv size: (8074, 67)
# features_PS_P1_S2_XY02.csv
# features_PS_P1_S2_XY02.csv size: (6758, 67)
# features_PS_P1_S2_XY03.csv
# features_PS_P1_S2_XY03.csv size: (7135, 67)
# features_PS_P1_S2_XY04.csv
# features_PS_P1_S2_XY04.csv size: (3012, 67)
# features_PS_P1_S2_XY05.csv
# features_PS_P1_S2_XY05.csv size: (5291, 67)
# features_PS_P1_S2_XY06.csv
# features_PS_P1_S2_XY06.csv size: (3823, 67)
# features_PS_P1_S2_XY07.csv
# features_PS_P1_S2_XY07.csv size: (1217, 67)
# features_PS_P1_S2_XY08.csv
# features_PS_P1_S2_XY08.csv size: (2612, 67)
# features_PS_P1_S2_XY09.csv
# features_PS_P1_S2_XY09.csv size: (3100, 67)
# features_PS_P1_S2_XY10.csv
# features_PS_P1_S2_XY10.csv size: (5216, 67)
# features_PS_P2_S1_XY01.csv
# features_PS_P2_S1_XY01.csv size: (292, 67)
# features_PS_P2_S1_XY02.csv
# features_PS_P2_S1_XY02.csv size: (3977, 67)
# features_PS_P2_S1_XY03.csv
# features_PS_P2_S1_XY03.csv size: (11525, 67)
# features_PS_P2_S1_XY04.csv
# features_PS_P2_S1_XY04.csv size: (9646, 67)
# features_PS_P2_S1_XY05.csv
# features_PS_P2_S1_XY05.csv size: (10383, 67)
# features_PS_P2_S1_XY06.csv
# features_PS_P2_S1_XY06.csv size: (8894, 67)
# features_PS_P2_S1_XY07.csv
# features_PS_P2_S1_XY07.csv size: (757, 67)
# features_PS_P2_S1_XY08.csv
# features_PS_P2_S1_XY08.csv size: (10516, 67)
# features_PS_P2_S1_XY09.csv
# features_PS_P2_S1_XY09.csv size: (3799, 67)
# features_PS_P2_S1_XY10.csv
# features_PS_P2_S1_XY10.csv size: (6867, 67)
# features_PS_P2_S2_XY01.csv
# features_PS_P2_S2_XY01.csv size: (4567, 67)
# features_PS_P2_S2_XY02.csv
# features_PS_P2_S2_XY02.csv size: (2059, 67)
# features_PS_P2_S2_XY03.csv
# features_PS_P2_S2_XY03.csv size: (8208, 67)
# features_PS_P2_S2_XY04.csv
# features_PS_P2_S2_XY04.csv size: (13124, 67)
# features_PS_P2_S2_XY05.csv
# features_PS_P2_S2_XY05.csv size: (9016, 67)
# features_PS_P2_S2_XY06.csv
# features_PS_P2_S2_XY06.csv size: (5401, 67)
# features_PS_P2_S2_XY07.csv
# features_PS_P2_S2_XY07.csv size: (702, 67)
# features_PS_P2_S2_XY08.csv
# features_PS_P2_S2_XY08.csv size: (3487, 67)
# features_PS_P2_S2_XY09.csv
# features_PS_P2_S2_XY09.csv size: (2993, 67)
# features_PS_P2_S2_XY10.csv
# features_PS_P2_S2_XY10.csv size: (1546, 67)

# %%
fstats_tot['LogDeff2'] = np.log(fstats_tot['Deff2']).replace([np.inf, -np.inf], np.nan)
fstats_tot['LogMeanDeff2'] = np.log(fstats_tot['Mean Deff2']).replace([np.inf, -np.inf], np.nan)
pcadataset.final['LogDeff2'] = np.log(pcadataset.final['Deff2']).replace([np.inf, -np.inf], np.nan)
pcadataset.final['LogMeanDeff2'] = np.log(pcadataset.final['Mean Deff2']).replace([np.inf, -np.inf], np.nan)

fstats_tot['LogDeff1'] = np.log(fstats_tot['Deff1']).replace([np.inf, -np.inf], np.nan)
fstats_tot['LogMeanDeff1'] = np.log(fstats_tot['Mean Deff1']).replace([np.inf, -np.inf], np.nan)
pcadataset.final['LogDeff1'] = np.log(pcadataset.final['Deff1']).replace([np.inf, -np.inf], np.nan)
pcadataset.final['LogMeanDeff1'] = np.log(pcadataset.final['Mean Deff1']).replace([np.inf, -np.inf], np.nan)
# Out:
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log
#
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log
#   import sys
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in log
#
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':

# %%
bins = list(range(0, 2048+1, 256))
pcadataset.final['binx'] = pd.cut(pcadataset.final.X, bins, labels=[0, 1, 2, 3, 4, 5, 6, 7])
pcadataset.final['biny'] = pd.cut(pcadataset.final.Y, bins, labels=[0, 1, 2, 3, 4, 5, 6, 7])
pcadataset.final['bins'] = 8*pcadataset.final['binx'] + pcadataset.final['biny']
pcadataset.final = pcadataset.final[np.isfinite(pcadataset.final.bins)]
pcadataset.final.bins = pcadataset.final.bins.astype(int)

cols = pcadataset.final.columns.tolist()
cols = cols[-3:] + cols[:-3]
pcadataset.final = pcadataset.final[cols]

def checkerboard(size):
    rows = int(size/2)
    checks = list(range(0, size*size, size+1))
    
    for i in range(1, rows):
        ssize = size - 2*i
        for j in range(0, ssize):
            checks.append(2*i + (size+1)*j)

    for i in range(1, rows):
        ssize = size - 2*i
        for j in range(0, ssize):
            checks.append(size*size - 1 - (2*i + (size+1)*j))
    checks.sort()
    return checks

# %%
X_train = pcadataset.final[pcadataset.final.bins.isin(checkerboard(8))].reset_index()
X_test = pcadataset.final[~pcadataset.final.bins.isin(checkerboard(8))].reset_index()

# %%
meanD = np.array(means)
meanD.sort()
Dbins = meanD[0:-1] + np.diff(meanD)/2
print(Dbins)
# Out:
# [-1.42378795 -0.52010465  0.58696309]

# %%
import matplotlib.pyplot as plt
Dbins = [-10, -1.424, -0.520, 0.587, 10]
bins = np.linspace(-10, 10, 200)
fig, axes = plt.subplots(nrows=4, figsize=(12, 9))
counter = 0
means = []
for ax in axes:
    means.append(X_train[X_train['Type and Serum']==types[counter]]['LogMeanDeff2'].median())
    for i in range(4):
        X_train[(X_train['Type and Serum']==types[counter]) & (Dbins[i] < X_train['LogMeanDeff2']) & (X_train['LogMeanDeff2'] < Dbins[i+1])].hist(column='LogMeanDeff2', bins=bins, figsize=(12,3), edgecolor='k', ax=ax, )
        ax.set_xlim([-7.5, 3.5])
        ax.set_ylim([0, 15000])
    ax.axvline(X_train[X_train['Type and Serum']==types[counter]]['LogMeanDeff2'].median(), color='k', linestyle='dashed', linewidth=3)
    ax.set_title(types[counter])
    if counter == 3:
        ax.set_xlabel(r'$log(D_{eff})$')
    counter = counter + 1

# %%
Dbins = [-10, -1.424, -0.520, 0.587, 10]
bins = np.linspace(-10, 10, 200)
fig, axes = plt.subplots(nrows=4, figsize=(12, 9))
counter = 0
means = []
for ax in axes:
    means.append(X_test[X_test['Type and Serum']==types[counter]]['LogMeanDeff2'].median())
    for i in range(4):
        X_test[(X_test['Type and Serum']==types[counter]) & (Dbins[i] < X_test['LogMeanDeff2']) & (X_test['LogMeanDeff2'] < Dbins[i+1])].hist(column='LogMeanDeff2', bins=bins, figsize=(12,3), edgecolor='k', ax=ax, )
        ax.set_xlim([-7.5, 3.5])
        ax.set_ylim([0, 15000])
    ax.axvline(X_test[X_test['Type and Serum']==types[counter]]['LogMeanDeff2'].median(), color='k', linestyle='dashed', linewidth=3)
    ax.set_title(types[counter])
    if counter == 3:
        ax.set_xlabel(r'$log(D_{eff})$')
    counter = counter + 1

# %%
from matplotlib.pyplot import cm
import matplotlib.pyplot as plt
Dbins = [-10, -1.424, -0.520, 0.587, 10]
bins = np.linspace(-10, 10, 200)
fig, axes = plt.subplots(nrows=4, figsize=(12, 14))
counter = 0
means = []
labels3 = ['PS-PEG in serum', 'PS-PEG', 'PS-COOH in serum', 'PS-COOH']
for ax in axes:
    means.append(X_test[X_test['Type and Serum']==types[counter]]['LogMeanDeff2'].median())
    color = iter(newmap)
    for i in range(4):
        c = next(color)
        X_test[(X_test['Type and Serum']==types[counter]) & (Dbins[i] < X_test['LogMeanDeff2']) & (X_test['LogMeanDeff2'] < Dbins[i+1])].hist(column='LogMeanDeff2', bins=bins, figsize=(12,3), label = labels3[3-i], color=c, alpha=0.85, edgecolor='k', ax=ax, )
        ax.set_xlim([-7.5, 3.5])
        ax.set_ylim([0, 6000])
        ax.tick_params(labelsize=16)
    ax.axvline(X_test[X_test['Type and Serum']==types[counter]]['LogMeanDeff2'].median(), color='k', linestyle='dashed', linewidth=3)
    ax.set_title('')
    if counter == 0:
        ax.legend(fontsize=17)
    #if counter == 3:
        #ax.set_xlabel(r'$log(\bar{D}_{eff})$', fontsize=22)
    if counter != 3:
        ax.set_xticklabels([])
    counter = counter + 1
fig.savefig('./pics/coronatissue_hist.png', dpi=300, pad_inches=0.1)

# %%
newmap = np.zeros((4,4))

newmap[0, :] = cm.viridis(np.linspace(0.9, 0.0, 4))[1, :]
newmap[1, :] = cm.viridis(np.linspace(0.9, 0.0, 4))[2, :]
newmap[2, :] = cm.viridis(np.linspace(0.9, 0.0, 4))[3, :]
newmap[0, :] = cm.viridis(np.linspace(0.9, 0.0, 4))[1, :]
newmap
# Out:
# array([[ 0.134692,  0.658636,  0.517649,  1.      ],
#        [ 0.206756,  0.371758,  0.553117,  1.      ],
#        [ 0.267004,  0.004874,  0.329415,  1.      ],
#        [ 0.      ,  0.      ,  0.      ,  0.      ]])

# %%
newmap = cm.viridis(np.linspace(0.9, 0.0, 4))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import cm

def feature_violin(df, label='label', lvals=['yes', 'no'], labels=['yes', 'no'], fsubset=3, **kwargs):
    """Creates violinplot of input feature dataset

    Designed to plot PCA components from pca_analysis.

    Parameters
    ----------
    df : pandas.core.frames.DataFrame
        Must contain a group name column, and numerical feature columns.
    label : string or int
        Name of group column.
    lvals : list of string or int
        All values that group column can take
    fsubset : int or list of int
        Features to be plotted. If integer, will plot range(fsubset).
        If list, will only plot features contained in fsubset.
    **kwargs : variable
        figsize : tuple of int or float
            Dimensions of output figure
        yrange : list of int or float
            Range of y axis
        xlabel : string
            Label of x axis
        labelsize : int or float
            Font size of x label
        ticksize : int or float
            Font size of y tick labels
        fname : None or string
            Name of output file
        legendfontsize : int or float
            Font size of legend
        legendloc : int
            Location of legend in plot e.g. 1, 2, 3, 4

    """

    defaults = {'figsize': (12, 5), 'yrange': [-20, 20], 'xlabel': 'Feature',
                'labelsize': 20, 'ticksize': 16, 'fname': None,
                'legendfontsize': 12, 'legendloc': 1}

    for defkey in defaults.keys():
        if defkey not in kwargs.keys():
            kwargs[defkey] = defaults[defkey]

    # Restacking input data
    groupsize = []
    featcol = []
    valcol = []
    feattype = []

    if isinstance(fsubset, int):
        frange = range(fsubset)
    else:
        frange = fsubset

    for feat in frange:
        groupsize.extend(df[label].values)
        featcol.extend([feat]*df[label].values.shape[0])
        valcol.extend(df[feat].values)

    to_violind = {'label': groupsize, 'Feature': featcol,
                  'Feature Value': valcol}
    to_violin = pd.DataFrame(data=to_violind)

    # Plotting function
    fig, ax = plt.subplots(figsize=kwargs['figsize'])
    sns.violinplot(x="Feature", y="Feature Value", hue="label", data=to_violin,
                   palette=cm.viridis(np.linspace(0, 0.9, 4)), hue_order=lvals,
                   figsize=kwargs['figsize'], linewidth=0)

    # kwargs
    ax.tick_params(axis='both', which='major', labelsize=kwargs['ticksize'])
    plt.xlabel('Feature', fontsize=kwargs['labelsize'])
    plt.ylabel('Normalized\nFeature Space', fontsize=kwargs['labelsize'])
    plt.ylim(kwargs['yrange'])
    plt.setp(ax.collections, alpha=.75)
    L=ax.legend(prop={'size': 18})
    for item, label in zip(L.get_texts(), labels):
        item.set_text(label)
    #ax.legend(prop={'size': 18})
    
    if kwargs['fname'] is None:
        plt.show()
    else:
        plt.savefig(kwargs['fname'], dpi=300, pad_inches=0.22)

    return to_violin

# %%
labels2 = ['PS-COOH', 'PS-COOH in serum', 'PS-PEG', 'PS-PEG in serum']
labels = ['PS', 'PS_cor', 'PEG', 'PEG_cor']
feats = feature_violin(pcadataset.final, label='Type and Serum', lvals=labels, labels=labels2, fsubset=14, yrange=[-14, 14],
                       legendfontsize=21, labelsize=24, fname='./pics/coronatissue_pcadist.png')

# %%
['PEG_cor', 'PEG', 'PS_cor', 'PS']

# %%
y_pred2 = list(pd.cut(X_train.LogMeanDeff2.values, bins=[-10, -1.424, -0.520, 0.587, 10], labels=types).astype(str))
y_true2 = X_train['Type and Serum'].values

print(classification_report(y_true2, y_pred2, digits=4))
# Out:
#              precision    recall  f1-score   support
#
#         PEG     0.0910    0.1420    0.1110     35969
#     PEG_cor     0.0235    0.0286    0.0258     95111
#          PS     0.0700    0.0825    0.0758     88001
#      PS_cor     0.3273    0.1758    0.2287    138913
#         nan     0.0000    0.0000    0.0000         0
#
# avg / total     0.1596    0.1104    0.1254    357994
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
y_pred2 = list(pd.cut(X_test.LogMeanDeff2.values, bins=[-10, -1.424, -0.520, 0.587, 10], labels=types).astype(str))
y_true2 = X_test['Type and Serum'].values

print(classification_report(y_true2, y_pred2, digits=4))
# Out:
#              precision    recall  f1-score   support
#
#         PEG     0.1109    0.1709    0.1345     36864
#     PEG_cor     0.0179    0.0229    0.0201     93907
#          PS     0.0645    0.0749    0.0693     86429
#      PS_cor     0.3304    0.1720    0.2262    142066
#         nan     0.0000    0.0000    0.0000         0
#
# avg / total     0.1622    0.1096    0.1252    359266
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
axes =fstats_tot.hist(column='Deff1', by='Type and Serum', layout=(4, 1), bins=100, sharex=True, sharey=True, figsize=(10, 6))
for ax in axes:
    ax.set_ylim([0,25000])
    ax.set_xscale("log", nonposx='clip')

# %%
ax = fstats_tot1.hist(column='logDeff1', by='Type and Serum', layout=(4, 1), bins=100, sharex=True, sharey=True,
                        figsize=(10, 6), edgecolor='k')

means = []
types2 = ['PEG', 'PEG_cor', 'PS', 'PS_cor']
for ax, typ in zip(axes, types2):
    ax.set_ylim([0,15000])
    #ax.set_xscale("log", nonposx='clip')
    ax.set_xlim([-7.5,2.5])
    means.append(fstats_tot1[fstats_tot1['Type and Serum']==typ]['logDeff1'].mean())
    ax.axvline(fstats_tot1[fstats_tot1['Type and Serum']==typ]['logDeff1'].mean(), color='k', linestyle='dashed', linewidth=3)

# %%
ax = fstats_tot1[fstats_tot1['logDeff1'] < Dbins[1]].hist(column='logDeff1', bins=bins, figsize=(10, 2.5), edgecolor='k')
fstats_tot1[(Dbins[1] < fstats_tot1['logDeff1']) & (fstats_tot1['logDeff1'] < Dbins[2])].hist(column='logDeff1', bins=bins, figsize=(10, 6), edgecolor='k', ax=ax)
fstats_tot1[(Dbins[2] < fstats_tot1['logDeff1']) & (fstats_tot1['logDeff1'] < Dbins[3])].hist(column='logDeff1', bins=bins, figsize=(10, 6), edgecolor='k', ax=ax)
fstats_tot1[(Dbins[3] < fstats_tot1['logDeff1']) & (fstats_tot1['logDeff1'] < Dbins[4])].hist(column='logDeff1', bins=bins, figsize=(10, 6), edgecolor='k', ax=ax)
ax[0][0].set_xlim([-7.5, 2.5])
# Out:
# (-7.5, 2.5)

# %%
bins = np.linspace(-10, 10, 200)

# %%
print(meanD)
print(Dbins)
# Out:
# [-0.96150465 -0.73068234  0.08427661  1.16142619]
# [-0.84609349 -0.32320287  0.6228514 ]

# %%
meanD = np.array(means)
#Dbins = meanD[0:-1] + np.diff(meanD)/2

# %%
np.diff(meanD)/2
# Out:
# array([ 0.11541115,  0.40747947,  0.53857479])

# %%
meanD.sort()
Dbins = meanD[0:-1] + np.diff(meanD)/2

# %%
Dbins = np.array([-10, -0.846, 0.323, 0.623, 10])

# %%
from sklearn.metrics import classification_report
y_pred2 = list(pd.cut(fstats_tot1.logDeff1, bins=Dbins, labels=['PS_cor', 'PS', 'PEG', 'PEG_cor']).astype(str))
y_true = fstats_tot1['Type and Serum'].tolist()

# %%
print(classification_report(y_true, y_pred2, digits=4))
# Out:
#              precision    recall  f1-score   support
#
#         PEG     0.1026    0.0973    0.0999     60942
#     PEG_cor     0.4754    0.8191    0.6016    189073
#          PS     0.3954    0.2654    0.3177    215329
#      PS_cor     0.5451    0.4234    0.4766    281272
#
# avg / total     0.4481    0.4515    0.4317    746616

# %%
size3 = np.random.rand(fstats_tot1.shape[0])
y_pred3 = list(pd.cut(size3, bins=[0, 0.25, 0.5, 0.75, 10], labels=['PS_cor', 'PS', 'PEG', 'PEG_cor']).astype(str))
print(classification_report(y_true, y_pred3, digits=4))
# Out:
#              precision    recall  f1-score   support
#
#         PEG     0.0812    0.2497    0.1225     60942
#     PEG_cor     0.2543    0.2505    0.2524    189073
#          PS     0.2904    0.2523    0.2700    215329
#      PS_cor     0.3758    0.2482    0.2990    281272
#
# avg / total     0.2963    0.2501    0.2644    746616

# %%
#PCA analyses with too many datapoints fail. You get rows with lots of NAs. I'm going to try making a subset of the data first
#and then do a PCA analysis on that.

#include all in analysis
import random
subset = np.sort(np.array(random.sample(range(fstats_tot.shape[0]), 60000)))
fstats_sub = fstats_tot.loc[subset, :].reset_index(drop=True)

# %%
fstats_tot['Type and Serum'].unique()
# Out:
# array(['PEG_cor', 'PEG', 'PS_cor', 'PS'], dtype=object)

# %%
for typ in fstats_tot['Type and Serum'].unique():
    fstats_type = fstats_tot[fstats_tot['Type and Serum']==typ].reset_index(drop=True)
    print(fstats_type.shape)
# Out:
# (189074, 75)
# (60949, 75)
# (281303, 75)
# (215346, 75)

# %%
#with equal sample sizes for each particle type
import random
counter = 0
for typ in fstats_tot['Type and Serum'].unique():
    fstats_type = fstats_tot[fstats_tot['Type and Serum']==typ].reset_index(drop=True)
    print(fstats_type.shape)
    subset = np.sort(np.array(random.sample(range(fstats_type.shape[0]), 60000)))
    if counter == 0:
        fstats_sub = fstats_type.loc[subset, :].reset_index(drop=True)
    else:
        fstats_sub = fstats_sub.append(fstats_type.loc[subset, :].reset_index(drop=True), ignore_index=True)
    counter = counter + 1
# Out:
# (189074, 75)
# (60949, 75)
# (281303, 75)
# (215346, 75)

# %%
#fstats = pd.read_csv(filename, encoding = "ISO-8859-1", index_col='Unnamed: 0')
nonnum = ['Type and Serum', 'Type', 'Serum', 'Video Number', 'Track_ID', 'Mean Mean_Intensity', 'Std Mean_Intensity', 'X', 'Y',
          'Mean X', 'Mean Y', 'Std X', 'Std Y', 'Pup Number', 'Slice Number']
fstats_num = fstats_sub.drop(nonnum, axis=1)
fstats_raw = fstats_num.as_matrix()
#fstats

# %% [markdown]
# ## PCA analysis

# %% [markdown]
# The pca.pca_analysis function provides a completely contained PCA analysis of the input trajectory features dataset. It includes options to impute NaN values (fill in with average values or drop them), and to scale features. Read the docstring for more information.

# %%
ncomp = 15
pcadataset = pca.pca_analysis(fstats_tot, dropcols=nonnum, n_components=ncomp)
# Out:
# Cumulative explained variance:
# 0 component: 0.24717058247219736
# 1 component: 0.38415381321358977
# 2 component: 0.46013263593333925
# 3 component: 0.5332270841384928
# 4 component: 0.586723185260542
# 5 component: 0.6217794027250144
# 6 component: 0.651516402446259
# 7 component: 0.6788286582123865
# 8 component: 0.7040041517676219
# 9 component: 0.7278845859835007
# 10 component: 0.7494286109932703
# 11 component: 0.7679517608216405
# 12 component: 0.7851265144532058
# 13 component: 0.8014077082097971
# 14 component: 0.8164608975355492

# %%
pcadataset.components.to_csv('components.csv')
aws.upload_s3('components.csv', '{}/components.csv'.format(remote_folder, filename), bucket_name=bucket)

# %%
fstats_num.columns
# Out:
# Index(['alpha', 'D_fit', 'kurtosis', 'asymmetry1', 'asymmetry2', 'asymmetry3',
#        'AR', 'elongation', 'boundedness', 'fractal_dim', 'trappedness',
#        'efficiency', 'straightness', 'MSD_ratio', 'frames', 'Quality',
#        'Mean_Intensity', 'SN_Ratio', 'Deff1', 'Deff2', 'Mean alpha',
#        'Std alpha', 'Mean D_fit', 'Std D_fit', 'Mean kurtosis', 'Std kurtosis',
#        'Mean asymmetry1', 'Std asymmetry1', 'Mean asymmetry2',
#        'Std asymmetry2', 'Mean asymmetry3', 'Std asymmetry3', 'Mean AR',
#        'Std AR', 'Mean elongation', 'Std elongation', 'Mean boundedness',
#        'Std boundedness', 'Mean fractal_dim', 'Std fractal_dim',
#        'Mean trappedness', 'Std trappedness', 'Mean efficiency',
#        'Std efficiency', 'Mean straightness', 'Std straightness',
#        'Mean MSD_ratio', 'Std MSD_ratio', 'Mean frames', 'Std frames',
#        'Mean Quality', 'Std Quality', 'Mean SN_Ratio', 'Std SN_Ratio',
#        'Mean Deff1', 'Std Deff1', 'Mean Deff2', 'Std Deff2'],
#       dtype='object')

# %%
pcadataset.prcomps
# Out:
#                   0                1                 2               3   \
# 0         Mean Deff1  Mean asymmetry2    Std asymmetry2    Mean Quality
# 1    Mean efficiency  Mean asymmetry1    Std elongation     Std Quality
# 2  Mean straightness  Mean asymmetry3    Std asymmetry3         Quality
# 3         Mean D_fit  Mean elongation    Std asymmetry1  Mean_Intensity
# 4          Std Deff1       asymmetry3  Std straightness   Mean SN_Ratio
#
#              4            5             6               7              8   \
# 0    asymmetry1        alpha   boundedness   Std MSD_ratio   Std kurtosis
# 1    asymmetry2  boundedness   trappedness  Mean MSD_ratio  Mean kurtosis
# 2  straightness  trappedness  straightness    Std kurtosis      MSD_ratio
# 3    asymmetry3    MSD_ratio         D_fit   Mean kurtosis     efficiency
# 4    efficiency        D_fit    efficiency     trappedness      Std alpha
#
#                 9            10                11              12  \
# 0  Std boundedness       frames          kurtosis   Std MSD_ratio
# 1  Std trappedness  fractal_dim          SN_Ratio  Mean MSD_ratio
# 2    Std MSD_ratio        D_fit     Mean SN_Ratio    Std kurtosis
# 3   Mean MSD_ratio        Deff2             alpha   Mean kurtosis
# 4      boundedness     kurtosis  Std straightness        SN_Ratio
#
#             13            14
# 0     kurtosis         Deff2
# 1     SN_Ratio     Std alpha
# 2  Std Quality    Mean alpha
# 3       frames  straightness
# 4  fractal_dim     Std Deff2

# %% [markdown]
# The pca.kmo function calculates the Kaiser-Meyer-Olkin statistic, a measure of sampling adequacy. Check the docstring for more information.

# %%
kmostat = pca.kmo(pcadataset.scaled)
# Out:
# 0.896778715737

# %% [markdown]
# ## Visualization

# %% [markdown]
# Users can then compare average principle component values between subgroups of the data. In this case, all particles were taken from the same sample, so there are no experimental subgroups. I chose to compare short trajectories to long trajectories, as I would expect differences between the two groups.

# %%
import numpy as np
featofvar = 'Type and Serum'
#ncomp = 14
dicti = {}
#test = np.exp(np.nanmean(np.log(pcadataset.final[pcadataset.final['Particle Size']==200].as_matrix()), axis=0))[-6:]
#test1 = np.exp(np.nanmean(np.log(pcadataset.final[pcadataset.final['Particle Size']==500].as_matrix()), axis=0))[-6:]
dicti[0] = np.nanmean(pcadataset.final[pcadataset.final[featofvar]=='PS'].values[:, -ncomp:], axis=0)
dicti[1] = np.nanmean(pcadataset.final[pcadataset.final[featofvar]=='PS_cor'].values[:, -ncomp:], axis=0)
dicti[2] = np.nanmean(pcadataset.final[pcadataset.final[featofvar]=='PEG'].values[:, -ncomp:], axis=0)
dicti[3] = np.nanmean(pcadataset.final[pcadataset.final[featofvar]=='PEG_cor'].values[:, -ncomp:], axis=0)

# %%
labels = ['PS-COOH', 'PS-COOH with serum', 'PS-PEG', 'PS-PEG with serum']
pca.plot_pca(dicti, savefig=True, labels=labels, rticks=np.linspace(-4, 4, 9))

# %% [markdown]
# The variable pcadataset.prcomps shows the user the major contributions to each of the new principle components. When observing the graph above, users can see that there are some differences between short trajectories and long trajectories in component 0 (asymmetry1 being the major contributor) and component 1 (elongation being the major contributor).

# %%
#labels=['10K', '5K', '1K', 'COOH']
label1 = ['PS', 'PS_cor', 'PEG', 'PEG_cor']
feats = pca.feature_violin(pcadataset.final, label=featofvar, lvals=label1, fsubset=ncomp, yrange=[-12, 12])

# %%
fstats1 = pca.feature_plot_3D(pcadataset.final, label=featofvar, lvals=label1, randcount=400, ylim=[-12, 12],
                              xlim=[-12, 12], zlim=[-12, 12], features=[0, 1, 3])

# %%
fstats1 = pca.feature_plot_3D(pcadataset.final, label='Serum', lvals=['serum', 'no serum'], randcount=800, ylim=[-12, 12],
                              xlim=[-12, 12], zlim=[-12, 12], features=[0, 1, 3])

# %%
fstats1 = pca.feature_plot_3D(pcadataset.final, label='Type', lvals=['COOH', 'PEG'], randcount=800, ylim=[-12, 12],
                              xlim=[-12, 12], zlim=[-12, 12], features=[0, 1, 3])

# %%
#ncomp = 14
trainp = np.array([])
testp = np.array([])
labels3 = ['COOH', 'PEG']

for i in range(0, 10):
    KNNmod, X, y = pca.build_model(pcadataset.final, featofvar, label1, equal_sampling=True,
                                       tsize=2000, input_cols=ncomp, model='MLP', NNhidden_layer=(10, 5, 3))
    trainp = np.append(trainp, pca.predict_model(KNNmod, X, y))
    
    X2 = pcadataset.final.values[:, -ncomp:]
    y2 = pcadataset.final[featofvar].values
    testp = np.append(testp, pca.predict_model(KNNmod, X2, y2))
    print('Run {}: {}'.format(i, testp[i]))

# %%
from sklearn.model_selection import GridSearchCV, cross_val_score, KFold, train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report

# %%
test = pcadataset.final.values[:, -ncomp:]
y = pcadataset.final[featofvar].values
X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.95)

# %%
X_train.shape

# %%
test.shape

# %%
num_trials = 2
model = MLPClassifier(hidden_layer_sizes=(100, ), solver='sgd', verbose=True)
scores = np.zeros(num_trials)
gridps = {'alpha': [0.001, 0.01, 0.5], 'batch_size': [10, 50, 100, 200], 'learning_rate_init': [0.001, 0.005, 0.01]}

for i in range(num_trials):
    outer_cv = KFold(n_splits=4, shuffle=True, random_state=i)
    
    clf = GridSearchCV(estimator=model, param_grid=gridps, cv=outer_cv)
    clf.fit(X_train, y_train)
    score = cross_val_score(clf, X=X_train, y=y_train, cv=outer_cv)
    scores[i] = score.mean()
    print(scores[i])

# %%
test = pcadataset.final.values[:, -ncomp:]
y = pcadataset.final[featofvar].values
X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.9)

num_trials = 2
model = MLPClassifier(hidden_layer_sizes=(100, ), solver='sgd', verbose=True, max_iter=100, tol=0.001)
scores = np.zeros(num_trials)
gridps = [{'alpha': [0.001, 0.01, 0.5], 'batch_size': [10, 50, 100, 200], 'learning_rate_init': [0.001, 0.005, 0.01]}]

print('# Tuning hyper-parameters for precision')
clf = GridSearchCV(estimator=model, param_grid=gridps, cv=5, scoring='precision_macro')
clf.fit(X_train, y_train)

# %%
print('Best parameters set found in development set:')
print()
print(clf.best_params_)
print()
print("Grid scores on development set:")
print()
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std*2, params))
print()
# Out:
# Best parameters set found in development set:
#
# {'alpha': 0.001, 'batch_size': 100, 'learning_rate_init': 0.005}
#
# Grid scores on development set:
#
# 0.734 (+/-0.012) for {'alpha': 0.001, 'batch_size': 10, 'learning_rate_init': 0.001}
# 0.723 (+/-0.010) for {'alpha': 0.001, 'batch_size': 10, 'learning_rate_init': 0.005}
# 0.729 (+/-0.006) for {'alpha': 0.001, 'batch_size': 10, 'learning_rate_init': 0.01}
# 0.729 (+/-0.013) for {'alpha': 0.001, 'batch_size': 50, 'learning_rate_init': 0.001}
# 0.731 (+/-0.012) for {'alpha': 0.001, 'batch_size': 50, 'learning_rate_init': 0.005}
# 0.727 (+/-0.016) for {'alpha': 0.001, 'batch_size': 50, 'learning_rate_init': 0.01}
# 0.715 (+/-0.011) for {'alpha': 0.001, 'batch_size': 100, 'learning_rate_init': 0.001}
# 0.735 (+/-0.015) for {'alpha': 0.001, 'batch_size': 100, 'learning_rate_init': 0.005}
# 0.732 (+/-0.008) for {'alpha': 0.001, 'batch_size': 100, 'learning_rate_init': 0.01}
# 0.705 (+/-0.014) for {'alpha': 0.001, 'batch_size': 200, 'learning_rate_init': 0.001}
# 0.726 (+/-0.005) for {'alpha': 0.001, 'batch_size': 200, 'learning_rate_init': 0.005}
# 0.729 (+/-0.007) for {'alpha': 0.001, 'batch_size': 200, 'learning_rate_init': 0.01}
# 0.730 (+/-0.020) for {'alpha': 0.01, 'batch_size': 10, 'learning_rate_init': 0.001}
# 0.726 (+/-0.007) for {'alpha': 0.01, 'batch_size': 10, 'learning_rate_init': 0.005}
# 0.708 (+/-0.021) for {'alpha': 0.01, 'batch_size': 10, 'learning_rate_init': 0.01}
# 0.726 (+/-0.018) for {'alpha': 0.01, 'batch_size': 50, 'learning_rate_init': 0.001}
# 0.730 (+/-0.016) for {'alpha': 0.01, 'batch_size': 50, 'learning_rate_init': 0.005}
# 0.727 (+/-0.017) for {'alpha': 0.01, 'batch_size': 50, 'learning_rate_init': 0.01}
# 0.714 (+/-0.013) for {'alpha': 0.01, 'batch_size': 100, 'learning_rate_init': 0.001}
# 0.729 (+/-0.008) for {'alpha': 0.01, 'batch_size': 100, 'learning_rate_init': 0.005}
# 0.726 (+/-0.015) for {'alpha': 0.01, 'batch_size': 100, 'learning_rate_init': 0.01}
# 0.704 (+/-0.012) for {'alpha': 0.01, 'batch_size': 200, 'learning_rate_init': 0.001}
# 0.729 (+/-0.010) for {'alpha': 0.01, 'batch_size': 200, 'learning_rate_init': 0.005}
# 0.727 (+/-0.014) for {'alpha': 0.01, 'batch_size': 200, 'learning_rate_init': 0.01}
# 0.641 (+/-0.015) for {'alpha': 0.5, 'batch_size': 10, 'learning_rate_init': 0.001}
# 0.636 (+/-0.020) for {'alpha': 0.5, 'batch_size': 10, 'learning_rate_init': 0.005}
# 0.626 (+/-0.018) for {'alpha': 0.5, 'batch_size': 10, 'learning_rate_init': 0.01}
# 0.700 (+/-0.017) for {'alpha': 0.5, 'batch_size': 50, 'learning_rate_init': 0.001}
# 0.703 (+/-0.010) for {'alpha': 0.5, 'batch_size': 50, 'learning_rate_init': 0.005}
# 0.700 (+/-0.012) for {'alpha': 0.5, 'batch_size': 50, 'learning_rate_init': 0.01}
# 0.704 (+/-0.015) for {'alpha': 0.5, 'batch_size': 100, 'learning_rate_init': 0.001}
# 0.718 (+/-0.019) for {'alpha': 0.5, 'batch_size': 100, 'learning_rate_init': 0.005}
# 0.721 (+/-0.015) for {'alpha': 0.5, 'batch_size': 100, 'learning_rate_init': 0.01}
# 0.697 (+/-0.012) for {'alpha': 0.5, 'batch_size': 200, 'learning_rate_init': 0.001}
# 0.721 (+/-0.018) for {'alpha': 0.5, 'batch_size': 200, 'learning_rate_init': 0.005}
# 0.725 (+/-0.012) for {'alpha': 0.5, 'batch_size': 200, 'learning_rate_init': 0.01}

# %%
print("Detailed classification report")
print()
print("The model is trained on the full development set")
print("The scores are computed on the full evaluation set")
print()
y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))
print()
# Out:
# Detailed classification report
#
# The model is trained on the full development set
# The scores are computed on the full evaluation set
#
#              precision    recall  f1-score   support
#
#         PEG       0.76      0.64      0.70     53941
#     PEG_cor       0.71      0.84      0.77     54031
#          PS       0.75      0.73      0.74     54003
#      PS_cor       0.73      0.74      0.73     54025
#
# avg / total       0.74      0.74      0.74    216000

# %%
X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.4)

clf = MLPClassifier(hidden_layer_sizes=(600, ), solver='sgd', verbose=True, max_iter=300, tol=0.00001,
                    alpha=0.001, batch_size=100, learning_rate_init=0.005, learning_rate='adaptive',
                    early_stopping=True, validation_fraction=0.1)

clf.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 0.78562665
# Validation score: 0.698125
# Iteration 2, loss = 0.69835967
# Validation score: 0.716181
# Iteration 3, loss = 0.67365672
# Validation score: 0.723958
# Iteration 4, loss = 0.65640453
# Validation score: 0.728333
# Iteration 5, loss = 0.64385518
# Validation score: 0.735000
# Iteration 6, loss = 0.63485453
# Validation score: 0.740347
# Iteration 7, loss = 0.62852205
# Validation score: 0.740625
# Iteration 8, loss = 0.62349603
# Validation score: 0.743403
# Iteration 9, loss = 0.61888560
# Validation score: 0.742153
# Iteration 10, loss = 0.61547598
# Validation score: 0.743889
# Iteration 11, loss = 0.61286564
# Validation score: 0.745764
# Iteration 12, loss = 0.60948934
# Validation score: 0.750556
# Iteration 13, loss = 0.60698024
# Validation score: 0.745556
# Iteration 14, loss = 0.60479519
# Validation score: 0.747778
# Iteration 15, loss = 0.60291001
# Validation score: 0.753750
# Iteration 16, loss = 0.60115488
# Validation score: 0.752014
# Iteration 17, loss = 0.59939619
# Validation score: 0.753056
# Iteration 18, loss = 0.59756299
# Validation score: 0.752778
# Validation score did not improve more than tol=0.000050 for two consecutive epochs. Setting learning rate to 0.001000
# Iteration 19, loss = 0.58517424
# Validation score: 0.753958
# Iteration 20, loss = 0.58396714
# Validation score: 0.755000
# Iteration 21, loss = 0.58345531
# Validation score: 0.755278
# Iteration 22, loss = 0.58295320
# Validation score: 0.757083
# Iteration 23, loss = 0.58244842
# Validation score: 0.755417
# Iteration 24, loss = 0.58189545
# Validation score: 0.756250
# Iteration 25, loss = 0.58198356
# Validation score: 0.756042
# Validation score did not improve more than tol=0.000050 for two consecutive epochs. Setting learning rate to 0.000200
# Iteration 26, loss = 0.57901578
# Validation score: 0.755556
# Iteration 27, loss = 0.57863961
# Validation score: 0.757431
# Iteration 28, loss = 0.57848091
# Validation score: 0.756806
# Iteration 29, loss = 0.57847459
# Validation score: 0.756806
# Iteration 30, loss = 0.57832982
# Validation score: 0.757153
# Validation score did not improve more than tol=0.000050 for two consecutive epochs. Setting learning rate to 0.000040
# Iteration 31, loss = 0.57765544
# Validation score: 0.756944
# Iteration 32, loss = 0.57757496
# Validation score: 0.757222
# Iteration 33, loss = 0.57755390
# Validation score: 0.756875
# Validation score did not improve more than tol=0.000050 for two consecutive epochs. Setting learning rate to 0.000008
# Iteration 34, loss = 0.57737382
# Validation score: 0.756944
# Iteration 35, loss = 0.57736685
# Validation score: 0.756736
# Iteration 36, loss = 0.57735630
# Validation score: 0.756597
# Validation score did not improve more than tol=0.000050 for two consecutive epochs. Setting learning rate to 0.000002
# Iteration 37, loss = 0.57732063
# Validation score: 0.756597
# Iteration 38, loss = 0.57731933
# Validation score: 0.756667
# Iteration 39, loss = 0.57731809
# Validation score: 0.756667
# Validation score did not improve more than tol=0.000050 for two consecutive epochs. Setting learning rate to 0.000000
# Iteration 40, loss = 0.57730910
# Validation score: 0.756667
# Iteration 41, loss = 0.57730893
# Validation score: 0.756667
# Iteration 42, loss = 0.57730869
# Validation score: 0.756667
# Validation score did not improve more than tol=0.000050 for two consecutive epochs. Learning rate too small. Stopping.
# MLPClassifier(activation='relu', alpha=0.001, batch_size=100, beta_1=0.9,
#        beta_2=0.999, early_stopping=True, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='adaptive',
#        learning_rate_init=0.005, max_iter=300, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='sgd', tol=5e-05, validation_fraction=0.1,
#        verbose=True, warm_start=False)

# %%
test = pcadataset.final.values[:, -ncomp:]
y = pcadataset.final[featofvar].values
for run in range(2):
    X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.4)

    clf = MLPClassifier(hidden_layer_sizes=(600, ), solver='sgd', verbose=True, max_iter=300, tol=0.00001,
                        alpha=0.001, batch_size=100, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))
# Out:
# Iteration 1, loss = 0.65600532
# Validation score: 0.758979
# Iteration 2, loss = 0.59674123
# Validation score: 0.760117
# Iteration 3, loss = 0.57745080
# Validation score: 0.771077
# Iteration 4, loss = 0.56581481
# Validation score: 0.774313
# Iteration 5, loss = 0.55641844
# Validation score: 0.775318
# Iteration 6, loss = 0.54957633
# Validation score: 0.718734
# Iteration 7, loss = 0.54456216
# Validation score: 0.774849
# Iteration 8, loss = 0.53860149
# Validation score: 0.776724
# Iteration 9, loss = 0.53328541
# Validation score: 0.776501
# Iteration 10, loss = 0.52956876
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000040
# Iteration 39, loss = 0.46943033
# Validation score: 0.810540
# Iteration 40, loss = 0.46929377
# Validation score: 0.809781
# Iteration 41, loss = 0.46924066
# Validation score: 0.810384
# Iteration 42, loss = 0.46920696
# Validation score: 0.810272
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000008
# Iteration 43, loss = 0.46885444
# Validation score: 0.810250
# Iteration 44, loss = 0.46883087
# Validation score: 0.810160
# Iteration 45, loss = 0.46880701
# Validation score: 0.810094
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000002
# Iteration 46, loss = 0.46872778
# Validation score: 0.810272
# Iteration 47, loss = 0.46872058
# Validation score: 0.810205
# Iteration 48, loss = 0.46871818
# Validation score: 0.810227
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000000
# Iteration 49, loss = 0.46869842
# Validation score: 0.810183
# Iteration 50, loss = 0.46869770
# Validation score: 0.810138
# Iteration 51, loss = 0.46869727
# Validation score: 0.810138
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Learning rate too small. Stopping.
# Training Results
#              precision    recall  f1-score   support
#
#         PEG     0.7120    0.4947    0.5838     36608
#     PEG_cor     0.8292    0.8988    0.8626    113754
#          PS     0.8182    0.7745    0.7958    128952
#      PS_cor     0.8211    0.8625    0.8413    168689
#
# avg / total     0.8134    0.8163    0.8125    448003
#
# Test Results
#
#              precision    recall  f1-score   support
#
#         PEG     0.6977    0.4836    0.5713     24341
#     PEG_cor     0.8255    0.8952    0.8589     75320
#          PS     0.8107    0.7675    0.7885     86394
#      PS_cor     0.8145    0.8558    0.8347    112614
#
# avg / total     0.8067    0.8099    0.8060    298669

# %%
import matplotlib.pyplot as plt

# %%
fig, ax1 = plt.subplots()
ax1.plot(clf.loss_curve_, linewidth=4)
#ax1.set_xlim([0, 50])
#ax1.set_ylim([0.5, 0.8])
ax1.set_ylabel('Loss Curve')

ax2 = ax1.twinx()
ax2.plot(clf.validation_scores_, linewidth=4, c='g')
#ax2.set_ylim([0.7, 0.8])
ax2.set_ylabel('Validation Scores')
# Out:
# Text(0,0.5,'Validation Scores')

# %%
#test = pcadataset.final.values[:, -ncomp:]
#y = pcadataset.final[featofvar].values

X_train = pcadataset.final[pcadataset.final['Slice Number']=='S1'].values[:, -ncomp:] 
X_test = pcadataset.final[pcadataset.final['Slice Number']=='S2'].values[:, -ncomp:]
y_train = pcadataset.final[pcadataset.final['Slice Number']=='S1'][featofvar].values
y_test = pcadataset.final[pcadataset.final['Slice Number']=='S2'][featofvar].values

for run in range(1):
    #X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.4)

    clf = MLPClassifier(hidden_layer_sizes=(600, ), solver='sgd', verbose=True, max_iter=300, tol=0.00001,
                        alpha=0.001, batch_size=100, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))
# Out:
# Iteration 1, loss = 0.44149860
# Validation score: 0.846829
# Iteration 2, loss = 0.38493469
# Validation score: 0.854904
# Iteration 3, loss = 0.36730121
# Validation score: 0.859397
# Iteration 4, loss = 0.35512375
# Validation score: 0.863836
# Iteration 5, loss = 0.34581901
# Validation score: 0.869852
# Iteration 6, loss = 0.33751402
# Validation score: 0.872072
# Iteration 7, loss = 0.33071801
# Validation score: 0.873676
# Iteration 8, loss = 0.32408840
# Validation score: 0.879506
# Iteration 9, loss = 0.31840422
# Validation score: 0.876297
# Iteration 10, loss = 0.31297011
# Validation score: 0.883891
# Iteration 11, loss = 0.30801383
# Validation score: 0.885282
# Iteration 12, loss = 0.30314379
# Validation score: 0.885255
# Iteration 13, loss = 0.29856917
# Validation score: 0.890683
# Iteration 14, loss = 0.29417120
# Validation score: 0.890389
# Iteration 15, loss = 0.28967261
# Validation score: 0.893572
# Iteration 16, loss = 0.28534438
# Validation score: 0.890978
# Iteration 17, loss = 0.28205961
#          PS     0.4646    0.5984    0.5231     97341
#      PS_cor     0.6193    0.5459    0.5803    167722
#
# avg / total     0.5162    0.5278    0.5153    372717

# %%
fig, ax1 = plt.subplots()
ax1.plot(clf.loss_curve_, linewidth=4)
#ax1.set_xlim([0, 50])
#ax1.set_ylim([0.5, 0.8])
ax1.set_ylabel('Loss Curve')

ax2 = ax1.twinx()
ax2.plot(clf.validation_scores_, linewidth=4, c='g')
#ax2.set_ylim([0.7, 0.8])
ax2.set_ylabel('Validation Scores')
# Out:
# Text(0,0.5,'Validation Scores')

# %%
X_train = pcadataset.final[pcadataset.final['Pup Number']=='P1'].values[:, -ncomp:] 
X_test = pcadataset.final[pcadataset.final['Pup Number']=='P2'].values[:, -ncomp:]
y_train = pcadataset.final[pcadataset.final['Pup Number']=='P1'][featofvar].values
y_test = pcadataset.final[pcadataset.final['Pup Number']=='P2'][featofvar].values

for run in range(1):
    #X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.4)

    clf = MLPClassifier(hidden_layer_sizes=(600, ), solver='sgd', verbose=True, max_iter=300, tol=0.00001,
                        alpha=0.001, batch_size=100, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))
# Out:
# Iteration 1, loss = 0.57986556
# Validation score: 0.800164
# Iteration 2, loss = 0.50898815
# Validation score: 0.810132
# Iteration 3, loss = 0.48478379
# Validation score: 0.815558
# Iteration 4, loss = 0.46756560
# Validation score: 0.824453
# Iteration 5, loss = 0.45395128
# Validation score: 0.828870
# Iteration 6, loss = 0.44268684
# Validation score: 0.828649
# Iteration 7, loss = 0.43295115
# Validation score: 0.830983
# Iteration 8, loss = 0.42402849
# Validation score: 0.836661
# Iteration 9, loss = 0.41608738
# Validation score: 0.838933
# Iteration 10, loss = 0.40945506
# Validation score: 0.842150
# Iteration 11, loss = 0.40209598
# Validation score: 0.840131
# Iteration 12, loss = 0.39613837
# Validation score: 0.848995
# Iteration 13, loss = 0.39018413
# Validation score: 0.851550
# Iteration 14, loss = 0.38497403
# Validation score: 0.849342
# Iteration 15, loss = 0.37914596
# Validation score: 0.859027
# Iteration 16, loss = 0.37584208
# Validation score: 0.854610
# Iteration 17, loss = 0.37026673
# Validation score: 0.859279
# Iteration 18, loss = 0.36623605
# Validation score: 0.849153
# Iteration 19, loss = 0.36227820
# Validation score: 0.861802
# Iteration 20, loss = 0.35800982
# Validation score: 0.834485
# Iteration 21, loss = 0.35414782
# Validation score: 0.862780
# Iteration 22, loss = 0.35074613
# Validation score: 0.861834
# Iteration 23, loss = 0.34740030
# Validation score: 0.867386
# Iteration 24, loss = 0.34389134
# Validation score: 0.868932
# Iteration 25, loss = 0.34118856
# Validation score: 0.865399
# Iteration 26, loss = 0.33768855
# Validation score: 0.866660
# Iteration 27, loss = 0.33474871
# Validation score: 0.870856
# Iteration 28, loss = 0.33259842
# Validation score: 0.866660
# Iteration 29, loss = 0.32999301
# Validation score: 0.850888
# Iteration 30, loss = 0.32820601
# Validation score: 0.852781
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.001000
# Iteration 31, loss = 0.29632800
# Validation score: 0.880540
# Iteration 32, loss = 0.29186452
# Validation score: 0.887922
# Iteration 33, loss = 0.29043280
# Validation score: 0.888868
# Iteration 34, loss = 0.28934667
# Validation score: 0.885934
# Iteration 35, loss = 0.28858682
# Validation score: 0.887732
# Iteration 36, loss = 0.28765232
# Validation score: 0.890161
# Iteration 37, loss = 0.28683884
# Validation score: 0.889656
# Iteration 38, loss = 0.28583747
# Validation score: 0.888395
# Iteration 39, loss = 0.28511934
# Validation score: 0.887985
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000200
# Iteration 40, loss = 0.27787494
# Validation score: 0.891297
# Iteration 41, loss = 0.27716665
# Validation score: 0.892022
# Iteration 42, loss = 0.27688397
# Validation score: 0.890824
# Iteration 43, loss = 0.27667883
# Validation score: 0.891202
# Iteration 44, loss = 0.27654821
# Validation score: 0.892716
# Iteration 45, loss = 0.27638405
# Validation score: 0.891991
# Iteration 46, loss = 0.27615510
# Validation score: 0.891139
# Iteration 47, loss = 0.27596440
# Validation score: 0.891833
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000040
# Iteration 48, loss = 0.27444812
# Validation score: 0.892590
# Iteration 49, loss = 0.27422777
# Validation score: 0.892685
# Iteration 50, loss = 0.27419300
# Validation score: 0.892275
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000008
# Iteration 51, loss = 0.27385790
# Validation score: 0.892338
# Iteration 52, loss = 0.27379603
# Validation score: 0.892748
# Iteration 53, loss = 0.27378209
# Validation score: 0.892559
# Iteration 54, loss = 0.27376421
# Validation score: 0.892779
# Iteration 55, loss = 0.27376696
# Validation score: 0.892842
# Iteration 56, loss = 0.27375937
# Validation score: 0.892496
# Iteration 57, loss = 0.27375947
# Validation score: 0.892685
# Iteration 58, loss = 0.27374105
# Validation score: 0.892559
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000002
# Iteration 59, loss = 0.27365838
# Validation score: 0.892842
# Iteration 60, loss = 0.27364953
# Validation score: 0.892716
# Iteration 61, loss = 0.27364788
# Validation score: 0.892622
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000000
# Iteration 62, loss = 0.27362702
# Validation score: 0.892685
# Iteration 63, loss = 0.27362650
# Validation score: 0.892685
# Iteration 64, loss = 0.27362607
# Validation score: 0.892685
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Learning rate too small. Stopping.
# Training Results
#              precision    recall  f1-score   support
#
#         PEG     0.8371    0.7834    0.8094     42260
#     PEG_cor     0.8888    0.9177    0.9030     83375
#          PS     0.9168    0.9098    0.9133     97587
#      PS_cor     0.9281    0.9355    0.9318     93785
#
# avg / total     0.9022    0.9026    0.9022    317007
#
# Test Results
#
#              precision    recall  f1-score   support
#
#         PEG     0.0851    0.0846    0.0849     18689
#     PEG_cor     0.7585    0.8341    0.7945    105699
#          PS     0.4498    0.8077    0.5778    117759
#      PS_cor     0.7749    0.3447    0.4771    187518
#
# avg / total     0.6518    0.5807    0.5657    429665

# %%
pcadataset.final['Pup and Slice'] = pcadataset.final['Pup Number'].map(str) + pcadataset.final['Slice Number']
pcadataset.final = pcadataset.final[['Pup and Slice'] + list(pcadataset.final.columns[:-1])]

# %%
X_train = pcadataset.final[pcadataset.final['Pup and Slice'].isin(['P1S1', 'P1S2', 'P2S1'])].values[:, -ncomp:] 
X_test = pcadataset.final[pcadataset.final['Pup and Slice']=='P2S2'].values[:, -ncomp:]
y_train = pcadataset.final[pcadataset.final['Pup and Slice'].isin(['P1S1', 'P1S2', 'P2S1'])][featofvar].values
y_test = pcadataset.final[pcadataset.final['Pup and Slice']=='P2S2'][featofvar].values

for run in range(1):
    #X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.4)

    clf = MLPClassifier(hidden_layer_sizes=(600, ), solver='sgd', verbose=True, max_iter=300, tol=0.00001,
                        alpha=0.001, batch_size=100, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))
# Out:
# Iteration 1, loss = 0.51433668
# Validation score: 0.818152
# Iteration 2, loss = 0.46183297
# Validation score: 0.826299
# Iteration 3, loss = 0.44315788
# Validation score: 0.832838
# Iteration 4, loss = 0.43072930
# Validation score: 0.835653
# Iteration 5, loss = 0.42055685
# Validation score: 0.840146
# Iteration 6, loss = 0.41263245
# Validation score: 0.841964
# Iteration 7, loss = 0.40577594
# Validation score: 0.841737
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000040
# Iteration 46, loss = 0.46682394
# Validation score: 0.808920
# Iteration 47, loss = 0.46666748
# Validation score: 0.809489
# Iteration 48, loss = 0.46658803
# Validation score: 0.808370
# Iteration 49, loss = 0.46650321
# Validation score: 0.808330
# Iteration 50, loss = 0.46643008
# Validation score: 0.808737
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000008
# Iteration 51, loss = 0.46597015
# Validation score: 0.809042
# Iteration 52, loss = 0.46589751
# Validation score: 0.808920
# Iteration 53, loss = 0.46588761
# Validation score: 0.809225
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000002
# Iteration 54, loss = 0.46577424
# Validation score: 0.809042
# Iteration 55, loss = 0.46576038
# Validation score: 0.808960
# Iteration 56, loss = 0.46575510
# Validation score: 0.808920
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000000
# Iteration 57, loss = 0.46572582
# Validation score: 0.808920
# Iteration 58, loss = 0.46572460
# Validation score: 0.809001
# Iteration 59, loss = 0.46572404
# Validation score: 0.808940
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Learning rate too small. Stopping.
# Training Results
#              precision    recall  f1-score   support
#
#         PEG     0.7755    0.6435    0.7034     51823
#     PEG_cor     0.8080    0.8743    0.8398    110564
#          PS     0.8208    0.7987    0.8096    148690
#      PS_cor     0.8354    0.8528    0.8440    180648
#
# avg / total     0.8185    0.8192    0.8178    491725
#
# Test Results
#
#              precision    recall  f1-score   support
#
#         PEG     0.0772    0.1378    0.0990      9126
#     PEG_cor     0.8938    0.8204    0.8555     78510
#          PS     0.6450    0.7800    0.7061     66656
#      PS_cor     0.7901    0.6749    0.7280    100655
#
# avg / total     0.7586    0.7280    0.7390    254947

# %%
X_train = pcadataset.final[pcadataset.final['Pup and Slice'].isin(['P1S1', 'P1S2', 'P2S2'])].values[:, -ncomp:] 
X_test = pcadataset.final[pcadataset.final['Pup and Slice']=='P2S1'].values[:, -ncomp:]
y_train = pcadataset.final[pcadataset.final['Pup and Slice'].isin(['P1S1', 'P1S2', 'P2S2'])]['Type'].values
y_test = pcadataset.final[pcadataset.final['Pup and Slice']=='P2S1']['Type'].values

for run in range(1):
    #X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.4)

    clf = MLPClassifier(hidden_layer_sizes=(600, ), solver='sgd', verbose=True, max_iter=300, tol=0.00001,
                        alpha=0.001, batch_size=100, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))
# Out:
# Iteration 1, loss = 0.24099031
# Validation score: 0.920281
# Iteration 2, loss = 0.20193857
# Validation score: 0.925264
# Iteration 3, loss = 0.19354503
# Validation score: 0.927704
# Iteration 4, loss = 0.18814448
# Validation score: 0.930206
# Iteration 5, loss = 0.18394853
# Validation score: 0.930572
# Iteration 6, loss = 0.18045065
# Validation score: 0.932829
# Iteration 7, loss = 0.17727940
# Validation score: 0.933622
# Iteration 8, loss = 0.17428833
# Validation score: 0.931426
# Iteration 9, loss = 0.17168921
# Validation score: 0.935351
# Iteration 10, loss = 0.16909569
# Validation score: 0.936266
# Iteration 11, loss = 0.16690356
# Validation score: 0.936001
# Iteration 12, loss = 0.16466154
# Validation score: 0.937628
# Iteration 13, loss = 0.16275982
# Validation score: 0.938991
# Iteration 14, loss = 0.16087516
# Validation score: 0.938381
# Iteration 15, loss = 0.15908183
# Validation score: 0.937649
# Iteration 16, loss = 0.15726617
# Validation score: 0.939804
# Iteration 17, loss = 0.15565424
# Validation score: 0.936551
# Iteration 18, loss = 0.15422676
# Validation score: 0.939642
# Iteration 19, loss = 0.15257747
# Validation score: 0.941065
# Iteration 20, loss = 0.15117732
# Validation score: 0.940231
# Iteration 21, loss = 0.14988000
# Validation score: 0.941431
# Iteration 22, loss = 0.14850374
# Validation score: 0.940191
# Iteration 23, loss = 0.14722872
# Validation score: 0.943424
# Iteration 24, loss = 0.14615404
# Validation score: 0.942123
# Iteration 25, loss = 0.14506648
# Validation score: 0.942590
# Iteration 26, loss = 0.14387049
# Validation score: 0.936652
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.001000
# Iteration 27, loss = 0.13414563
# Validation score: 0.946149
# Iteration 28, loss = 0.13325818
# Validation score: 0.947431
# Iteration 29, loss = 0.13282921
# Validation score: 0.947593
# Iteration 30, loss = 0.13238996
# Validation score: 0.948122
# Iteration 31, loss = 0.13217046
# Validation score: 0.947898
# Iteration 32, loss = 0.13172971
# Validation score: 0.947756
# Iteration 33, loss = 0.13135114
# Validation score: 0.947573
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000200
# Iteration 34, loss = 0.12913762
# Validation score: 0.948041
# Iteration 35, loss = 0.12905175
# Validation score: 0.948407
# Iteration 36, loss = 0.12892154
# Validation score: 0.948366
# Iteration 37, loss = 0.12881798
# Validation score: 0.948671
# Iteration 38, loss = 0.12879378
# Validation score: 0.948712
# Iteration 39, loss = 0.12869602
# Validation score: 0.948630
# Iteration 40, loss = 0.12863784
# Validation score: 0.948752
# Iteration 41, loss = 0.12856272
# Validation score: 0.948549
# Iteration 42, loss = 0.12851790
# Validation score: 0.948529
# Iteration 43, loss = 0.12839597
# Validation score: 0.948651
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000040
# Iteration 44, loss = 0.12792286
# Validation score: 0.948691
# Iteration 45, loss = 0.12788796
# Validation score: 0.948508
# Iteration 46, loss = 0.12786237
# Validation score: 0.948671
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000008
# Iteration 47, loss = 0.12776931
# Validation score: 0.948895
# Iteration 48, loss = 0.12774837
# Validation score: 0.948752
# Iteration 49, loss = 0.12774691
# Validation score: 0.948732
# Iteration 50, loss = 0.12773930
# Validation score: 0.948874
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000002
# Iteration 51, loss = 0.12772020
# Validation score: 0.948854
# Iteration 52, loss = 0.12771501
# Validation score: 0.948813
# Iteration 53, loss = 0.12771353
# Validation score: 0.948773
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000000
# Iteration 54, loss = 0.12770715
# Validation score: 0.948793
# Iteration 55, loss = 0.12770695
# Validation score: 0.948793
# Iteration 56, loss = 0.12770670
# Validation score: 0.948752
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Learning rate too small. Stopping.
# Training Results
#              precision    recall  f1-score   support
#
#        COOH     0.9627    0.9676    0.9651    329338
#         PEG     0.9335    0.9239    0.9287    162387
#
# avg / total     0.9531    0.9532    0.9531    491725
#
# Test Results
#
#              precision    recall  f1-score   support
#
#        COOH     0.9166    0.9167    0.9167    167311
#         PEG     0.8409    0.8408    0.8409     87636
#
# avg / total     0.8906    0.8906    0.8906    254947

# %%
fig, ax1 = plt.subplots()
ax1.plot(clf.loss_curve_, linewidth=4)
#ax1.set_xlim([0, 50])
#ax1.set_ylim([0.5, 0.8])
ax1.set_ylabel('Loss Curve')

ax2 = ax1.twinx()
ax2.plot(clf.validation_scores_, linewidth=4, c='g')
#ax2.set_ylim([0.7, 0.8])
ax2.set_ylabel('Validation Scores')

# %%
X_train = pcadataset.final[pcadataset.final['Pup and Slice'].isin(['P2S1', 'P1S2', 'P2S2'])].values[:, -ncomp:] 
X_test = pcadataset.final[pcadataset.final['Pup and Slice']=='P1S1'].values[:, -ncomp:]
y_train = pcadataset.final[pcadataset.final['Pup and Slice'].isin(['P2S1', 'P1S2', 'P2S2'])][featofvar].values
y_test = pcadataset.final[pcadataset.final['Pup and Slice']=='P1S1'][featofvar].values

for run in range(1):
    #X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.4)

    clf = MLPClassifier(hidden_layer_sizes=(600, ), solver='sgd', verbose=True, max_iter=300, tol=0.00001,
                        alpha=0.001, batch_size=100, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))
# Out:
# Iteration 1, loss = 0
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000000
# Iteration 48, loss = 0.34167963
# Validation score: 0.866538
# Iteration 49, loss = 0.34167879
# Validation score: 0.866522
# Iteration 50, loss = 0.34167807
# Validation score: 0.866506
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Learning rate too small. Stopping.
# Training Results
#              precision    recall  f1-score   support
#
#         PEG     0.7762    0.6104    0.6834     49319
#     PEG_cor     0.8755    0.9145    0.8946    145971
#          PS     0.8737    0.8406    0.8569    163997
#      PS_cor     0.8854    0.9192    0.9020    268377
#
# avg / total     0.8715    0.8733    0.8713    627664
#
# Test Results
#
#              precision    recall  f1-score   support
#
#         PEG     0.1772    0.0887    0.1182     11630
#     PEG_cor     0.7283    0.8097    0.7669     43103
#          PS     0.8057    0.2920    0.4287     51349
#      PS_cor     0.1894    0.6837    0.2966     12926
#
# avg / total     0.6493    0.5022    0.5065    119008

# %%
fig, ax1 = plt.subplots()
ax1.plot(clf.loss_curve_, linewidth=4)
#ax1.set_xlim([0, 50])
#ax1.set_ylim([0.5, 0.8])
ax1.set_ylabel('Loss Curve')

ax2 = ax1.twinx()
ax2.plot(clf.validation_scores_, linewidth=4, c='g')
#ax2.set_ylim([0.7, 0.8])
ax2.set_ylabel('Validation Scores')
# Out:
# Text(0,0.5,'Validation Scores')

# %%
X_train = pcadataset.final[pcadataset.final['Pup and Slice'].isin(['P2S1', 'P1S1', 'P2S2'])].values[:, -ncomp:] 
X_test = pcadataset.final[pcadataset.final['Pup and Slice']=='P1S2'].values[:, -ncomp:]
y_train = pcadataset.final[pcadataset.final['Pup and Slice'].isin(['P2S1', 'P1S1', 'P2S2'])][featofvar].values
y_test = pcadataset.final[pcadataset.final['Pup and Slice']=='P1S2'][featofvar].values

for run in range(1):
    #X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.4)

    clf = MLPClassifier(hidden_layer_sizes=(600, ), solver='sgd', verbose=True, max_iter=300, tol=0.00001,
                        alpha=0.001, batch_size=100, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))
# Out:
# Iteration 1, loss = 0.60092491
# Validation score: 0.779744
# Iteration 2, loss = 0.54311390
# Validation score: 0.789258
# Iteration 3, loss = 0.52491169
# Validation score: 0.790661
# Iteration 4, loss = 0.51340327
# Validation score: 0.799683
# Iteration 5, loss = 0.50383130
# Validation score: 0.797514
# Iteration 6, loss = 0.49582724
# Validation score: 0.803164
# Iteration 7, loss = 0.48802526
# Validation score: 0.801177
# Iteration 8, loss = 0.48198986
# Validation score: 0.799847
# Iteration 9, loss = 0.47591064
# Validation score: 0.809634
# Iteration 10, loss = 0.47016891
# Validation score: 0.799282
# Iteration 11, loss = 0.46518849
# Validation score: 0.796894
# Iteration 12, loss = 0.45937814
# Validation score: 0.811074
# Iteration 13, loss = 0.45545757
# Validation score: 0.819385
# Iteration 14, loss = 0.45071053
# Validation score: 0.796311
# Iteration 15, loss = 0.44602521
# Validation score: 0.798024
# Iteration 16, loss = 0.44234085
# Validation score: 0.822027
# Iteration 17, loss = 0.43806778
# Validation score: 0.816542
# Iteration 18, loss = 0.43390766
# Validation score: 0.832288
# Iteration 19, loss = 0.43034974
# Validation score: 0.754976
# Iteration 20, loss = 0.42777817
# Validation score: 0.827404
# Iteration 21, loss = 0.42437275
# Validation score: 0.810983
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.001000
# Iteration 22, loss = 0.39141522
# Validation score: 0.848290
# Iteration 23, loss = 0.38790676
# Validation score: 0.846741
# Iteration 24, loss = 0.38642089
# Validation score: 0.842094
# Iteration 25, loss = 0.38512779
# Validation score: 0.850295
# Iteration 26, loss = 0.38354344
# Validation score: 0.851589
# Iteration 27, loss = 0.38262542
# Validation score: 0.853138
# Iteration 28, loss = 0.38116524
# Validation score: 0.852737
# Iteration 29, loss = 0.38018493
# Validation score: 0.854196
# Iteration 30, loss = 0.37884151
# Validation score: 0.852829
# Iteration 31, loss = 0.37770403
# Validation score: 0.853849
# Iteration 32, loss = 0.37671394
# Validation score: 0.855216
# Iteration 33, loss = 0.37572188
# Validation score: 0.853029
# Iteration 34, loss = 0.37454394
# Validation score: 0.852446
# Iteration 35, loss = 0.37358392
# Validation score: 0.852683
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000200
# Iteration 36, loss = 0.36494254
# Validation score: 0.860338
# Iteration 37, loss = 0.36423479
# Validation score: 0.859681
# Iteration 38, loss = 0.36384025
# Validation score: 0.860009
# Iteration 39, loss = 0.36361859
# Validation score: 0.860483
# Iteration 40, loss = 0.36338543
# Validation score: 0.861158
# Iteration 41, loss = 0.36306375
# Validation score: 0.860429
# Iteration 42, loss = 0.36286864
# Validation score: 0.860866
# Iteration 43, loss = 0.36267071
# Validation score: 0.860374
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000040
# Iteration 44, loss = 0.36075805
# Validation score: 0.860811
# Iteration 45, loss = 0.36054462
# Validation score: 0.860502
# Iteration 46, loss = 0.36044421
# Validation score: 0.861832
# Iteration 47, loss = 0.36041234
# Validation score: 0.860702
# Iteration 48, loss = 0.36042094
# Validation score: 0.861158
# Iteration 49, loss = 0.36034806
# Validation score: 0.861613
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000008
# Iteration 50, loss = 0.35991722
# Validation score: 0.861595
# Iteration 51, loss = 0.35986897
# Validation score: 0.861413
# Iteration 52, loss = 0.35986045
# Validation score: 0.861486
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000002
# Iteration 53, loss = 0.35975875
# Validation score: 0.861413
# Iteration 54, loss = 0.35974888
# Validation score: 0.861340
# Iteration 55, loss = 0.35974505
# Validation score: 0.861486
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000000
# Iteration 56, loss = 0.35972330
# Validation score: 0.861358
# Iteration 57, loss = 0.35972089
# Validation score: 0.861285
# Iteration 58, loss = 0.35972031
# Validation score: 0.861303
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Learning rate too small. Stopping.
# Training Results
#              precision    recall  f1-score   support
#
#         PEG     0.7439    0.4838    0.5863     30319
#     PEG_cor     0.8669    0.9137    0.8897    148802
#          PS     0.8759    0.8574    0.8665    169108
#      PS_cor     0.8714    0.8981    0.8845    200444
#
# avg / total     0.8645    0.8669    0.8639    548673
#
# Test Results
#
#              precision    recall  f1-score   support
#
#         PEG     0.1870    0.0656    0.0971     30630
#     PEG_cor     0.6415    0.4765    0.5468     40272
#          PS     0.5518    0.5298    0.5406     46238
#      PS_cor     0.5744    0.8024    0.6695     80859
#
# avg / total     0.5228    0.5585    0.5259    197999

# %%
fig, ax1 = plt.subplots()
ax1.plot(clf.loss_curve_, linewidth=4)
#ax1.set_xlim([0, 50])
#ax1.set_ylim([0.5, 0.8])
ax1.set_ylabel('Loss Curve')

ax2 = ax1.twinx()
ax2.plot(clf.validation_scores_, linewidth=4, c='g')
#ax2.set_ylim([0.7, 0.8])
ax2.set_ylabel('Validation Scores')
# Out:
# Text(0,0.5,'Validation Scores')

# %%
X_train = pcadataset.final[(pcadataset.final['Type'] == 'COOH') & (pcadataset.final['Pup and Slice'].isin(['P1S1', 'P1S2', 'P2S2']))].values[:, -ncomp:] 
X_test = pcadataset.final[(pcadataset.final['Type'] == 'COOH') & (pcadataset.final['Pup and Slice']=='P2S1')].values[:, -ncomp:]
y_train = pcadataset.final[(pcadataset.final['Type'] == 'COOH') & (pcadataset.final['Pup and Slice'].isin(['P1S1', 'P1S2', 'P2S2']))]['Serum'].values
y_test = pcadataset.final[(pcadataset.final['Type'] == 'COOH') & (pcadataset.final['Pup and Slice']=='P2S1')]['Serum'].values

for run in range(1):
    #X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.4)

    clf = MLPClassifier(hidden_layer_sizes=(600, ), solver='sgd', verbose=True, max_iter=300, tol=0.00001,
                        alpha=0.001, batch_size=100, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))
# Out:
# Iteration 1, loss = 0
# Validation score: 0.915514
# Iteration 38, loss = 0.20623498
# Validation score: 0.918960
# Iteration 39, loss = 0.20430474
# Validation score: 0.913548
# Iteration 40, loss = 0.20221769
# Validation score: 0.919654
# Iteration 41, loss = 0.20094378
# Validation score: 0.918729
# Iteration 42, loss = 0.19973667
# Validation score: 0.915815
# Iteration 43, loss = 0.19843824
# Validation score: 0.925598
# Iteration 44, loss = 0.19643258
# Validation score: 0.917850
# Iteration 45, loss = 0.19499360
# Validation score: 0.923054
# Iteration 46, loss = 0.19426210
# Validation score: 0.924973
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.001000
# Iteration 47, loss = 0.16782384
# Validation score: 0.936237
# Iteration 48, loss = 0.16577453
# Validation score: 0.935520
# Iteration 49, loss = 0.16493488
# Validation score: 0.936630
# Iteration 50, loss = 0.16422440
# Validation score: 0.935612
# Iteration 51, loss = 0.16376365
# Validation score: 0.938434
# Iteration 52, loss = 0.16304753
# Validation score: 0.936630
# Iteration 53, loss = 0.16267675
# Validation score: 0.935959
# Iteration 54, loss = 0.16216999
# Validation score: 0.936445
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000200
# Iteration 55, loss = 0.15664684
# Validation score: 0.939567
# Iteration 56, loss = 0.15634242
# Validation score: 0.939798
# Iteration 57, loss = 0.15623807
# Validation score: 0.940307
# Iteration 58, loss = 0.15598539
# Validation score: 0.940053
# Iteration 59, loss = 0.15596798
# Validation score: 0.941024
# Iteration 60, loss = 0.15586611
# Validation score: 0.940700
# Iteration 61, loss = 0.15567961
# Validation score: 0.939868
# Iteration 62, loss = 0.15556325
# Validation score: 0.940400
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000040
# Iteration 63, loss = 0.15439333
# Validation score: 0.940932
# Iteration 64, loss = 0.15432316
# Validation score: 0.940885
# Iteration 65, loss = 0.15429029
# Validation score: 0.940932
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000008
# Iteration 66, loss = 0.15403430
# Validation score: 0.940908
# Iteration 67, loss = 0.15401008
# Validation score: 0.941024
# Iteration 68, loss = 0.15399710
# Validation score: 0.941024
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000002
# Iteration 69, loss = 0.15393827
# Validation score: 0.941047
# Iteration 70, loss = 0.15393453
# Validation score: 0.941117
# Iteration 71, loss = 0.15393258
# Validation score: 0.941001
# Iteration 72, loss = 0.15393274
# Validation score: 0.941140
# Iteration 73, loss = 0.15393146
# Validation score: 0.941070
# Iteration 74, loss = 0.15393115
# Validation score: 0.941047
# Iteration 75, loss = 0.15393003
# Validation score: 0.941024
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000000
# Iteration 76, loss = 0.15391375
# Validation score: 0.940978
# Iteration 77, loss = 0.15391338
# Validation score: 0.941047
# Iteration 78, loss = 0.15391334
# Validation score: 0.941001
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Learning rate too small. Stopping.
# Training Results
#              precision    recall  f1-score   support
#
#    no serum     0.9422    0.9164    0.9291    163997
#       serum     0.9498    0.9656    0.9576    268377
#
# avg / total     0.9469    0.9470    0.9468    432374
#
# Test Results
#
#              precision    recall  f1-score   support
#
#    no serum     0.9005    0.3253    0.4779     51349
#       serum     0.2423    0.8572    0.3778     12926
#
# avg / total     0.7681    0.4323    0.4578     64275

# %%
X_train = pcadataset.final[(pcadataset.final['Type'] == 'COOH') & (pcadataset.final['Pup and Slice'].isin(['P1S1', 'P2S1', 'P2S2']))].values[:, -ncomp:] 
X_test = pcadataset.final[(pcadataset.final['Type'] == 'COOH') & (pcadataset.final['Pup and Slice']=='P1S2')].values[:, -ncomp:]
y_train = pcadataset.final[(pcadataset.final['Type'] == 'COOH') & (pcadataset.final['Pup and Slice'].isin(['P1S1', 'P2S1', 'P2S2']))]['Serum'].values
y_test = pcadataset.final[(pcadataset.final['Type'] == 'COOH') & (pcadataset.final['Pup and Slice']=='P1S2')]['Serum'].values

for run in range(1):
    #X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.4)

    clf = MLPClassifier(hidden_layer_sizes=(600, ), solver='sgd', verbose=True, max_iter=300, tol=0.00001,
                        alpha=0.001, batch_size=100, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))
# Out:
# Iteration 1, loss = 0
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000008
# Iteration 27, loss = 0.24867190
# Validation score: 0.897895
# Iteration 28, loss = 0.24866400
# Validation score: 0.897895
# Iteration 29, loss = 0.24865949
# Validation score: 0.897951
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000002
# Iteration 30, loss = 0.24863768
# Validation score: 0.897840
# Iteration 31, loss = 0.24863680
# Validation score: 0.897840
# Iteration 32, loss = 0.24863588
# Validation score: 0.897840
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000000
# Iteration 33, loss = 0.24863108
# Validation score: 0.897951
# Iteration 34, loss = 0.24863085
# Validation score: 0.897951
# Iteration 35, loss = 0.24863060
# Validation score: 0.897951
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Learning rate too small. Stopping.
# Training Results
#              precision    recall  f1-score   support
#
#    no serum     0.7910    0.5410    0.6426     30319
#       serum     0.9121    0.9709    0.9406    148802
#
# avg / total     0.8916    0.8981    0.8901    179121
#
# Test Results
#
#              precision    recall  f1-score   support
#
#    no serum     0.4844    0.3016    0.3718     30630
#       serum     0.5873    0.7558    0.6610     40272
#
# avg / total     0.5429    0.5596    0.5360     70902

# %%
X_train = pcadataset.final[(pcadataset.final['Type'] == 'PEG') & (pcadataset.final['Pup and Slice'].isin(['P1S1', 'P2S1', 'P1S2']))].values[:, -ncomp:] 
X_test = pcadataset.final[(pcadataset.final['Type'] == 'PEG') & (pcadataset.final['Pup and Slice']=='P2S2')].values[:, -ncomp:]
y_train = pcadataset.final[(pcadataset.final['Type'] == 'PEG') & (pcadataset.final['Pup and Slice'].isin(['P1S1', 'P2S1', 'P1S2']))]['Serum'].values
y_test = pcadataset.final[(pcadataset.final['Type'] == 'PEG') & (pcadataset.final['Pup and Slice']=='P2S2')]['Serum'].values

for run in range(1):
    #X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.4)

    clf = MLPClassifier(hidden_layer_sizes=(600, ), solver='sgd', verbose=True, max_iter=300, tol=0.00001,
                        alpha=0.001, batch_size=100, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))
# Out:
# Iteration 1, loss = 0.31584266
# Validation score: 0.880626
# Iteration 2, loss = 0.28092064
# Validation score: 0.886018
# Iteration 3, loss = 0.26895515
# Validation score: 0.889722
# Iteration 4, loss = 0.26026345
# Validation score: 0.894880
# Iteration 5, loss = 0.25332271
# Validation score: 0.897412
# Iteration 6, loss = 0.24752359
# Validation score: 0.898490
# Iteration 7, loss = 0.24237942
# Validation score: 0.899944
# Iteration 8, loss = 0.23843434
# Validation score: 0.901772
# Iteration 9, loss = 0.23516574
# Validation score: 0.901538
# Iteration 10, loss = 0.23162661
# Validation score: 0.902804
# Iteration 11, loss = 0.22846480
# Validation score: 0.898772
# Iteration 12, loss = 0.22615534
# Validation score: 0.903788
# Iteration 13, loss = 0.22350662
# Validation score: 0.907539
# Iteration 14, loss = 0.22094498
# Validation score: 0.900178
# Iteration 15, loss = 0.21877875
# Validation score: 0.906086
# Iteration 16, loss = 0.21646527
# Validation score: 0.908477
# Iteration 17, loss = 0.21423810
# Validation score: 0.908758
# Iteration 18, loss = 0.21213897
# Validation score: 0.910634
# Iteration 19, loss = 0.21062574
# Validation score: 0.909602
# Iteration 20, loss = 0.20858112
# Validation score: 0.910306
# Iteration 21, loss = 0.20696536
# Validation score: 0.913400
# Iteration 22, loss = 0.20527054
# Validation score: 0.912322
# Iteration 23, loss = 0.20317140
# Validation score: 0.912556
# Iteration 24, loss = 0.20170111
# Validation score: 0.914385
# Iteration 25, loss = 0.20022499
# Validation score: 0.913306
# Iteration 26, loss = 0.19874762
# Validation score: 0.913447
# Iteration 27, loss = 0.19738048
# Validation score: 0.914807
# Iteration 28, loss = 0.19624700
# Validation score: 0.913400
# Iteration 29, loss = 0.19508924
# Validation score: 0.916729
# Iteration 30, loss = 0.19320400
# Validation score: 0.919495
pcadataset.final['biny'] = pd.cut(pcadataset.final.Y, bins, labels=[0, 1, 2, 3, 4, 5, 6, 7])
pcadataset.final['bins'] = 8*pcadataset.final['binx'] + pcadataset.final['biny']
pcadataset.final = pcadataset.final[np.isfinite(pcadataset.final.bins)]
pcadataset.final.bins = pcadataset.final.bins.astype(int)

cols = pcadataset.final.columns.tolist()
cols = cols[-3:] + cols[:-3]
pcadataset.final = pcadataset.final[cols]

def checkerboard(size):
    rows = int(size/2)
    checks = list(range(0, size*size, size+1))
    
    for i in range(1, rows):
        ssize = size - 2*i
        for j in range(0, ssize):
            checks.append(2*i + (size+1)*j)

    for i in range(1, rows):
        ssize = size - 2*i
        for j in range(0, ssize):
            checks.append(size*size - 1 - (2*i + (size+1)*j))
    checks.sort()
    return checks

# %%
X_train = pcadataset.final[pcadataset.final.bins.isin(checkerboard(8))].values[:, -ncomp:]
X_test = pcadataset.final[~pcadataset.final.bins.isin(checkerboard(8))].values[:, -ncomp:]
y_train = pcadataset.final[pcadataset.final.bins.isin(checkerboard(8))][featofvar].values
y_test = pcadataset.final[~pcadataset.final.bins.isin(checkerboard(8))][featofvar].values

for run in range(1):
    clf = MLPClassifier(hidden_layer_sizes=(900, ), solver='sgd', verbose=True, max_iter=500, tol=0.00001,
                        alpha=0.001, batch_size=50, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))
# Out:
# Iteration 1, loss = 0.68584267
# Validation score: 0.737654
# Iteration 2, loss = 0.63020024
# Validation score: 0.756788
# Iteration 3, loss = 0.60867270
# Validation score: 0.764413
# Iteration 4, loss = 0.59165559
# Validation score: 0.762933
# Iteration 5, loss = 0.57859928
# Validation score: 0.771061
# Iteration 6, loss = 0.56770208
# Validation score: 0.781564
# Iteration 7, loss = 0.55805681
# Validation score: 0.790168
# Iteration 8, loss = 0.54871318
# Validation score: 0.793575
# Iteration 9, loss = 0.54015493
# Validation score: 0.793966
# Iteration 10, loss = 0.53314865
# Validation score: 0.767263
# Iteration 11, loss = 0.52614275
# Validation score: 0.800838
# Iteration 12, loss = 0.51878538
# Validation score: 0.797430
# Iteration 13, loss = 0.51375107
# Validation score: 0.810615
# Iteration 14, loss = 0.50790191
# Validation score: 0.808268
# Iteration 15, loss = 0.50322592
# Validation score: 0.812570
# Iteration 16, loss = 0.49887128
# Validation score: 0.808352
# Iteration 17, loss = 0.49523755
# Validation score: 0.811592
# Iteration 18, loss = 0.49214085
# Validation score: 0.821844
# Iteration 19, loss = 0.48880502
# Validation score: 0.813547
# Iteration 20, loss = 0.48476325
# Validation score: 0.807626
# Iteration 21, loss = 0.48220359
# Validation score: 0.809218
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.001000
# Iteration 22, loss = 0.40455191
# Validation score: 0.850670
# Iteration 23, loss = 0.39690617
# Validation score: 0.852849
# Iteration 24, loss = 0.39327717
# Validation score: 0.852514
# Iteration 25, loss = 0.39048051
# Validation score: 0.853547
# Iteration 26, loss = 0.38773694
# Validation score: 0.856313
# Iteration 27, loss = 0.38500741
# Validation score: 0.855000
# Iteration 28, loss = 0.38293378
# Validation score: 0.847905
# Iteration 29, loss = 0.38077998
# Validation score: 0.855950
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000200
# Iteration 30, loss = 0.36333901
# Validation score: 0.864274
# Iteration 31, loss = 0.36174858
# Validation score: 0.864972
# Iteration 32, loss = 0.36103432
# Validation score: 0.864078
# Iteration 33, loss = 0.36042938
# Validation score: 0.865000
# Iteration 34, loss = 0.35984879
# Validation score: 0.867123
# Iteration 35, loss = 0.35938534
# Validation score: 0.867095
# Iteration 36, loss = 0.35880476
# Validation score: 0.865307
# Iteration 37, loss = 0.35828467
# Validation score: 0.867207
# Iteration 38, loss = 0.35771748
# Validation score: 0.867067
# Iteration 39, loss = 0.35734025
# Validation score: 0.864972
# Iteration 40, loss = 0.35660486
# Validation score: 0.866564
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000040
# Iteration 41, loss = 0.35295887
# Validation score: 0.867877
# Iteration 42, loss = 0.35265950
# Validation score: 0.868045
# Iteration 43, loss = 0.35248990
# Validation score: 0.867709
# Iteration 44, loss = 0.35240623
# Validation score: 0.868324
# Iteration 45, loss = 0.35225107
# Validation score: 0.867765
# Iteration 46, loss = 0.35216468
# Validation score: 0.868827
# Iteration 47, loss = 0.35204169
# Validation score: 0.868156
# Iteration 48, loss = 0.35194537
# Validation score: 0.868855
# Iteration 49, loss = 0.35180372
# Validation score: 0.868492
# Iteration 50, loss = 0.35173458
# Validation score: 0.868184
# Iteration 51, loss = 0.35162259
# Validation score: 0.868156
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000008
# Iteration 52, loss = 0.35083288
# Validation score: 0.868492
# Iteration 53, loss = 0.35074455
# Validation score: 0.869022
# Iteration 54, loss = 0.35070579
# Validation score: 0.868575
# Iteration 55, loss = 0.35068932
# Validation score: 0.868799
# Iteration 56, loss = 0.35066104
# Validation score: 0.868352
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000002
# Iteration 57, loss = 0.35048665
# Validation score: 0.868659
# Iteration 58, loss = 0.35045994
# Validation score: 0.868687
# Iteration 59, loss = 0.35044631
# Validation score: 0.868771
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000000
# Iteration 60, loss = 0.35040991
# Validation score: 0.868939
# Iteration 61, loss = 0.35040634
# Validation score: 0.868883
# Iteration 62, loss = 0.35040446
# Validation score: 0.868939
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Learning rate too small. Stopping.
# Training Results
#              precision    recall  f1-score   support
#
#         PEG     0.7992    0.6537    0.7191     35969
#     PEG_cor     0.8788    0.9303    0.9038     95111
#          PS     0.8760    0.8465    0.8610     88001
#      PS_cor     0.8973    0.9227    0.9098    138913
#
# avg / total     0.8773    0.8790    0.8771    357994
#
# Test Results
#
#              precision    recall  f1-score   support
#
#         PEG     0.5868    0.4332    0.4985     36864
#     PEG_cor     0.8070    0.8492    0.8275     93907
#          PS     0.6237    0.6302    0.6269     86429
#      PS_cor     0.7417    0.7617    0.7515    142066
#
# avg / total     0.7145    0.7192    0.7155    359266

# %%
X_train = pcadataset.final[(pcadataset.final['Type'] == 'PEG') & (pcadataset.final.bins.isin(checkerboard(8)))].values[:, -ncomp:]
X_test = pcadataset.final[(pcadataset.final['Type'] == 'PEG') & (~pcadataset.final.bins.isin(checkerboard(8)))].values[:, -ncomp:]
y_train = pcadataset.final[(pcadataset.final['Type'] == 'PEG') & (pcadataset.final.bins.isin(checkerboard(8)))][featofvar].values
y_test = pcadataset.final[(pcadataset.final['Type'] == 'PEG') & (~pcadataset.final.bins.isin(checkerboard(8)))][featofvar].values

for run in range(1):
    clf = MLPClassifier(hidden_layer_sizes=(900, ), solver='sgd', verbose=True, max_iter=500, tol=0.00001,
                        alpha=0.001, batch_size=50, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))
# Out:
# Iteration 1, loss = 0
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000000
# Iteration 55, loss = 0.18307725
# Validation score: 0.919439
# Iteration 56, loss = 0.18307694
# Validation score: 0.919439
# Iteration 57, loss = 0.18307640
# Validation score: 0.919439
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Learning rate too small. Stopping.
# Training Results
#              precision    recall  f1-score   support
#
#         PEG     0.9186    0.8267    0.8702     35969
#     PEG_cor     0.9369    0.9723    0.9543     95111
#
# avg / total     0.9319    0.9324    0.9312    131080
#
# Test Results
#
#              precision    recall  f1-score   support
#
#         PEG     0.7539    0.6190    0.6798     36864
#     PEG_cor     0.8603    0.9207    0.8894     93907
#
# avg / total     0.8303    0.8356    0.8304    130771

# %%
X_train = pcadataset.final[(pcadataset.final['Type'] == 'COOH') & (pcadataset.final.bins.isin(checkerboard(8)))].values[:, -ncomp:]
X_test = pcadataset.final[(pcadataset.final['Type'] == 'COOH') & (~pcadataset.final.bins.isin(checkerboard(8)))].values[:, -ncomp:]
y_train = pcadataset.final[(pcadataset.final['Type'] == 'COOH') & (pcadataset.final.bins.isin(checkerboard(8)))][featofvar].values
y_test = pcadataset.final[(pcadataset.final['Type'] == 'COOH') & (~pcadataset.final.bins.isin(checkerboard(8)))][featofvar].values

for run in range(1):
    clf = MLPClassifier(hidden_layer_sizes=(900, ), solver='sgd', verbose=True, max_iter=500, tol=0.00001,
                        alpha=0.001, batch_size=50, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))
# Out:
# Iteration 1, loss = 0.47361266
# Validation score: 0.789265
# Iteration 2, loss = 0.44801458
# Validation score: 0.795743
# Iteration 3, loss = 0.43171624
# Validation score: 0.806011
# Iteration 4, loss = 0.41794672
# Validation score: 0.815574
# Iteration 5, loss = 0.40662374
# Validation score: 0.821611
# Iteration 6, loss = 0.39540740
# Validation score: 0.824872
# Iteration 7, loss = 0.38611381
# Validation score: 0.830557
# Iteration 8, loss = 0.37679804
# Validation score: 0.829676
# Iteration 9, loss = 0.36852474
# Validation score: 0.831174
# Iteration 10, loss = 0.36136508
# Validation score: 0.826150
# Iteration 11, loss = 0.35348313
# Validation score: 0.848096
# Iteration 12, loss = 0.34623487
# Validation score: 0.845011
# Iteration 13, loss = 0.33929601
# Validation score: 0.858717
# Iteration 14, loss = 0.33351662
# Validation score: 0.855896
# Iteration 15, loss = 0.32845815
# Validation score: 0.858717
# Iteration 16, loss = 0.32196846
# Validation score: 0.850212
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.001000
# Iteration 17, loss = 0.28236077
# Validation score: 0.881103
# Iteration 18, loss = 0.27689850
# Validation score: 0.882998
# Iteration 19, loss = 0.27436259
# Validation score: 0.880002
# Iteration 20, loss = 0.27185263
# Validation score: 0.887582
# Iteration 21, loss = 0.26963630
# Validation score: 0.886568
# Iteration 22, loss = 0.26752696
# Validation score: 0.885510
# Iteration 23, loss = 0.26533738
# Validation score: 0.891195
# Iteration 24, loss = 0.26334291
# Validation score: 0.888243
# Iteration 25, loss = 0.26136596
# Validation score: 0.884453
# Iteration 26, loss = 0.25934893
# Validation score: 0.887317
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000200
# Iteration 27, loss = 0.24936031
# Validation score: 0.897717
# Iteration 28, loss = 0.24825367
# Validation score: 0.897629
# Iteration 29, loss = 0.24782256
# Validation score: 0.896087
# Iteration 30, loss = 0.24737559
# Validation score: 0.897805
# Iteration 31, loss = 0.24684439
# Validation score: 0.896439
# Iteration 32, loss = 0.24647782
# Validation score: 0.898202
# Iteration 33, loss = 0.24597783
# Validation score: 0.898466
# Iteration 34, loss = 0.24552193
# Validation score: 0.897938
# Iteration 35, loss = 0.24509756
# Validation score: 0.897717
# Iteration 36, loss = 0.24461052
# Validation score: 0.897144
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000040
# Iteration 37, loss = 0.24250083
# Validation score: 0.900097
# Iteration 38, loss = 0.24221430
# Validation score: 0.899304
# Iteration 39, loss = 0.24217114
# Validation score: 0.899172
# Iteration 40, loss = 0.24204232
# Validation score: 0.899612
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000008
# Iteration 41, loss = 0.24159205
# Validation score: 0.899524
# Iteration 42, loss = 0.24152714
# Validation score: 0.899260
# Iteration 43, loss = 0.24150187
# Validation score: 0.899039
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000002
# Iteration 44, loss = 0.24138452
# Validation score: 0.899216
# Iteration 45, loss = 0.24137660
# Validation score: 0.899304
# Iteration 46, loss = 0.24137469
# Validation score: 0.899216
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000000
# Iteration 47, loss = 0.24134751
# Validation score: 0.899216
# Iteration 48, loss = 0.24134586
# Validation score: 0.899172
# Iteration 49, loss = 0.24134475
# Validation score: 0.899127
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Learning rate too small. Stopping.
# Training Results
#              precision    recall  f1-score   support
#
#          PS     0.9020    0.8641    0.8827     88001
#      PS_cor     0.9162    0.9405    0.9282    138913
#
# avg / total     0.9107    0.9109    0.9105    226914
#
# Test Results
#
#              precision    recall  f1-score   support
#
#          PS     0.6792    0.6865    0.6828     86429
#      PS_cor     0.8080    0.8027    0.8054    142066
#
# avg / total     0.7593    0.7588    0.7590    228495

# %%
print('{} +/ {}'.format(np.mean(trainp), np.std(trainp)))
print('{} +/ {}'.format(np.mean(testp), np.std(testp)))

# %%
#ncomp = 14
trainp = np.array([])
testp = np.array([])
labels3 = ['COOH', 'PEG']

for i in range(0, 5):
    KNNmod, X, y = pca.build_model(pcadataset.final, featofvar, labels, equal_sampling=True,
                                       tsize=2000, input_cols=ncomp, model='MLP', NNhidden_layer=(6, 5, 3))
    trainp = np.append(trainp, pca.predict_model(KNNmod, X, y))
    
    X2 = pcadataset.final.values[:, -ncomp:]
    y2 = pcadataset.final[featofvar].values
    testp = np.append(testp, pca.predict_model(KNNmod, X2, y2))
    print('Run {}: {}'.format(i, testp[i]))

# %%
print('{} +/ {}'.format(np.mean(trainp), np.std(trainp)))
print('{} +/ {}'.format(np.mean(testp), np.std(testp)))

# %%
ypred = pd.Series(KNNmod.predict(X2)).str.split('_', expand=True)

# %%
ya = np.copy(yact[0].values)
ya[ya == 'COOH'] = 1
ya[ya != 1] = 0

yp = np.copy(ypred[0].values)
yp[yp == 'COOH'] = 1
yp[yp != 1] = 0

# %%
from sklearn import metrics

def mod_roc_curve(y_true, y_score, pos_label):
    ya = np.copy(y_true)
    ya[ya == pos_label] = 1
    ya[ya != 1] = 0

    yp = np.copy(y_score)
    yp[yp == pos_label] = 1
    yp[yp != 1] = 0
    
    fpr, tpr, thresholds = metrics.roc_curve(ya, yp, drop_intermediate=False)
    return fpr, tpr, thresholds

# %%
fpr, tpr, thresholds = mod_roc_curve(yact[1].values, ypred[1].values, pos_label=None)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(fpr, tpr)

# %%
plt.plot(fpr, tpr)

# %%
plt.plot(fpr, tpr)

# %%
plt.plot(fpr, tpr)

# %%
yr1 = np.random.randint(0, 2, size=400)
yr2 = np.random.rand(400)
fpr, tpr, thresholds = metrics.roc_curve(yr1, yr2)
plt.plot(fpr, tpr)

# %%
noise = 10
size = 400
yr1 = np.random.randint(0, 2, size=size)
yr2 = yr1 + noise*np.random.rand(size) - 0.5*noise
fpr, tpr, thresholds = metrics.roc_curve(yr1, yr2)
plt.plot(fpr, tpr)

# %%
noise = 5
size = 400
yr1 = np.random.randint(0, 2, size=size)
yr2 = yr1 + noise*np.random.rand(size) - 0.5*noise
fpr, tpr, thresholds = metrics.roc_curve(yr1, yr2)
plt.plot(fpr, tpr)

# %%
noise = 2.5
size = 400
yr1 = np.random.randint(0, 2, size=size)
yr2 = yr1 + noise*np.random.rand(size) - 0.5*noise
fpr, tpr, thresholds = metrics.roc_curve(yr1, yr2)
plt.plot(fpr, tpr)

# %%
noise = 1.5
size = 400
yr1 = np.random.randint(0, 2, size=size)
yr2 = yr1 + noise*np.random.rand(size) - 0.5*noise
fpr, tpr, thresholds = metrics.roc_curve(yr1, yr2)
plt.plot(fpr, tpr)

# %%
KNNmod.score(X2, y2)

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn import svm
from sklearn import metrics

# %%
ynew = label_binarize(y, classes=labels)
y2new = label_binarize(y2, classes=labels)
n_classes = ynew.shape[1]

# %%
ynew

# %%
classifier = OneVsRestClassifier(svm.SVC(kernel='linear', probability=True))

# %%
y_score = classifier.fit(X, ynew).decision_function(X2)

# %%
y_scorep = pd.DataFrame(data=y_score.transpose()).idxmax()
y2newp = pd.DataFrame(data=y2new.transpose()).idxmax()

# %%
ycorrect = y_scorep == y2newp

# %%
ycorrect.mean()

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = metrics.roc_curve(y2new[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = metrics.roc_curve(y2new.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# %%
tclass = 0
plt.figure()
lw = 4
plt.plot(fpr[tclass], tpr[tclass], color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[tclass])
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")

# %%
classifier.score(X2, y2new)

# %%
roc_auc[0]*roc_auc[1]*roc_auc[2]*roc_auc[3]

# %%
# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure()
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'slategray'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0, 0.4])
plt.ylim([0.5, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")

# %% [markdown]
# I found a standard way of implementing ROC curves with non-binary data called the one versus all method. It essentially breaks a n-class system into n-1 binary systems, and you make an n-1 roc curves for each case. I can't use MLP methods this way, but it looks like I can get high predictive power as-is? Kind of? I can get

# %%
fpr, tpr, _ = metrics.roc_curve(y, y_score)

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp

# %%
# Import some data to play with
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %%
# Binarize the output
y = label_binarize(y, classes=[0, 1, 2])
n_classes = y.shape[1]

# %%
y

# %%
# Add noisy features to make the problem harder
random_state = np.random.RandomState(0)
n_samples, n_features = X.shape
X = np.c_[X, random_state.randn(n_samples, 200 * n_features)]

# shuffle and split training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.5,
                                                    random_state=0)

# %%
# Learn to predict each class against the other
classifier = OneVsRestClassifier(svm.SVC(kernel='linear', probability=True,
                                 random_state=random_state))
y_score = classifier.fit(X_train, y_train).decision_function(X_test)

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
