# %% [markdown]
# # Experiment Initialization

# %% [markdown]
# Here, I define the terms of my experiment, among them the location of the files in S3 (bucket and folder name), and each of the video prefixes (everything before the file extension) that I want to track.
#
# Note that these videos should be similar-ish: while we can account for differences in mean intensities between videos, particle sizes should be approximately the same, and (slightly less important) particles should be moving at about the same order of magnitude speed. In this experiment, these videos were taken in 0.4% agarose gel at 100x magnification and 100.02 fps shutter speeds with nanoparticles of about 100nm in diameter.

# %%
to_track = []
result_futures = {}
start_knot = 36 #Must be unique number for every run on Cloudknot.

remote_folder = '09_26_18_tissue_study' #Folder in AWS S3 containing files to be analyzed
bucket = 'hpontes.data'
vids = 5
types = ['10K', '1K', '5K', 'COOH']
slices = [4, 5, 6]

for typ in types:
    for slic in slices:
        for num in range(1, vids+1):
            #to_track.append('100x_0_4_1_2_gel_{}_bulk_vid_{}'.format(vis, num))
            to_track.append('{}_tissue_S{}_XY{}'.format(typ, slic, num))

# %%
to_track[25]

# %% [markdown]
# The videos used with this analysis are fairly large (2048 x 2048 pixels and 651 frames), and in cases like this, the tracking algorithm can quickly eat up RAM. In this case, we chose to crop the videos to 512 x 512 images such that we can run our jobs on smaller EC2 instances with 16GB of RAM.
#
# Note that larger jobs can be made with user-defined functions such that splitting isn't necessary-- or perhaps an intermediate amount of memory that contains splitting, tracking, and msd calculation functions all performed on a single EC2 instance.
#
# The compiled functions in the knotlets module require access to buckets on AWS. In this case, we will be using a publicly (read-only) bucket. If users want to run this notebook on their own, will have to transfer files from nancelab.publicfiles to their own bucket, as it requires writing to S3 buckets.

# %%
import diff_classifier.knotlets as kn

# %%
for prefix in to_track[25:]:
    kn.split(prefix, remote_folder=remote_folder, bucket=bucket)

# %% [markdown]
# ## Tracking predictor

# %% [markdown]
# Tracking normally requires user input in the form of tracking parameters e.g. particle radius, linking max distance, max frame gap etc. When large datasets aren't required, each video can be manageably manually tracked using the TrackMate GUI. However, when datasets get large e.g. >20 videos, this can become extremely arduous. For videos that are fairly similar, you can get away with using similar tracking parameters across all videos. However, one parameter that is a little more noisy that the others is the quality filter value. Quality is a numerical value that approximate how likely a particle is to be "real."
#
# In this case, I built a predictor that estimates the quality filter value based on intensity distributions from the input images. Using a relatively small training dataset (5-20 videos), users can get fairly good estimates of quality filter values that can be used in parallelized tracking workflows.
#
# Note: in the current setup, the predictor should be run in Python 3. While the code will run in Python 3, there are differences between the random number generators in Python2 and Python3 that I was not able to control for.

# %%
import os
import diff_classifier.imagej as ij
import boto3
import os.path as op
import diff_classifier.aws as aws
import diff_classifier.knotlets as kn
import numpy as np
from sklearn.externals import joblib

# %% [markdown]
# The regress_sys function should be run twice. When have_output is set to False, it generates a list of files that the user should manually track using Trackmate. Once the quality filter values are found, they can be used as input (y) to generate a regress object that can predict quality filter values for additional videos. Once y is assigned, set have_output to True and re-run the cell.

# %%
tnum=15 #number of training datasets
pref = []
for num in to_track:                    
    for row in range(0, 4):
        for col in range(0, 4):
            pref.append("{}_{}_{}".format(num, row, col))

y = np.array([0.7, 14.0, 1.15, 1.5, 1.7, 7.1, 1.6, 0.9, 1.6, 2.4, 1.35, 11.9, 1.47, 0.9, 1.0])

# Creates regression object based of training dataset composed of input images and manually
# calculated quality cutoffs from tracking with GUI interface.
regress = ij.regress_sys(remote_folder, pref, y, tnum, randselect=True,
                         have_output=True, bucket_name=bucket)
#Read up on how regress_sys works before running.

# %%
#Pickle object
filename = 'regress.obj'
with open(filename,'wb') as fp:
    joblib.dump(regress,fp)

import boto3
s3 = boto3.client('s3')
aws.upload_s3(filename, remote_folder+'/'+filename, bucket_name=bucket)

# %% [markdown]
# Users should input all tracking parameters into the tparams object. Note that the quality value will be overwritten by values found using the quality predictor found above.

# %%
tparams1 = {'radius': 5.0, 'threshold': 0.0, 'do_median_filtering': False,
           'quality': 5.0, 'xdims': (0, 511), 'ydims': (1, 511),
           'median_intensity': 300.0, 'snr': 0.0, 'linking_max_distance': 12.0,
           'gap_closing_max_distance': 18.0, 'max_frame_gap': 8,
           'track_duration': 20.0}

# tparams2 = {'radius': 4.0, 'threshold': 0.0, 'do_median_filtering': False,
#            'quality': 10.0, 'xdims': (0, 511), 'ydims': (1, 511),
#            'median_intensity': 300.0, 'snr': 0.0, 'linking_max_distance': 8.0,
#            'gap_closing_max_distance': 12.0, 'max_frame_gap': 6,
#            'track_duration': 20.0}

# %% [markdown]
# ## Cloudknot setup

# %% [markdown]
# Cloudknot requires the user to define a function that will be sent to multiple computers to run. In this case, the function knotlets.tracking will be used. We create a docker image that has the required installations (defined by the requirements.txt file from diff_classifier on Github, and the base Docker Image below that has Fiji pre-installed in the correct location.
#
# Note that I modify the Docker image below such that the correct version of boto3 is installed. For some reason, versions later than 1.5.28 error out, so I specified 5.28 as the correct version. Run my_image.build below to double-check that the Docker image is successfully built prior to submitting the job to Cloudknot.

# %%
import cloudknot as ck
import os.path as op

github_installs=('https://github.com/ccurtis7/diff_classifier.git@Chad')
#my_image = ck.DockerImage(func=kn.tracking, base_image='arokem/python3-fiji:0.3', github_installs=github_installs)
my_image = ck.DockerImage(func=kn.assemble_msds, base_image='arokem/python3-fiji:0.3', github_installs=github_installs)
docker_file = open(my_image.docker_path)
docker_string = docker_file.read()
docker_file.close()

req = open(op.join(op.split(my_image.docker_path)[0], 'requirements.txt'))
req_string = req.read()
req.close()

new_req = req_string[0:req_string.find('\n')-4]+'5.28'+ req_string[req_string.find('\n'):]
req_overwrite = open(op.join(op.split(my_image.docker_path)[0], 'requirements.txt'), 'w')
req_overwrite.write(new_req)
req_overwrite.close()

# %%
my_image.build("0.1", image_name="test_image")

# %% [markdown]
# The object all_maps is an iterable containing all the inputs sent to Cloudknot. This is useful, because if the user needs to modify some of the tracking parameters for a single video, this can be done prior to submission to Cloudknot.

# %%
names = []
all_maps = []
for prefix in to_track:    
    for i in range(0, 4):
        for j in range(0, 4):
            names.append('{}_{}_{}'.format(prefix, i, j))
            all_maps.append(('{}_{}_{}'.format(prefix, i, j), remote_folder, bucket, 'regress.obj',
                             4, 4, (512, 512), tparams1))

all_maps
# Out:
# [('10K_tissue_S4_XY1_0_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY1_0_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY1_0_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY1_0_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY1_1_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY1_1_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY1_1_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY1_1_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY1_2_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY1_2_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY1_2_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY1_2_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY1_3_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY1_3_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY1_3_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY1_3_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY2_0_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY2_0_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY2_0_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY2_0_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY2_1_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY2_1_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY2_1_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY2_1_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY2_2_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY2_2_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY2_2_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY2_2_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY2_3_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY2_3_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY2_3_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY2_3_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY3_0_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY3_0_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY3_0_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY3_0_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY3_1_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY3_1_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY3_1_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY3_1_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY3_2_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY3_2_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY3_2_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY3_2_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY3_3_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY3_3_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY3_3_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY3_3_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY4_0_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY4_0_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY4_0_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY4_0_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY4_1_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY4_1_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY4_1_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY4_1_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY4_2_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY4_2_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY4_2_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY4_2_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY4_3_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY4_3_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY4_3_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY4_3_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY5_0_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY5_0_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY5_0_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY5_0_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY5_1_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY5_1_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY5_1_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY5_1_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY5_2_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY5_2_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY5_2_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY5_2_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY5_3_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY5_3_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY5_3_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S4_XY5_3_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY1_0_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY1_0_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY1_0_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY1_0_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY1_1_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY1_1_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY1_1_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY1_1_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY1_2_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY1_2_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY1_2_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY1_2_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY1_3_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY1_3_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY1_3_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY1_3_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY2_0_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY2_0_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY2_0_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY2_0_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY2_1_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY2_1_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY2_1_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY2_1_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY2_2_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY2_2_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY2_2_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY2_2_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY2_3_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY2_3_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY2_3_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY2_3_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY3_0_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY3_0_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY3_0_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('10K_tissue_S5_XY3_0_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
# ...
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY3_2_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY3_2_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY3_3_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY3_3_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY3_3_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY3_3_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY4_0_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY4_0_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY4_0_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY4_0_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY4_1_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY4_1_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY4_1_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY4_1_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY4_2_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY4_2_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY4_2_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY4_2_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY4_3_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY4_3_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY4_3_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY4_3_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY5_0_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY5_0_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY5_0_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY5_0_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY5_1_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY5_1_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY5_1_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY5_1_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY5_2_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY5_2_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY5_2_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY5_2_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY5_3_0',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY5_3_1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY5_3_2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('COOH_tissue_S6_XY5_3_3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 18.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 8,
#    'median_intensity': 300.0,
#    'quality': 5.0,
#    'radius': 5.0,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)})]

# %%
len(all_maps)
# Out:
# 960

# %% [markdown]
# The Cloudknot knot object sets up the compute environment which will run the code. Note that the name must be unique. Every time you submit a new knot, you should change the name. I do this with the variable start_knot, which I vary for each run.
#
# If larger jobs are anticipated, users can adjust both RAM and storage with the memory and image_id variables. Memory specifies the amount of RAM to be used. Users can build a customized AMI with as much space as they need, and enter the ID into image_ID. Read the Cloudknot documentation for more details.

# %%
ck.aws.set_region('us-west-1')
knot = ck.Knot(name='download_and_track_{}_b{}'.format('chadg', start_knot),
               docker_image = my_image,
               memory = 16000,
               resource_type = "SPOT",
               bid_percentage = 100,
               #image_id = 'ami-015a1b4cd3895860b', #May need to change this line
               pars_policies=('AmazonS3FullAccess',),
               )
result_futures = knot.map(all_maps[0:500], starmap=True)

# %%
ck.aws.set_region('us-west-1')
knot.clobber()

# %%
ck.aws.set_region('us-east-1')
knot1 = ck.Knot(name='download_and_track_{}_c{}'.format('chadg', start_knot),
               docker_image = my_image,
               memory = 16000,
               resource_type = "SPOT",
               bid_percentage = 100,
               #image_id = 'ami-015a1b4cd3895860b', #May need to change this line
               pars_policies=('AmazonS3FullAccess',),
               )
result_futures1 = knot1.map(all_maps[500:], starmap=True)

# %%
ck.aws.set_region('us-east-1')
knot1.clobber()

# %%
ck.aws.set_region('us-east-1')
knot2 = ck.Knot(name='download_and_track_{}_f{}'.format('chadg', start_knot),
               docker_image = my_image,
               memory = 16000,
               resource_type = "SPOT",
               bid_percentage = 100,
               #image_id = 'ami-015a1b4cd3895860b', #May need to change this line
               pars_policies=('AmazonS3FullAccess',),
               )
result_futures2 = knot2.map(all_maps2, starmap=True)

# %%
ck.aws.set_region('us-east-1')
knot2.clobber()

# %%
knot2 = ck.Knot(name='download_and_track_{}_b{}'.format('chadh', start_knot),
               docker_image = my_image,
               memory = 16000,
               resource_type = "SPOT",
               bid_percentage = 100,
               #image_id = 'ami-015a1b4cd3895860b', #May need to change this line
               pars_policies=('AmazonS3FullAccess',),
               )

# %%
result_futures2 = knot2.map(all_maps3, starmap=True)

# %%
ck.aws.set_region('us-west-1')

# %%
knot2.clobber()

# %%
names = []
all_maps2 = []
for prefix in to_track:
    all_maps2.append((prefix, remote_folder, bucket, (512, 512), 651, 4, 4))

all_maps2
# Out:
# [('10K_tissue_S4_XY1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('10K_tissue_S4_XY2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('10K_tissue_S4_XY3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('10K_tissue_S4_XY4',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('10K_tissue_S4_XY5',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('10K_tissue_S5_XY1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('10K_tissue_S5_XY2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('10K_tissue_S5_XY3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('10K_tissue_S5_XY4',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('10K_tissue_S5_XY5',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('10K_tissue_S6_XY1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('10K_tissue_S6_XY2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('10K_tissue_S6_XY3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('10K_tissue_S6_XY4',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('10K_tissue_S6_XY5',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('1K_tissue_S4_XY1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('1K_tissue_S4_XY2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('1K_tissue_S4_XY3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('1K_tissue_S4_XY4',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('1K_tissue_S4_XY5',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('1K_tissue_S5_XY1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('1K_tissue_S5_XY2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('1K_tissue_S5_XY3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('1K_tissue_S5_XY4',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('1K_tissue_S5_XY5',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('1K_tissue_S6_XY1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('1K_tissue_S6_XY2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('1K_tissue_S6_XY3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('1K_tissue_S6_XY4',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('1K_tissue_S6_XY5',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('5K_tissue_S4_XY1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('5K_tissue_S4_XY2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('5K_tissue_S4_XY3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('5K_tissue_S4_XY4',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('5K_tissue_S4_XY5',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('5K_tissue_S5_XY1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('5K_tissue_S5_XY2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('5K_tissue_S5_XY3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('5K_tissue_S5_XY4',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('5K_tissue_S5_XY5',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('5K_tissue_S6_XY1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('5K_tissue_S6_XY2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('5K_tissue_S6_XY3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('5K_tissue_S6_XY4',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('5K_tissue_S6_XY5',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('COOH_tissue_S4_XY1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('COOH_tissue_S4_XY2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('COOH_tissue_S4_XY3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('COOH_tissue_S4_XY4',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('COOH_tissue_S4_XY5',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('COOH_tissue_S5_XY1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('COOH_tissue_S5_XY2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('COOH_tissue_S5_XY3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('COOH_tissue_S5_XY4',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('COOH_tissue_S5_XY5',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('COOH_tissue_S6_XY1',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('COOH_tissue_S6_XY2',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('COOH_tissue_S6_XY3',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('COOH_tissue_S6_XY4',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4),
#  ('COOH_tissue_S6_XY5',
#   '09_26_18_tissue_study',
#   'hpontes.data',
#   (512, 512),
#   651,
#   4,
#   4)]

# %%
len(all_maps2)
# Out:
# 60

# %%
ck.aws.set_region('us-east-1')

# %%
knot3 = ck.Knot(name='download_and_track_{}_b{}'.format('chadi', start_knot),
               docker_image = my_image,
               memory = 144000,
               resource_type = "SPOT",
               bid_percentage = 100,
               #image_id = 'ami-015a1b4cd3895860b', #May need to change this line
               pars_policies=('AmazonS3FullAccess',),
               )

# %%
result_futures3 = knot3.map(all_maps2, starmap=True)

# %%
knot3.clobber()

# %%
knot4 = ck.Knot(name='download_and_track_{}_b{}'.format('chadj', start_knot),
               docker_image = my_image,
               memory = 144000,
               resource_type = "SPOT",
               bid_percentage = 100,
               #image_id = 'ami-015a1b4cd3895860b', #May need to change this line
               pars_policies=('AmazonS3FullAccess',),
               )

# %%
result_futures4 = knot4.map(all_maps2, starmap=True)

# %%
for i in range(0, 4):
        for j in range(0, 4):
            names.append('{}_{}_{}.tif'.format(prefix, i, j))
print(prefix)
for name in names:
    row = int(name.split(prefix)[1].split('.')[0].split('_')[1])

# %%
all_maps2

# %%
ck.aws.get_region()

# %%
knot3 = ck.Knot(name='download_and_track_{}_b{}'.format('chad33', start_knot),
               docker_image = my_image,
               memory = 64000,
               resource_type = "SPOT",
               bid_percentage = 100,
               #image_id = 'ami-015a1b4cd3895860b', #May need to change this line
               pars_policies=('AmazonS3FullAccess',),
               )

# %%
result_futures5 = knot3.map(all_maps2, starmap=True)

# %%
knot3.clobber()

# %%
ck.aws.get_region()
ck.aws.set_region('us-east-1')
ck.aws.get_region()

# %%
knot2 = ck.Knot(name='download_and_track_{}_b{}'.format('chad2', start_knot),
               docker_image = my_image,
               memory = 144000,
               resource_type = "SPOT",
               bid_percentage = 100,
               #image_id = 'ami-0e00afdf500081a0d', #May need to change this line
               pars_policies=('AmazonS3FullAccess',))

# %%
result_futures2 = knot2.map(all_maps, starmap=True)

# %%
knot3 = ck.Knot(name='download_and_track_{}_b{}'.format('chad3', start_knot),
               docker_image = my_image,
               memory = 144000,
               resource_type = "SPOT",
               bid_percentage = 100,
               #image_id = 'ami-0e00afdf500081a0d', #May need to change this line
               pars_policies=('AmazonS3FullAccess',))

# %%
result_futures3 = knot3.map(all_maps, starmap=True)

# %%
knot4 = ck.Knot(name='download_and_track_{}_b{}'.format('chad4', start_knot),
               docker_image = my_image,
               memory = 144000,
               resource_type = "SPOT",
               bid_percentage = 100,
               #image_id = 'ami-0e00afdf500081a0d', #May need to change this line
               pars_policies=('AmazonS3FullAccess',))

# %%
result_futures4 = knot4.map(all_maps, starmap=True)

# %%
knot5 = ck.Knot(name='download_and_track_{}_b{}'.format('chad5', start_knot),
               docker_image = my_image,
               memory = 144000,
               resource_type = "SPOT",
               bid_percentage = 100,
               #image_id = 'ami-0e00afdf500081a0d', #May need to change this line
               pars_policies=('AmazonS3FullAccess',))

# %%
result_futures5 = knot5.map(all_maps, starmap=True)

# %%
ck.aws.set_region('eu-west-1')
knot5.clobber()

# %%
tparams2 = {'radius': 3.5, 'threshold': 0.0, 'do_median_filtering': False,
           'quality': 10.0, 'xdims': (0, 511), 'ydims': (1, 511),
           'median_intensity': 300.0, 'snr': 0.0, 'linking_max_distance': 15.0,
           'gap_closing_max_distance': 22.0, 'max_frame_gap': 5,
           'track_duration': 20.0}

# %%
missing = []
all_maps3 = []
import boto3
import botocore

s3 = boto3.resource('s3')


for name in names:
    try:
        s3.Object(bucket, '{}/Traj_{}.csv'.format(remote_folder, name)).load()
    except botocore.exceptions.ClientError as e:
        if e.response['Error']['Code'] == "404":
            missing.append(name)
            all_maps3.append((name, remote_folder, bucket, 'regress.obj',
                             4, 4, (512, 512), tparams1))
        else:
            print('Something else has gone wrong')

# %%
all_maps3

# %%
import diff_classifier.aws as aws

# %%
old_folder = 'Gel_Studies/08_14_18_gel_validation/old_msds2'

for name in missing:
    filename = 'Traj_{}.csv'.format(name)
    aws.download_s3('{}/{}'.format(old_folder, filename), filename, bucket_name=bucket)
    aws.upload_s3(filename, '{}/{}'.format(remote_folder, filename), bucket_name=bucket)

# %% [markdown]
# Users can monitor the progress of their job in the Batch interface. Once the code is complete, users should clobber their knot to make sure that all AWS resources are removed.

# %%
knot.clobber()

# %% [markdown]
# ## Downstream analysis and visualization

# %% [markdown]
# The knotlet.assemble_msds function (which can also potentially be submitted to Cloudknot as well for large jobs) calculates the mean squared displacements and trajectory features from the raw trajectory csv files found from the Cloudknot submission. It accesses them from the S3 bucket to which they were saved.

# %%
for prefix in to_track:
    kn.assemble_msds(prefix, remote_folder, bucket=bucket)
    print('Successfully output msds for {}'.format(prefix))

# %%
for prefix in to_track[5:7]:
    kn.assemble_msds(prefix, remote_folder, bucket='ccurtis.data')
    print('Successfully output msds for {}'.format(prefix))

# %%
all_maps2 = []
for prefix in to_track:    
    all_maps2.append((prefix, remote_folder, bucket, 'regress100.obj',
                     4, 4, (512, 512), tparams))

# %%
knot = ck.Knot(name='download_and_track_{}_b{}'.format('chad', start_knot),
               docker_image = my_image,
               memory = 16000,
               resource_type = "SPOT",
               bid_percentage = 100,
               #image_id = 'ami-0e00afdf500081a0d', #May need to change this line
               pars_policies=('AmazonS3FullAccess',))

# %% [markdown]
# Diff_classifier includes some useful imaging tools as well, including checking trajectories, plotting heatmaps of trajectory features, distributions of diffusion coefficients, and MSD plots.

# %%
import diff_classifier.heatmaps as hm
import diff_classifier.aws as aws

# %%
prefix = to_track[1]

msds = 'msd_{}.csv'.format(prefix)
feat = 'features_{}.csv'.format(prefix)
aws.download_s3('{}/{}'.format(remote_folder, msds), msds, bucket_name=bucket)
aws.download_s3('{}/{}'.format(remote_folder, feat), feat, bucket_name=bucket)

# %%
hm.plot_trajectories(prefix, upload=False, figsize=(8, 8))

# %%
geomean, geoSEM = hm.plot_individual_msds(prefix, x_range=10, y_range=300, umppx=1, fps=1, upload=False)

# %%
hm.plot_heatmap(prefix, upload=False)

# %%
hm.plot_particles_in_frame(prefix, y_range=6000, upload=False)

# %%
missing = []
all_maps2 = []
import boto3
import botocore

s3 = boto3.resource('s3')


for name in names:
    try:
        s3.Object(bucket, '{}/Traj_{}.csv'.format(remote_folder, name)).load()
    except botocore.exceptions.ClientError as e:
        if e.response['Error']['Code'] == "404":
            missing.append(name)
            #all_maps2.append((name, remote_folder, bucket, 'regress.obj',
            #                 4, 4, (512, 512), tparams2))
        else:
            print('Something else has gone wrong')

# %%
missing = ['PS_COOH_2mM_XY05_1_1', 'PS_NH2_2mM_XY04_2_1']

# %%
all_maps

# %%
kn.tracking(missing[0], remote_folder, bucket=bucket, tparams=tparams1)

# %%
kn.tracking(missing[1], remote_folder, bucket=bucket, tparams=tparams1)
