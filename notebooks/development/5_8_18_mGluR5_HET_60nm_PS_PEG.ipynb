# %%
import diff_classifier.aws as aws
import diff_classifier.utils as ut
import diff_classifier.msd as msd
import diff_classifier.features as ft
import diff_classifier.imagej as ij
import diff_classifier.heatmaps as hm
import diff_classifier.heatmaps_MM_adjust as hm_mm
import os
import os.path as op
import numpy as np
import numpy.ma as ma
import scipy.stats as stats
import pandas as pd
import skimage.io as sio
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Loading and checking a video

# %%
test_image = sio.imread('{}_1_1.tif'.format(prefix))

# %%
#aws.download_s3('{}/{}.tif'.format(remote_folder, prefix), '{}.tif'.format(prefix))

fig, ax = plt.subplots(figsize=(14, 14))
full_image = sio.imread('{}.tif'.format(prefix))
ax.imshow(full_image[300, :, :], cmap='gray', vmin=60, vmax=500)
ax.axis('off')

# %%
# fig, ax = plt.subplots(figsize=(10, 10))
# ax.imshow(test_image[650, :, :], cmap='gray', vmin=60, vmax=300)

# %%
# fig, ax = plt.subplots(figsize=(10, 10))
# ax.imshow(test_image[0, :, :], cmap='gray', vmin=60, vmax=300)

# %% [markdown]
# # Splitting images before analysis

# %%
prefix = '60nm_PS_PEG_hippocampus_vid_1_1'
#remote_folder = "01_18_Experiment/{}".format(prefix.split('_')[0])
local_folder = '/Volumes/McKenna_Mac_Partition/Confocal_Data/MPT/5_8_18_mGluR5_HET_60nm_PS_PEG/section_1'
ires = 511
frames = 650
filename = '{}.tif'.format(prefix)
#remote_name = op.join(remote_folder, filename)
local_name = op.join(local_folder, filename)
#s3 = boto3.client('s3')

# %%
os.getcwd()

# %%
#aws.download_s3(remote_name, local_name)
names = ij.partition_im(local_name)
for name in names:
    #aws.upload_s3(name, op.join(remote_folder, name))
    print("Done with splitting.  Should output file of name {}".format(local_folder+'/'+name))

# %%
names = []
for i in range(0, 4):
    for j in range(0, 4):
        names.append('{}_{}_{}.tif'.format(prefix, i, j))

# %%
#delete when done: only using to run plotting on a single of the 16 crops
names = prefix+'_0_0.tif'

# %% [markdown]
# # Particle Tracking

# %% [markdown]
# Pause here to demonstrate tracking with the Trackmate GUI.  Show the Trackmate template file.

# %%
#ij.track?

# %%
# outfile = 'Traj_' + names[15].split('.')[0] + '.csv'
# row = int(names[15].split('.')[0].split('_')[4])
# local_im = op.join(local_folder, names[15])
# row=3

# test_intensity = ij.mean_intensity(local_im)
# if test_intensity > 500:
#     quality = 245
# else:
#     quality = 4.5
    
# if row==3:
#     y = 500
# else:
#     y = 511

# ij.track(local_im, outfile, template=None, fiji_bin=None, radius=4.5, threshold=0., 
#       do_median_filtering=True, quality=quality, x=511, y=y, ylo=1, median_intensity=300.0, snr=0.0, 
#       linking_max_distance=8.0, gap_closing_max_distance=10.0, max_frame_gap=2,
#       track_displacement=10.0)

# %%
print(names)
# Out:
# ['60nm_PS_PEG_hippocampus_vid_1_1_0_0.tif', '60nm_PS_PEG_hippocampus_vid_1_1_0_1.tif', '60nm_PS_PEG_hippocampus_vid_1_1_0_2.tif', '60nm_PS_PEG_hippocampus_vid_1_1_0_3.tif', '60nm_PS_PEG_hippocampus_vid_1_1_1_0.tif', '60nm_PS_PEG_hippocampus_vid_1_1_1_1.tif', '60nm_PS_PEG_hippocampus_vid_1_1_1_2.tif', '60nm_PS_PEG_hippocampus_vid_1_1_1_3.tif', '60nm_PS_PEG_hippocampus_vid_1_1_2_0.tif', '60nm_PS_PEG_hippocampus_vid_1_1_2_1.tif', '60nm_PS_PEG_hippocampus_vid_1_1_2_2.tif', '60nm_PS_PEG_hippocampus_vid_1_1_2_3.tif', '60nm_PS_PEG_hippocampus_vid_1_1_3_0.tif', '60nm_PS_PEG_hippocampus_vid_1_1_3_1.tif', '60nm_PS_PEG_hippocampus_vid_1_1_3_2.tif', '60nm_PS_PEG_hippocampus_vid_1_1_3_3.tif']

# %%
names[0].split('.')[0].split('_')
# Out:
# ['60nm', 'PS', 'PEG', 'hippocampus', 'vid', '1', '1', '0', '0']

# %%
print(names[0].split('.')[0])
# Out:
# 60nm_PS_PEG_cortex_vid_1_1_0_0

# %%
for name in names:
    outfile = 'Traj_' + name.split('.')[0] + '.csv'
    local_im = op.join(local_folder, name)
    
    row = int(name.split('.')[0].split('_')[7])
    col = int(name.split('.')[0].split('_')[8])

#     try:
#         aws.download_s3(remote_folder+'/'+outfile, outfile)
#     except:
    test_intensity = ij.mean_intensity(local_im)
    quality = 2.81
        
    if row==3:
        y = 485
    else:
        y = 510

    ij.track(local_im, outfile, template=None, radius=3.5, threshold=0., 
          do_median_filtering=True, quality=quality, x=511, y=y, ylo=1, median_intensity=300.0, snr=0.0, 
          linking_max_distance=10.0, gap_closing_max_distance=8.0, max_frame_gap=2,
          track_displacement=10.0)

    # aws.upload_s3(outfile, remote_folder+'/'+outfile)
    print("Done with tracking.  Should output file of name {}".format(local_folder+'/'+outfile))
# Out:
# /Applications/Fiji.app/Contents/MacOS/ImageJ-macosx --ij2 --headless --run /var/folders/bq/82bsdg792tz2kq2c1b32j7zm0000gn/T/tmprb5xd0jq.py
# Done with tracking.  Should output file of name /Volumes/McKenna_Mac_Partition/Confocal_Data/MPT/5_8_18_mGluR5_HET_60nm_PS_PEG/section_1//Traj_60nm_PS_PEG_thalamus_vid_1_5_0_0.csv
# /Applications/Fiji.app/Contents/MacOS/ImageJ-macosx --ij2 --headless --run /var/folders/bq/82bsdg792tz2kq2c1b32j7zm0000gn/T/tmp77w907iv.py
# Done with tracking.  Should output file of name /Volumes/McKenna_Mac_Partition/Confocal_Data/MPT/5_8_18_mGluR5_HET_60nm_PS_PEG/section_1//Traj_60nm_PS_PEG_thalamus_vid_1_5_0_1.csv
# /Applications/Fiji.app/Contents/MacOS/ImageJ-macosx --ij2 --headless --run /var/folders/bq/82bsdg792tz2kq2c1b32j7zm0000gn/T/tmp883nfpvt.py
# Done with tracking.  Should output file of name /Volumes/McKenna_Mac_Partition/Confocal_Data/MPT/5_8_18_mGluR5_HET_60nm_PS_PEG/section_1//Traj_60nm_PS_PEG_thalamus_vid_1_5_0_2.csv
# /Applications/Fiji.app/Contents/MacOS/ImageJ-macosx --ij2 --headless --run /var/folders/bq/82bsdg792tz2kq2c1b32j7zm0000gn/T/tmpldziixgj.py
# Done with tracking.  Should output file of name /Volumes/McKenna_Mac_Partition/Confocal_Data/MPT/5_8_18_mGluR5_HET_60nm_PS_PEG/section_1//Traj_60nm_PS_PEG_thalamus_vid_1_5_0_3.csv
# /Applications/Fiji.app/Contents/MacOS/ImageJ-macosx --ij2 --headless --run /var/folders/bq/82bsdg792tz2kq2c1b32j7zm0000gn/T/tmphj5cbwct.py
# Done with tracking.  Should output file of name /Volumes/McKenna_Mac_Partition/Confocal_Data/MPT/5_8_18_mGluR5_HET_60nm_PS_PEG/section_1//Traj_60nm_PS_PEG_thalamus_vid_1_5_1_0.csv
# /Applications/Fiji.app/Contents/MacOS/ImageJ-macosx --ij2 --headless --run /var/folders/bq/82bsdg792tz2kq2c1b32j7zm0000gn/T/tmphit77_rr.py
# Done with tracking.  Should output file of name /Volumes/McKenna_Mac_Partition/Confocal_Data/MPT/5_8_18_mGluR5_HET_60nm_PS_PEG/section_1//Traj_60nm_PS_PEG_thalamus_vid_1_5_1_1.csv
# /Applications/Fiji.app/Contents/MacOS/ImageJ-macosx --ij2 --headless --run /var/folders/bq/82bsdg792tz2kq2c1b32j7zm0000gn/T/tmp5k1j36aw.py
# Done with tracking.  Should output file of name /Volumes/McKenna_Mac_Partition/Confocal_Data/MPT/5_8_18_mGluR5_HET_60nm_PS_PEG/section_1//Traj_60nm_PS_PEG_thalamus_vid_1_5_1_2.csv
# /Applications/Fiji.app/Contents/MacOS/ImageJ-macosx --ij2 --headless --run /var/folders/bq/82bsdg792tz2kq2c1b32j7zm0000gn/T/tmpgn8fhp8j.py
# Done with tracking.  Should output file of name /Volumes/McKenna_Mac_Partition/Confocal_Data/MPT/5_8_18_mGluR5_HET_60nm_PS_PEG/section_1//Traj_60nm_PS_PEG_thalamus_vid_1_5_1_3.csv
# /Applications/Fiji.app/Contents/MacOS/ImageJ-macosx --ij2 --headless --run /var/folders/bq/82bsdg792tz2kq2c1b32j7zm0000gn/T/tmponuro7k_.py
# Done with tracking.  Should output file of name /Volumes/McKenna_Mac_Partition/Confocal_Data/MPT/5_8_18_mGluR5_HET_60nm_PS_PEG/section_1//Traj_60nm_PS_PEG_thalamus_vid_1_5_2_0.csv
# /Applications/Fiji.app/Contents/MacOS/ImageJ-macosx --ij2 --headless --run /var/folders/bq/82bsdg792tz2kq2c1b32j7zm0000gn/T/tmpn594rurf.py
# Done with tracking.  Should output file of name /Volumes/McKenna_Mac_Partition/Confocal_Data/MPT/5_8_18_mGluR5_HET_60nm_PS_PEG/section_1//Traj_60nm_PS_PEG_thalamus_vid_1_5_2_1.csv
# /Applications/Fiji.app/Contents/MacOS/ImageJ-macosx --ij2 --headless --run /var/folders/bq/82bsdg792tz2kq2c1b32j7zm0000gn/T/tmpqlnu_8ov.py
# Done with tracking.  Should output file of name /Volumes/McKenna_Mac_Partition/Confocal_Data/MPT/5_8_18_mGluR5_HET_60nm_PS_PEG/section_1//Traj_60nm_PS_PEG_thalamus_vid_1_5_2_2.csv
# /Applications/Fiji.app/Contents/MacOS/ImageJ-macosx --ij2 --headless --run /var/folders/bq/82bsdg792tz2kq2c1b32j7zm0000gn/T/tmpfd_lm87z.py
# Done with tracking.  Should output file of name /Volumes/McKenna_Mac_Partition/Confocal_Data/MPT/5_8_18_mGluR5_HET_60nm_PS_PEG/section_1//Traj_60nm_PS_PEG_thalamus_vid_1_5_2_3.csv
# /Applications/Fiji.app/Contents/MacOS/ImageJ-macosx --ij2 --headless --run /var/folders/bq/82bsdg792tz2kq2c1b32j7zm0000gn/T/tmplik6moey.py
# Done with tracking.  Should output file of name /Volumes/McKenna_Mac_Partition/Confocal_Data/MPT/5_8_18_mGluR5_HET_60nm_PS_PEG/section_1//Traj_60nm_PS_PEG_thalamus_vid_1_5_3_0.csv
# /Applications/Fiji.app/Contents/MacOS/ImageJ-macosx --ij2 --headless --run /var/folders/bq/82bsdg792tz2kq2c1b32j7zm0000gn/T/tmpg6jrvx2j.py
# Done with tracking.  Should output file of name /Volumes/McKenna_Mac_Partition/Confocal_Data/MPT/5_8_18_mGluR5_HET_60nm_PS_PEG/section_1//Traj_60nm_PS_PEG_thalamus_vid_1_5_3_1.csv
# /Applications/Fiji.app/Contents/MacOS/ImageJ-macosx --ij2 --headless --run /var/folders/bq/82bsdg792tz2kq2c1b32j7zm0000gn/T/tmpbk2hzxuu.py
# Done with tracking.  Should output file of name /Volumes/McKenna_Mac_Partition/Confocal_Data/MPT/5_8_18_mGluR5_HET_60nm_PS_PEG/section_1//Traj_60nm_PS_PEG_thalamus_vid_1_5_3_2.csv
# /Applications/Fiji.app/Contents/MacOS/ImageJ-macosx --ij2 --headless --run /var/folders/bq/82bsdg792tz2kq2c1b32j7zm0000gn/T/tmptsmb5og4.py
# Done with tracking.  Should output file of name /Volumes/McKenna_Mac_Partition/Confocal_Data/MPT/5_8_18_mGluR5_HET_60nm_PS_PEG/section_1//Traj_60nm_PS_PEG_thalamus_vid_1_5_3_3.csv

# %% [markdown]
# # Calculating MSDs and Features

# %%
#msd.all_msds2?

# %%
#filename = "Traj_{}_{}_{}.csv".format(prefix, row, col)
#local_name = local_folder+'/'+filename

#merged = msd.all_msds2(ut.csv_to_pd(local_name), frames=frames)

# %%
# merged

# %%
# merged_ft = ft.calculated_features(merged)

# %%
# merged_ft

# %%
print(prefix)
print(names)
# Out:
# 60_nm_PS_PEG_in_hippocampus_vid_1_2
# ['60_nm_PS_PEG_in_hippocampus_vid_1_2_0_0.tif', '60_nm_PS_PEG_in_hippocampus_vid_1_2_0_1.tif', '60_nm_PS_PEG_in_hippocampus_vid_1_2_0_2.tif', '60_nm_PS_PEG_in_hippocampus_vid_1_2_0_3.tif', '60_nm_PS_PEG_in_hippocampus_vid_1_2_1_0.tif', '60_nm_PS_PEG_in_hippocampus_vid_1_2_1_1.tif', '60_nm_PS_PEG_in_hippocampus_vid_1_2_1_2.tif', '60_nm_PS_PEG_in_hippocampus_vid_1_2_1_3.tif', '60_nm_PS_PEG_in_hippocampus_vid_1_2_2_0.tif', '60_nm_PS_PEG_in_hippocampus_vid_1_2_2_1.tif', '60_nm_PS_PEG_in_hippocampus_vid_1_2_2_2.tif', '60_nm_PS_PEG_in_hippocampus_vid_1_2_2_3.tif', '60_nm_PS_PEG_in_hippocampus_vid_1_2_3_0.tif', '60_nm_PS_PEG_in_hippocampus_vid_1_2_3_1.tif', '60_nm_PS_PEG_in_hippocampus_vid_1_2_3_2.tif', '60_nm_PS_PEG_in_hippocampus_vid_1_2_3_3.tif']

# %%
names[0].split('.')[0].split('_')
# Out:
# ['60nm', 'PS', 'PEG', 'cortex', 'vid', '1', '1', '0', '0']

# %%
msd_file = 'msd_{}.csv'.format(prefix)
ft_file = 'features_{}.csv'.format(prefix)
local_folder = os.getcwd()

counter = 0
for name in names:
    row = int(name.split('.')[0].split('_')[7])
    col = int(name.split('.')[0].split('_')[8])

    filename = "Traj_{}_{}_{}.csv".format(prefix, row, col)
    local_name = local_folder+'/'+filename

    if counter == 0:
        to_add = ut.csv_to_pd(local_name)
        to_add['X'] = to_add['X'] + ires*col
        to_add['Y'] = ires - to_add['Y'] + ires*(3-row)
        merged = msd.all_msds2(to_add, frames=frames)
    else: 

        if merged.shape[0] > 0:
            to_add = ut.csv_to_pd(local_name)
            to_add['X'] = to_add['X'] + ires*col
            to_add['Y'] = ires - to_add['Y'] + ires*(3-row)
            to_add['Track_ID'] = to_add['Track_ID'] + max(merged['Track_ID']) + 1
        else:
            to_add = ut.csv_to_pd(local_name)
            to_add['X'] = to_add['X'] + ires*col
            to_add['Y'] = ires - to_add['Y'] + ires*(3-row)
            to_add['Track_ID'] = to_add['Track_ID']

        merged = merged.append(msd.all_msds2(to_add, frames=frames))
        print('Done calculating MSDs for row {} and col {}'.format(row, col))
    counter = counter + 1

merged.to_csv(msd_file)
#aws.upload_s3(msd_file, remote_folder+'/'+msd_file)
merged_ft = ft.calculate_features(merged)
merged_ft.to_csv(ft_file)
#aws.upload_s3(ft_file, remote_folder+'/'+ft_file)
# Out:
# Done calculating MSDs for row 0 and col 1
# Done calculating MSDs for row 0 and col 2
# Done calculating MSDs for row 0 and col 3
# Done calculating MSDs for row 1 and col 0
# Done calculating MSDs for row 1 and col 1
# Done calculating MSDs for row 1 and col 2
# Done calculating MSDs for row 1 and col 3
# Done calculating MSDs for row 2 and col 0
# Done calculating MSDs for row 2 and col 1
# Done calculating MSDs for row 2 and col 2
# Done calculating MSDs for row 2 and col 3
# Done calculating MSDs for row 3 and col 0
# Done calculating MSDs for row 3 and col 1
# Done calculating MSDs for row 3 and col 2
# Done calculating MSDs for row 3 and col 3
# Optimal parameters not found. Print NaN instead.

# %%
# delete once I'm done, trying to run this on a single crop of a vid
msd_file = 'msd_{}.csv'.format(prefix)
ft_file = 'features_{}.csv'.format(prefix)
local_folder = os.getcwd()

#counter = 0
#for name in names:
#    row = int(name.split('.')[0].split('_')[14])
#    col = int(name.split('.')[0].split('_')[15])

    #filename = "Traj_{}_{}_{}.csv".format(prefix, row, col)
filename = "Traj_{}.csv".format(prefix)
    #local_name = local_folder+'/'+filename
local_name = local_folder+'/'+filename
to_add = ut.csv_to_pd(local_name)
merged = msd.all_msds(to_add)
    #if counter == 0:
    #    to_add = ut.csv_to_pd(local_name)
    #    to_add['X'] = to_add['X'] + ires*col
    #    to_add['Y'] = ires - to_add['Y'] + ires*(3-row)
    #    merged = msd.all_msds2(to_add, frames=frames)
    #else: 

    #    if merged.shape[0] > 0:
    #        to_add = ut.csv_to_pd(local_name)
    #        to_add['X'] = to_add['X'] + ires*col
    #        to_add['Y'] = ires - to_add['Y'] + ires*(3-row)
    #        to_add['Track_ID'] = to_add['Track_ID'] + max(merged['Track_ID']) + 1
    #    else:
    #        to_add = ut.csv_to_pd(local_name)
    #        to_add['X'] = to_add['X'] + ires*col
    #        to_add['Y'] = ires - to_add['Y'] + ires*(3-row)
    #        to_add['Track_ID'] = to_add['Track_ID']

    #    merged = merged.append(msd.all_msds2(to_add, frames=frames))
    #    print('Done calculating MSDs for row {} and col {}'.format(row, col))
    #counter = counter + 1

merged.to_csv(msd_file)
#aws.upload_s3(msd_file, remote_folder+'/'+msd_file)
merged_ft = ft.calculate_features(merged)
merged_ft.to_csv(ft_file)
#aws.upload_s3(ft_file, remote_folder+'/'+ft_file)

# %% [markdown]
# # Trajectory Visualization

# %%
print(prefix)
os.chdir(local_folder)
print(os.getcwd())
# Out:
# 60nm_PS_PEG_hippocampus_vid_1_1
# /Volumes/McKenna_Mac_Partition/Confocal_Data/MPT/5_8_18_mGluR5_HET_60nm_PS_PEG/section_1

# %%
merged = pd.read_csv('msd_{}.csv'.format(prefix))
merged_ft = pd.read_csv('features_{}.csv'.format(prefix))

# %%
hm_mm.plot_trajectories(prefix, resolution=512, rows=4,cols=4, upload=False)

# %%
feature = 'D_fit'
hm_mm.plot_heatmap(prefix, feature=feature, vmin=merged_ft[feature].quantile(0.1), vmax=merged_ft[feature].quantile(0.9), upload=False)

# %%
hm.plot_trajectories(prefix, upload=False)
# Out:
# Plotted 60nm_PS_PEG_hippocampus_vid_1_1 trajectories successfully.

# %%
hm.plot_individual_msds(prefix,x_range=40,y_range=5,umppx=0.16,fps=99.93,alpha=0.05,upload=False)
# Out:
# /Users/mike_mckenna/Downloads/Users/mike_mckenna/Desktop/lib/python3.5/site-packages/numpy/ma/core.py:827: RuntimeWarning: invalid value encountered in less_equal
#   return umath.less_equal(x, self.critical_value)
# /Users/mike_mckenna/Downloads/Users/mike_mckenna/Desktop/lib/python3.5/site-packages/numpy/ma/core.py:827: RuntimeWarning: invalid value encountered in less_equal
#   return umath.less_equal(x, self.critical_value)
# (masked_array(data = [-- -3.2777297217323667 -2.9682312676249816 -2.830092017394446
#   -2.7370329984708905 -2.671371817112988 -2.637473164803929
#   -2.592901445645463 -2.5537924563141527 -2.529271377737184
#   -2.536494229497572 -2.48231093741431 -2.501829759679562
#   -2.4908481153472084 -2.494268757756362 -2.5094454580667036
#   -2.440439810333189 -2.456550836656986 -2.470363427988202
#   -2.5005704569886267 -2.446992205816382 -2.4478665949761425
#   -2.4383183810858937 -2.4381856441316967 -2.4331490353069922
#   -2.47003404245183 -2.4185746763163545 -2.412115788770469 -2.47402181759693
#   -2.4542163488071784 -2.4751421460949388 -2.4079121523696077
#   -2.407289606806355 -2.418833269091332 -2.389967940093752
#   -2.309729884140687 -2.2662432412940374 -2.2605641851366025
#   -2.24170691675386 -2.2043386506929754 -2.170656667269129
#   -2.1891161295109383 -2.195350251463489 -2.1281332509615294
#   -2.1085469967033514 -2.1294260071265687 -2.1045599054430766
#   -2.125657202187083 -2.1341264238466358 -2.1424291511537614
#   -2.1450906748588987 -2.156257857131001 -2.1306577929159958
#   -2.089509311338466 -2.082576709817725 -2.1280730910705463
#   -2.1258564244299896 -2.090397397391849 -2.104778931553208
#   -2.112663528093359 -2.1211333867760644 -2.1907328027672586
#   -2.2269910417230876 -2.206005646134888 -2.1310825066722585
#   -2.0983246790934316 -2.1228250593783984 -2.1170155917578426
#   -2.1320741804480208 -2.1092656845782476 -2.0984821402496303
#   -2.0950301157962308 -2.064999112079503 -2.0409601159943933
#   -2.011363785561341 -2.027572536997293 -2.04397023344186
#   -2.0578641950515495 -2.0797058102173724 -2.1213750715076363
#   -2.1160346901256437 -2.0995606984099346 -2.0990199450166913
#   -2.0917610651084466 -2.110978143142273 -2.0961983706449643
#   -2.094843249502713 -2.089309362332369 -2.1218704969133184
#   -2.1167497013883123 -2.110385323710984 -2.1283372205330697
#   -2.10473440580396 -2.1498418666773085 -2.1424517331411415
#   -2.182468489553734 -2.14411948697583 -2.1357793497431103
#   -2.1292244195200993 -2.1181609172116596 -2.110816412708354
#   -2.1134156701254185 -2.125465063268138 -2.0878515973380574
#   -2.0679283623103797 -2.093690523970838 -2.0957108292058866
#   -2.090058815298556 -2.0685490722895787 -2.1328637939535664
#   -2.107459470874111 -2.0798183332938764 -2.0931663944946792
#   -2.0855846555285553 -2.049166634969903 -2.044778073968948
#   -2.0348662921079343 -2.0684046678655896 -2.0710504821882716
#   -2.1156002666684537 -2.1181198732626845 -2.1188518498620645
#   -2.1093237150590856 -2.0895237813031 -2.1079635939238393
#   -2.143474358961066 -2.131089909892799 -2.1524006867091976
#   -2.1419285842438165 -2.1325187502671312 -2.125936146244415
#   -2.125868233438898 -2.113070544806323 -2.106926669214747
#   -2.1275626868025213 -2.092331049060172 -2.082188354304363
#   -2.114750574948831 -2.1265344241056985 -2.126722877993458
#   -2.05940268812394 -2.0902410400644524 -2.1513421054240043
#   -2.1037827054052802 -2.108574093595284 -2.1019401486244114
#   -2.1018522739132206 -2.156250429917982 -2.16781159871405
#   -2.1364779388835604 -2.147706638716235 -2.177563711191959
#   -2.1554621447848215 -2.151889369221931 -2.2061854846876607
#   -2.114243785101084 -2.1050729336868756 -2.1372448259539225
#   -2.1267401731478266 -2.1124362334903806 -2.11783848177899
#   -2.1037139919315684 -2.0794693835189557 -2.068591412279229
#   -2.0624896061638434 -2.082490599693309 -2.1134963193207725
#   -2.048777347657233 -2.065535564474342 -2.0635620090588245
#   -2.058294821526773 -2.046235453194154 -2.0464448989039865
#   -2.032640563290515 -2.0351951377305197 -2.0164075019606393
#   -2.0215172901432585 -2.0151769860255047 -2.0089554959900333
#   -2.0096803120017084 -1.9873032267339499 -1.9734983784487805
#   -1.9313758024252592 -1.9097944864073522 -1.8974438537073928
#   -1.8931876961269154 -1.8880009387754555 -1.8773137501958286
#   -1.871891239970085 -1.8676168760752638 -1.871583971549712
#   -1.8502335693558993 -1.8245049746885174 -1.8248214938214236
#   -1.8154152616592212 -1.8318135320332731 -1.8064122716054722
#   -1.8059219075152069 -1.7842600941873445 -1.7275644817406477
#   -1.7354575644071186 -1.7273641824151258 -1.7191295757774514
#   -1.7200121444232586 -1.7183373811873628 -1.715918627928442
#   -1.7114291473379437 -1.7102931020417858 -1.7154374619526387
#   -1.7088006651857366 -1.791431857501887 -1.7782110465690744
#   -1.7635765644972698 -1.7708987538662837 -1.7636894293649972
#   -1.7557245552656504 -1.750567135693843 -1.7435591640766679
#   -1.7358191417960378 -1.7265215145655142 -1.7183284291175747
#   -1.710471529756204 -1.7125655644295255 -1.7236919684640957
#   -1.7184976608567426 -1.7533393446457088 -1.7652321077977866
#   -1.7874469648875895 -1.8147678297626615 -1.8103592688197847
#   -1.7789383671502093 -1.8033175333638118 -1.6896309163115943
#   -1.687198251758603 -1.6763016048701689 -1.6701581918453379
#   -1.6698201790367768 -1.6788101322250184 -1.6759001826681021
#   -1.66570395925039 -1.672352809460992 -1.6786880618133195
#   -1.6720540458268587 -1.6555747486919612 -1.6379886671810744
#   -1.6388481789527698 -1.6340120801490718 -1.630184707579017
#   -1.6375878233129806 -1.6336840496047762 -1.6508362179433218
#   -1.693910506065375 -1.6848771939850267 -1.6875759368330543
#   -1.6812277879245041 -1.6758834695706097 -1.6730443833928215
#   -1.6706902949969316 -1.6631929851353005 -1.6638044221039627
#   -1.6692697907750453 -1.687776461049678 -1.686209790185708
#   -1.7723588684704856 -1.7704054434382508 -1.7653166059786551
#   -1.7619964376470236 -1.7557660893186238 -1.7539818261779168
#   -1.7546336134232439 -1.7446090980750404 -1.732636496300026
#   -1.725236250150167 -1.7261547767076195 -1.7189671502370327
#   -1.7164577672351136 -1.7062494118785823 -1.6964530299615908
#   -1.689889175776715 -1.6848943744743596 -1.6811013914104345
#   -1.7852482748909047 -1.7750494797445497 -1.773805664218519
#   -1.7660978559553464 -1.7673787707241446 -1.7631344688166528
#   -1.7523260116442538 -1.74789307484146 -1.7513271642624333
#   -1.7605100232968296 -1.7595185081081621 -1.7625449755465177
#   -1.7566116363766013 -1.74845713638047 -1.7411230169355754
#   -1.72771447901704 -1.7707918648944974 -1.7700975049079957
#   -1.7729433602682223 -1.7603989931166544 -1.7576759076643795
#   -1.7570647981830314 -1.7671729071256181 -1.7595660463129432
#   -1.7468741728988113 -1.7441321595156303 -1.747102683020316
#   -1.7643787024286326 -1.7981767692394706 -1.7747703147886882
#   -1.7903683136799615 -1.8213070927396995 -1.8132873006703494
#   -1.811762620591971 -1.8087619085116948 -1.809529953929823
#   -1.8032738841360771 -1.7986720387116315 -1.7938819194487792
#   -1.79823646172107 -1.7992382245479923 -1.7900619527446384
#   -1.7861412322682864 -1.7659257373942758 -1.7483626282482414
#   -1.7431125070653 -1.7394895797154633 -1.7371065005595636
#   -1.7306933445122752 -1.7260828290851664 -1.72026303748061
#   -1.7164912446727059 -1.7140506540726763 -1.7071464521199529
#   -1.7053300395211692 -1.6933539076285216 -1.6881386116810448
#   -1.6865593927016802 -1.6800493688707794 -1.6952517292895712
#   -1.7160055833436898 -1.8598685097480072 -1.8572907746526819
#   -1.8518206450650059 -1.8551961033681004 -1.8566486893046985
#   -1.8487154508615098 -1.8485078858693316 -1.843153462726995
#   -1.841917499131604 -1.842169974401599 -1.837615257352114
#   -1.8324118477839337 -1.824614741511868 -1.8168552267792193
#   -1.8197037944249739 -1.8191465347149216 -1.8061268891330755
#   -1.8033987600724843 -1.7987474179693455 -1.7933464394348566
#   -1.7906214893567867 -1.7933677945558788 -1.7861330153857606
#   -1.7844793155858425 -1.7721284803834771 -1.767283466979785
#   -1.7604753996007378 -1.751761797943168 -1.7517335107682188
#   -1.744369011055026 -1.7375126671782133 -1.730529283012865
#   -1.7245230112755534 -1.7287132317376381 -1.7249870783472296
#   -1.7153520552643433 -1.7203802838281068 -1.7119629615307388
#   -1.7068836555383688 -1.7051510699504222 -1.6970608891805312
#   -1.6967558485814513 -1.6931582111750512 -1.6907229244805448
#   -1.6786502251156161 -1.6771857264383758 -1.6780713950689707
#   -1.6694621932227247 -1.6700881767956905 -1.672459733154514
#   -1.6716742228269228 -1.6645105300862477 -1.6685669913346657
#   -1.6574487241960771 -1.6512083007283842 -1.6526945677964469
#   -1.6544702516190641 -1.6449003177703905 -1.6433743635331826
#   -1.6425363986760133 -1.641623599709774 -1.644177647068537
#   -1.6401206060612423 -1.6422773689743577 -1.6423194286936764
#   -1.6369908732368799 -1.6339027593750919 -1.617234647065196
#   -1.621164252629886 -1.6201892623651124 -1.607695836471101
#   -1.6060041998639392 -1.59358167254458 -1.5843492803896149
#   -1.5675621258533698 -1.5318351264798764 -1.6676113788043985
#   -1.664611775464082 -1.6640980344146528 -1.6588827620798157
#   -1.6524712088701554 -1.649011926312149 -1.6474667809981476
#   -1.6577109079724028 -1.8170399713481609 -1.8131275120187444
#   -1.8155931265249052 -1.8126630242892658 -1.8106623339165064
#   -1.8062877443015408 -1.7999737478781603 -1.796897462523236
#   -1.7923925214365792 -1.7906721862001556 -1.7885289219390443
#   -1.7906780189874376 -1.7886239551498737 -1.789449979262295
#   -1.7870415436799094 -1.7926572992813352 -1.7903864551361794
#   -1.7899279955440746 -1.7840705112161908 -1.7823995148918008
#   -1.7816826400781904 -1.7818823421851886 -1.7785879904333475
#   -1.9283882317293977 -1.9407540158628052 -1.9445755519151924
#   -1.944197877336445 -1.9394193186579327 -1.9270704698303898
#   -1.9263998352808258 -1.9299300777416175 -1.9289270287563547
#   -1.9437608060365401 -2.03700011525884 -2.033634233136021
#   -2.036300642315916 -2.035702935484761 -2.0348720293997564
#   -2.031100837236947 -2.03827113252656 -2.0320633139081568
#   -2.029964815708377 -2.0259972761570233 -2.0300982080943215
#   -2.0222465283097675 -2.0193126853585763 -2.01825436201872
#   -2.013287176038115 -2.008502316824755 -2.0035388408087966
#   -2.0002462465362183 -2.0084296128815207 -1.9965669037073976
#   -2.0027840354579163 -1.9952577580601936 -1.9925880415895156
#   -1.981415743924462 -1.9892443879984423 -1.9766295712492286
#   -1.974243422427778 -1.962435294392742 -1.9616553922827156
#   -1.9542050448352641 -1.9546560423725172 -1.9492313886808437
#   -1.9496088092709687 -1.9387246849173252 -1.9344656208667093
#   -1.9244434947840394 -1.9206446097535765 -1.9078550882843186
#   -1.9057085486912275 -1.8991932630124 -1.8998661298938602
#   -1.8905412483845216 -1.8786000028839995 -1.8659906921769693
#   -1.8698567140523499 -1.8536661044841405 -1.8501659947969975
#   -1.8526487601984074 -1.8538932615326686 -1.8457974933752643
#   -1.8397708549111043 -1.8428374252782525 -1.8408074025430046
#   -1.8390036468980075 -1.835452178336489 -1.8302964220946067
#   -1.831847063646094 -1.8334127571594425 -1.829246618458249
#   -1.8237140621006647 -1.8270387144656983 -1.8130815410609786
#   -1.8073503484955293 -1.8097977659320748 -1.8202578276888781
#   -1.8000090371954998 -1.949955524017157 -1.9526570338474942
#   -1.9499201782846483 -1.946210490864896 -1.9413143920530602
#   -1.9415037477456385 -1.9394010910330863 -1.9326523849987816
#   -1.9262148571415263 -1.920458628896565 -1.9146608253971202
#   -1.9087675056839923 -1.9064863289615712 -1.9114636334749167
#   -1.9099176920505272 -1.9020653604276088 -1.899244698309628
#   -1.889360000783138 -1.8888926022390369 -1.8848803539003347
#   -1.894231668511223 -1.8846783448052111 -1.8780043762923642
#   -1.8788889363361896 -1.871976026289863 -1.8594854108959795
#   -1.8556897977258717 -1.8534472740723478 -1.8504598904475635
#   -1.851481738078775 -1.8483696870636754 -1.8355054282872008
#   -1.8401981161696541 -1.8430345957956238 -1.8382122935100076
#   -1.8367892920806301 -1.850620222815513 -1.8551599669321919
#   -1.8611179399710451 -1.843311686522487 -1.8433003398844248
#   -1.8530693808896694 -1.8638591098104378 -1.859257315604595
#   -1.8653675812996473 -1.8628733267211677 -1.8672583566537677
#   -1.8533426786743112 -1.8472322148095248 -1.8396114330920366
#   -1.851000903023926 -1.8464357433948662 -1.8478231460860108
#   -1.8603426625513009 -1.8622268651864184 -1.8620374381226252
#   -1.848989836307293 -1.8596103272925164 -1.8590265930208851
#   -1.859828269877539 -1.8575061107487312 -1.865034832190516
#   -1.8666689717147131 -1.8745760060584669 -1.8732509415769016
#   -1.881093679272629 -1.8500417587521198 -1.8635289052487278
#   -1.8721142938408375 -1.9295905699628688 -2.1426497161644447
#   -2.1450478025932225 -2.1382032571582203 -2.148279378680898
#   -2.1528443611954833 -2.14182618012111 -2.1347801349661353
#   -2.145084403451855 -2.122139123760585 -2.12400069610402 -2.119751778184818
#   -2.1248303100528836 -2.0969345850604983 -2.087694930030465
#   -2.133584985868928 -2.0945924164913947 -2.0617031117882054
#   -2.052638053823598 -2.0549812194627757 -2.038320404318464
#   -2.027465195942768 -2.0317483096402764 -2.030663573590009
#   -2.0281395128851587 -2.0099546972267257 -2.0014258253216473
#   -2.001786950203853 -2.0055502633283235 -1.9889354125740053
#   -1.97849379822991 -1.960164113098384 -1.9400961287719187
#   -1.9187470829597142 -1.9165623074516125 -1.885190578904354
#   -1.8949885571245728 -1.8947510786056843 -1.935921253912378
#   -1.9415933808576495 -1.9586267364453676 -1.9790080701762243
#   -1.991077086433948 -2.4585442352946116 -2.4899388388729693
#   -2.5073748241326745 -2.496753659573846 -2.5095378092846694
#   -2.531572768028637 -2.5008696461547175 -2.467339010050428
#   -2.4498475241466124 -2.4358105176215394 -2.3610074406650385
#   -2.491292254813219 -2.7462548190500735],
#               mask = [ True False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False],
#         fill_value = 1e+20),
#  masked_array(data = [0.0 0.026272681059112502 0.02842918565484032 0.030865036619982363
#   0.03258694219414319 0.03365438347546282 0.03520951104566752
#   0.03699753438466282 0.03773211109801231 0.039287541448347174
#   0.041324595689289055 0.04274134411596278 0.046818144058527786
#   0.050005335752580655 0.049587634952605854 0.053096857401115756
#   0.05423257758848159 0.057252681533341676 0.05801719841680154
#   0.05940499256733316 0.05941026401417083 0.06320784977946355
#   0.06275099361362164 0.06421440250052467 0.06346527947150518
#   0.06880470478474572 0.06816783963180008 0.06863473493620952
#   0.07760577869840928 0.07608938975775278 0.07908653093888687
#   0.08204997608048187 0.0837472697122594 0.08908340081134146
#   0.08874228467802585 0.08931889771567972 0.09247246663381209
#   0.0986349878332796 0.10063493182429845 0.09422361939280763
#   0.09475322017812016 0.0988194593295018 0.10358607009290174
#   0.10074165235783297 0.1036709067368319 0.10892155659049342
#   0.10740152950950073 0.10912055154654246 0.10811628976241004
#   0.1116997244380548 0.1136246612687841 0.11927842687591217
#   0.11868738582717678 0.11900300374035881 0.11647186117970312
#   0.11784991066195118 0.11831810346424217 0.11754997446955585
#   0.1235920996368607 0.1265788287965424 0.1271834183110199
#   0.13062849410708957 0.14093810204033055 0.13958734024288827
#   0.13668393426709893 0.13833388226562882 0.14042322522199355
#   0.13597697295551175 0.13798616051109436 0.1453123082343657
#   0.14500217439637247 0.14722813467929852 0.14540246991688074
#   0.14877861068588621 0.14771632610696567 0.15018220260039492
#   0.15217325341602803 0.1562847556115565 0.16042705924167303
#   0.15808630720646383 0.15884122401283896 0.1576746221336639
#   0.15896944496104568 0.158863535449964 0.15988708217058414
#   0.16052653977748163 0.15698346744367286 0.1580919594450764
#   0.15885383878346518 0.15812737542903504 0.1581187031507319
#   0.1608173271319401 0.1619485697530678 0.16547953929055909
#   0.169599782555427 0.16757279342851533 0.1675683029221835
#   0.16940350608378202 0.17107114596419656 0.17124424827990184
#   0.17021897258554824 0.17444729312001825 0.18141354111580266
#   0.17283011189304787 0.17690264461174163 0.176817949156694
#   0.178535957496644 0.17985474247365243 0.18214719536331975
#   0.18404127459814063 0.179998539886161 0.18103240600235676
#   0.1799333815895625 0.1804192149493538 0.18482369034947532
#   0.18604414418956092 0.18886040776492302 0.18774836694870267
#   0.18814184649886556 0.1910466108249309 0.19066286324125328
#   0.19375566616315595 0.19497168627988878 0.20080855385215224
#   0.19987184142639622 0.20505504670903257 0.20317668149341891
#   0.20557444505336653 0.20446634759181956 0.20518734783409256
#   0.204843142514376 0.20509628203449196 0.20284222770643243
#   0.20171071697892692 0.20432433860870813 0.20013900764996634
#   0.2007371348202161 0.20700444222097264 0.20789381287978786
#   0.20817700507029185 0.2046674903880194 0.20469694482937348
#   0.21278793981047056 0.21231634714790912 0.21473347958714276
#   0.21732021708299745 0.22031790413347957 0.20970869394697342
#   0.21160897143679563 0.20779882404619585 0.2095422427023661
#   0.21451972532495997 0.20896352217802086 0.20747410230366903
#   0.22048080903113781 0.21056588804357473 0.20951316038711676
#   0.214115143284021 0.21081930006591093 0.21143949899858042
#   0.20956107942587798 0.20811559163749066 0.20683774246092065
#   0.20731780701332994 0.2088155587437276 0.21114349108067076
#   0.21675983309419927 0.22111423286430473 0.22211842835953005
#   0.22331563455884662 0.2298279700705024 0.2292147445584254
#   0.22981017259572412 0.2286481845798155 0.23004812121884677
#   0.22891848734473913 0.2296373162107596 0.22877684474017515
#   0.22865929945302862 0.22717923501343032 0.2339226703274261
#   0.23380896919642202 0.2298470675432367 0.2353089224656361
#   0.2353088198755066 0.23598097390145065 0.23626745340291824
#   0.235836500169077 0.23660958326201356 0.2369983592346806
#   0.23806841548043403 0.23725854413838288 0.23730635039058082
#   0.2377666221736405 0.24467042133106298 0.24844387963751666
#   0.2464627362333599 0.24861896502923936 0.24766801263064875
#   0.24644174551045 0.26915554673123 0.27069751371544953 0.27078349362368453
#   0.2722628798056066 0.2733908094098941 0.2743077828002272
#   0.2759294860414323 0.2769433464492621 0.2787895196680556
#   0.2791753199011433 0.2753367905536996 0.27507517202647286
#   0.2747664240633472 0.2762773749252173 0.274835707350187 0.2745835138180519
#   0.27423158450291024 0.2735979244418412 0.2728976340974705
#   0.2726864039627865 0.27236224322394753 0.2724315428513956
#   0.2729455941309006 0.2721227296065654 0.2734186338116042
#   0.2789881098774883 0.27858099338213455 0.27961970645305684
#   0.28433699561993775 0.2854617885284012 0.2826061865202688
#   0.2899372320984917 0.3006690415993869 0.300984205470442 0.3025403520709113
#   0.30256045088414346 0.3038382779798442 0.30467272853563754
#   0.30664800877454695 0.30723757865579154 0.30878943603822984
#   0.3211340426660256 0.32209326185067894 0.32147964494295433
#   0.3335450403841679 0.33311893462690445 0.3313285718239125
#   0.3310862411564922 0.33010481450222323 0.32652946392563076
#   0.3240214200071379 0.3330004022402363 0.333063821158894
#   0.33368948366667667 0.33341624232155354 0.3321887322118112
#   0.33222997329932524 0.3316060037957719 0.3337993918772802
#   0.33251356954470773 0.3315352620150197 0.3231627591815005
#   0.3223513105677128 0.32418252480071585 0.32472858757651374
#   0.3242899272398239 0.32430396836545183 0.3247167780880322
#   0.32522993817374535 0.326263182439233 0.32580913406593137
#   0.3248413079551798 0.32484891898397694 0.32584891249815456
#   0.32410576438232314 0.32509872738292145 0.32414468864486273
#   0.3227822256022526 0.3223898291404962 0.32229435492623143
#   0.32111208721657847 0.3164038289908216 0.3164999809962234
#   0.3171289595446971 0.3153323286987171 0.31604741699031275
#   0.31542680981370186 0.3156511481324557 0.31612142401157733
#   0.31399730012958954 0.31317509637051594 0.311117452513616
#   0.3119299403720177 0.3129978314892146 0.3125245023225125
#   0.31270651968307184 0.3123318410583472 0.3241795485132058
#   0.32351062072155756 0.324028923155409 0.3244617804829023
#   0.3233790094669306 0.32385274017959087 0.324301558931042
#   0.32452482198636096 0.32428862797555097 0.32451250576850377
#   0.32375128687116334 0.3207017688701502 0.31799422626777996
#   0.31966031897986363 0.3334149556631698 0.3479270774538953
#   0.3470048783073586 0.34676343551447125 0.3471220952096618
#   0.3474294248702799 0.34712614420830595 0.34669735493425935
#   0.3479599651601974 0.34854497905022547 0.34935018477432433
#   0.34942800381967953 0.34937652955628196 0.34784804599454744
#   0.3658101904314386 0.3656553768538987 0.3664979803746615
#   0.36577209780227504 0.3665997222246636 0.36551339645251923
#   0.3652649081019388 0.36479643514063936 0.3649173780832335
#   0.3646627245947303 0.366586175530262 0.3671869715628311
#   0.36693518972851297 0.36667287630742146 0.36846639838296874
#   0.3647980368371694 0.38322024593100285 0.3741057373546204
#   0.3734833711573715 0.37298618376656767 0.374689414619034
#   0.3749544836490299 0.37458247606758127 0.3754143282825459
#   0.37524064405846935 0.3756320809290095 0.3761186171992433
#   0.3758838357088017 0.3754295717290769 0.3749917481699294
#   0.3746789615680115 0.37543592371352597 0.3764696656491728
#   0.3760878682191093 0.3767647719703252 0.3762815375973201
#   0.3759508489681954 0.37640122592458186 0.37727038857114753
#   0.37707200491968995 0.37739210012825186 0.3767955473673994
#   0.37665438528217476 0.37610790900908314 0.37569795190649724
#   0.37605545878689334 0.37588414485841026 0.37635490568598556
#   0.3759116847635581 0.37621323402907175 0.3770762721499732
#   0.37662447237261304 0.3759211272219298 0.3771807049531037
#   0.3772898104581786 0.37671453085939244 0.37691852028382783
#   0.37777245795481695 0.3760581841832031 0.3761807867087773
#   0.3769321042578978 0.3751696250072213 0.37580490409005196
#   0.37685429825557965 0.37507330790026117 0.3762501394084551
#   0.37675306408872483 0.37598304887981154 0.3759332156186276
#   0.37585325567964734 0.3756071305097937 0.37577931167826983
#   0.3741117529184936 0.37524898054943173 0.3743744477691253
#   0.37411601823447765 0.37349230406694894 0.3719825268647683
#   0.37188033527997116 0.3712587798116658 0.3701324851381579
#   0.37055743726868834 0.3684936676172541 0.36966491417666314
#   0.36947177882412247 0.36834564605289727 0.36642073864702734
#   0.3670036474388443 0.3665961220901113 0.3681715368135017
#   0.36712730624427853 0.3708659784570299 0.3813270387033391
#   0.3756732177886237 0.376274168893458 0.3773198177423696
#   0.37717967975338845 0.37489142357705907 0.3754280644890776
#   0.3734769746925784 0.36555031002217786 0.35380065757701346
#   0.35317594147404774 0.3528758418879227 0.3522553555142996
#   0.3516764760182385 0.35269719216859075 0.35369697051394106
#   0.35508462956395764 0.35595059679693625 0.3559031147104736
#   0.354844057296217 0.3555677119138517 0.3562477352935072 0.3550022824591841
#   0.3542221324319669 0.35460167077185817 0.3536367770597249
#   0.35390390678946965 0.3556526381976164 0.3544247687696776
#   0.3577812099008499 0.35980426543345506 0.3608123597136077
#   0.349477968340209 0.34837281304949813 0.34606801160887213
#   0.34449144971597995 0.34927841098362145 0.350393567635804
#   0.34678653223356665 0.34991524050565265 0.35128968483931966
#   0.3407359722618345 0.35563048587989987 0.3551024760306426
#   0.3545925808933643 0.3528897489462556 0.351512654713839 0.3491277844959175
#   0.3505047088543578 0.3488178372787104 0.3473675661156448
#   0.34622767375711355 0.3491766450095027 0.346812719361212
#   0.34596117555077444 0.3464556230119508 0.34706934107883747
#   0.3462903681447333 0.3460897394330646 0.34620055259907784
#   0.3488356975369095 0.3454407102745917 0.34664959679166646
#   0.3473233787527372 0.3460722458255767 0.3453731992791262
#   0.3487011059658144 0.347610748970242 0.3486034320198947
#   0.34625266729176485 0.3478673263843887 0.3474505259888927
#   0.3506073129378263 0.352304222981103 0.35453652671797453
#   0.35404723381502323 0.3556376159877711 0.3543345361551275
#   0.3570827349616887 0.3546667513280488 0.3552651808179751
#   0.35684865498883156 0.36018271832195475 0.36105699932585583
#   0.3608718709849029 0.3583628702254788 0.36219020605651964
#   0.3633366112037066 0.36408773470737654 0.36616918338622756
#   0.3700793338215894 0.3699904064573662 0.37064317001156105
#   0.3710988921955132 0.3733708437338898 0.3718877396654415
#   0.3743189585071766 0.37243383135351754 0.36998498780790207
#   0.37274061181224716 0.3751519309388959 0.3772366992220924
#   0.3768167055606989 0.37809659639100246 0.375058769694532
#   0.3773571969115879 0.3706141053760934 0.37535079557795287
#   0.37733321452565893 0.3779074768996234 0.37886075166242145
#   0.37888194614704235 0.3788183212772146 0.3799792577735406
#   0.3789763866339433 0.379200477370076 0.37956393839313635
#   0.3806508283805641 0.3800836345800658 0.380239551428539 0.3799443382514117
#   0.3828510269601729 0.38278583923712173 0.38198752197338187
#   0.3787044559634746 0.37790503584538887 0.3802469170938394
#   0.3811027750153359 0.38600529156423274 0.3837266775074806
#   0.3794878242136657 0.3815933060105944 0.3794580197600203
#   0.3772030220764379 0.3767124838172468 0.3764213215550408
#   0.3758224773430811 0.3768368124797625 0.3770443997113848
#   0.3709559170085437 0.37483117958757944 0.3770657768881337
#   0.3730237851144808 0.37108704956628524 0.37622666669235016
#   0.3762046651249808 0.38073692595013076 0.375549208383018
#   0.3731613987358442 0.3757643554934528 0.3795207793138059 0.375303786434496
#   0.3761839302799814 0.3740386381219661 0.373194062055563 0.3694436371510717
#   0.36798726089918504 0.36720850208803857 0.3727219291548818
#   0.3673478867031064 0.36664304556063265 0.36408488148924023
#   0.3648913712750489 0.3614865951999497 0.36292934517267006
#   0.36538914176686177 0.36868348657953004 0.37023083411994706
#   0.3739803106105075 0.3777790531156452 0.37884637926999654
#   0.38119642273869314 0.38252466854301814 0.38309061650269666
#   0.3857543421872878 0.39346388448913827 0.4023739442157324
#   0.40507609373690934 0.34878486311194984 0.3494815214744917
#   0.3493966489247519 0.3540139645944938 0.35343925321859115
#   0.3488540602538241 0.35185330464947356 0.3616313431420517
#   0.3580741758014472 0.3615720982189376 0.36993508723945495
#   0.3789168789764772 0.36980321494949064 0.37269831249206437
#   0.3779347894362617 0.37180796721945397 0.36436139711337534
#   0.4133250375224764 0.4151642783287514 0.41528204867376756
#   0.4051725078610681 0.4074290066905463 0.4123447461667256
#   0.4172505022571191 0.408717100807841 0.4107107623506978 0.4137043038098393
#   0.4201981234356981 0.4130847359996081 0.4221930410398391
#   0.42398531825723906 0.42892630354593964 0.4323952385962069
#   0.4442765306091068 0.440611348489166 0.4483891951643637
#   0.45057247836249364 0.465646917048179 0.46659332530025605
#   0.47412672678549117 0.47290240898078334 0.48803231059458824
#   0.29305686231078554 0.31402763353300517 0.3212366237693567
#   0.3000299240702547 0.30177153900876996 0.32448841234327197
#   0.30259805278539303 0.3168997960351711 0.3059870955234532
#   0.3174146750406198 0.34213755896511994 0.48323573066204545
#   0.5849484573038022],
#               mask = [False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False],
#         fill_value = 1e+20))

# %%
# features = ('AR', 'D_fit', 'alpha', 'MSD_ratio', 'Track_ID', 'X', 'Y', 'asymmetry1', 'asymmetry2', 'asymmetry3',
#             'boundedness', 'efficiency', 'elongation', 'fractal_dim', 'frames', 'kurtosis', 'straightness', 'trappedness')

# for feature in features:
#     print('10th percentile of {}: {}'.format(feature, merged_ft[feature].quantile(0.1)))
#     print('90th percentile of {}: {}'.format(feature, merged_ft[feature].quantile(0.9)))
    
#     hm.plot_heatmap(prefix, feature=feature, vmin=merged_ft[feature].quantile(0.1), vmax=merged_ft[feature].quantile(0.9))

# %%
# features = ('AR', 'D_fit', 'alpha', 'MSD_ratio', 'Track_ID', 'X', 'Y', 'asymmetry1', 'asymmetry2', 'asymmetry3',
#             'boundedness', 'efficiency', 'elongation', 'fractal_dim', 'frames', 'kurtosis', 'straightness', 'trappedness')
# vmin = (1.36, 0.015, 0.72, -0.09, 0, 0, 0, 0.5, 0.049, 0.089, 0.0069, 0.65, 0.26, 1.28, 0, 1.66, 0.087, -0.225)
# vmax = (3.98, 2.6, 2.3, 0.015, max(merged_ft['Track_ID']), 2048, 2048, 0.99, 0.415, 0.53, 0.062, 3.44, 0.75, 1.79, 650, 3.33, 0.52, -0.208)

# die = {'features': features,
#        'vmin': vmin,
#        'vmax': vmax}
# di = pd.DataFrame(data=die)

# %%
# for i in range(0, di.shape[0]):
#     hm.plot_heatmap(prefix, feature=di['features'][i], vmin=di['vmin'][i], vmax=di['vmax'][i])
#     hm.plot_scatterplot(prefix, feature=di['features'][i], vmin=di['vmin'][i], vmax=di['vmax'][i])

# %%
feature = 'efficiency'
hm.plot_heatmap(prefix, feature=feature, vmin=merged_ft[feature].quantile(0.1), vmax=merged_ft[feature].quantile(0.9), upload=False)
# Out:
# Plotted 60nm_PS_PEG_hippocampus_vid_1_1 heatmap successfully.

# %%
ft.efficiency?

# %%
# fig, ax = plt.subplots(4, 4, figsize=(14, 14))
# for row in range(0, 2):
#     for col in range(0, 4):
#         subimage = sio.imread('{}_{}_{}.tif'.format(prefix, row, col))
#         ax[row, col].imshow(subimage[650, :, :], cmap='gray', vmin=60, vmax=500)
#         ax[row, col].axis('off')

# %%
hm.plot_scatterplot(prefix)

# %%
hm.plot_histogram(prefix)

# %%
hm.plot_particles_in_frame(prefix)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /Users/mike_mckenna/Downloads/Users/mike_mckenna/Desktop/lib/python3.5/site-packages/boto3/s3/transfer.py in upload_file(self, filename, bucket, key, callback, extra_args)
#     278         try:
# --> 279             future.result()
#     280         # If a client error was raised, add the backwards compatibility layer
#
# /Users/mike_mckenna/Downloads/Users/mike_mckenna/Desktop/lib/python3.5/site-packages/s3transfer/futures.py in result(self)
#      72             # out of this and propogate the exception.
# ---> 73             return self._coordinator.result()
#      74         except KeyboardInterrupt as e:
#
# /Users/mike_mckenna/Downloads/Users/mike_mckenna/Desktop/lib/python3.5/site-packages/s3transfer/futures.py in result(self)
#     232         if self._exception:
# --> 233             raise self._exception
#     234         return self._result
#
# /Users/mike_mckenna/Downloads/Users/mike_mckenna/Desktop/lib/python3.5/site-packages/s3transfer/tasks.py in __call__(self)
#     125             if not self._transfer_coordinator.done():
# --> 126                 return self._execute_main(kwargs)
#     127         except Exception as e:
#
# /Users/mike_mckenna/Downloads/Users/mike_mckenna/Desktop/lib/python3.5/site-packages/s3transfer/tasks.py in _execute_main(self, kwargs)
#     149
# --> 150         return_value = self._main(**kwargs)
#     151         # If the task is the final task, then set the TransferFuture's
#
# /Users/mike_mckenna/Downloads/Users/mike_mckenna/Desktop/lib/python3.5/site-packages/s3transfer/upload.py in _main(self, client, fileobj, bucket, key, extra_args)
#     691         with fileobj as body:
# --> 692             client.put_object(Bucket=bucket, Key=key, Body=body, **extra_args)
#     693
#
# /Users/mike_mckenna/Downloads/Users/mike_mckenna/Desktop/lib/python3.5/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     313             # The "self" in this scope is referring to the BaseClient.
# --> 314             return self._make_api_call(operation_name, kwargs)
#     315
#
# /Users/mike_mckenna/Downloads/Users/mike_mckenna/Desktop/lib/python3.5/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     611             error_class = self.exceptions.from_code(error_code)
# --> 612             raise error_class(parsed_response, operation_name)
#     613         else:
#
# ClientError: An error occurred (AccessDenied) when calling the PutObject operation: Access Denied
#
# During handling of the above exception, another exception occurred:
#
# S3UploadFailedError                       Traceback (most recent call last)
# <ipython-input-31-0ef6954dc838> in <module>()
# ----> 1 hm.plot_particles_in_frame(prefix)
#
# /Users/mike_mckenna/Desktop/diff_classifier/diff_classifier/heatmaps.py in plot_particles_in_frame(prefix, x_range, y_range, upload)
#     322     fig.savefig(outfile, bbox_inches='tight')
#     323     if upload==True:
# --> 324         aws.upload_s3(outfile, remote_folder+'/'+outfile)
#     325
#     326
#
# /Users/mike_mckenna/Desktop/diff_classifier/diff_classifier/aws.py in upload_s3(local_fname, remote_fname, bucket_name)
#      19     s3 = boto3.resource('s3')
#      20     b = s3.Bucket(bucket_name)
# ---> 21     b.upload_file(local_fname, remote_fname)
#      22
#      23
#
# /Users/mike_mckenna/Downloads/Users/mike_mckenna/Desktop/lib/python3.5/site-packages/boto3/s3/inject.py in bucket_upload_file(self, Filename, Key, ExtraArgs, Callback, Config)
#     147     return self.meta.client.upload_file(
#     148         Filename=Filename, Bucket=self.name, Key=Key,
# --> 149         ExtraArgs=ExtraArgs, Callback=Callback, Config=Config)
#     150
#     151
#
# /Users/mike_mckenna/Downloads/Users/mike_mckenna/Desktop/lib/python3.5/site-packages/boto3/s3/inject.py in upload_file(self, Filename, Bucket, Key, ExtraArgs, Callback, Config)
#     108         return transfer.upload_file(
#     109             filename=Filename, bucket=Bucket, key=Key,
# --> 110             extra_args=ExtraArgs, callback=Callback)
#     111
#     112
#
# /Users/mike_mckenna/Downloads/Users/mike_mckenna/Desktop/lib/python3.5/site-packages/boto3/s3/transfer.py in upload_file(self, filename, bucket, key, callback, extra_args)
#     285             raise S3UploadFailedError(
#     286                 "Failed to upload %s to %s: %s" % (
# --> 287                     filename, '/'.join([bucket, key]), e))
#     288
#     289     def download_file(self, bucket, key, filename, extra_args=None,
#
# S3UploadFailedError: Failed to upload in_frame_60_nm_PS_PEG_in_hippocampus_vid_1_2.png to ccurtis7.pup/01_18_Experiment/60/in_frame_60_nm_PS_PEG_in_hippocampus_vid_1_2.png: An error occurred (AccessDenied) when calling the PutObject operation: Access Denied

# %%
gmean1, gSEM1 = hm.plot_individual_msds(prefix, alpha=0.05)
