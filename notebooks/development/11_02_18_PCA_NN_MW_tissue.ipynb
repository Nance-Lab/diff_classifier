# %% [markdown]
# ## Importing and prepping data

# %%
import pandas as pd
import numpy as np
import diff_classifier.aws as aws
import diff_classifier.pca as pca

# %%
features = []
remote_folder = '09_26_18_tissue_study'
bucket = 'hpontes.data'

vids = 5
types = ['10K', '5K', '1K', 'COOH']
slices = [1, 2, 3, 4, 5, 6]
counter = 0
for typ in types:
    for slic in slices:
        for num in range(1, vids+1):
            try:
                #to_track.append('100x_0_4_1_2_gel_{}_bulk_vid_{}'.format(vis, num))
                #to_track.append('{}_P{}_S{}_XY{}'.format(typ, pup, slic, '%02d' % num))
                filename = 'features_{}_tissue_S{}_XY{}.csv'.format(typ, slic, num)
                aws.download_s3('{}/{}'.format(remote_folder, filename), filename, bucket_name=bucket)
                fstats = pd.read_csv(filename, encoding = "ISO-8859-1", index_col='Unnamed: 0')
                fstats['Particle Type'] = pd.Series(fstats.shape[0]*[typ], index=fstats.index)
                fstats['Video Number'] = pd.Series(fstats.shape[0]*[num], index=fstats.index)
                fstats['Slices'] = pd.Series(fstats.shape[0]*[str(slic)], index=fstats.index)
                #print(num)
                print(filename)
                counter = counter + 1
                if counter == 1:
                    fstats_tot = fstats
                else:
                    fstats_tot = fstats_tot.append(fstats, ignore_index=True)
            except:
                print('skipped filename: {}'.format(filename))
# Out:
# features_10K_tissue_S1_XY1.csv
# features_10K_tissue_S1_XY2.csv
# features_10K_tissue_S1_XY3.csv
# features_10K_tissue_S1_XY4.csv
# features_10K_tissue_S1_XY5.csv
# features_10K_tissue_S2_XY1.csv
# features_10K_tissue_S2_XY2.csv
# features_10K_tissue_S2_XY3.csv
# features_10K_tissue_S2_XY4.csv
# features_10K_tissue_S2_XY5.csv
# features_10K_tissue_S3_XY1.csv
# features_10K_tissue_S3_XY2.csv
# features_10K_tissue_S3_XY3.csv
# features_10K_tissue_S3_XY4.csv
# features_10K_tissue_S3_XY5.csv
# features_10K_tissue_S4_XY1.csv
# features_10K_tissue_S4_XY2.csv
# features_10K_tissue_S4_XY3.csv
# features_10K_tissue_S4_XY4.csv
# features_10K_tissue_S4_XY5.csv
# features_10K_tissue_S5_XY1.csv
# features_10K_tissue_S5_XY2.csv
# features_10K_tissue_S5_XY3.csv
# features_10K_tissue_S5_XY4.csv
# features_10K_tissue_S5_XY5.csv
# features_10K_tissue_S6_XY1.csv
# features_10K_tissue_S6_XY2.csv
# features_10K_tissue_S6_XY3.csv
# features_10K_tissue_S6_XY4.csv
# features_10K_tissue_S6_XY5.csv
# features_5K_tissue_S1_XY1.csv
# features_5K_tissue_S1_XY2.csv
# features_5K_tissue_S1_XY3.csv
# features_5K_tissue_S1_XY4.csv
# features_5K_tissue_S1_XY5.csv
# features_5K_tissue_S2_XY1.csv
# features_5K_tissue_S2_XY2.csv
# features_5K_tissue_S2_XY3.csv
# features_5K_tissue_S2_XY4.csv
# features_5K_tissue_S2_XY5.csv
# features_5K_tissue_S3_XY1.csv
# features_5K_tissue_S3_XY2.csv
# features_5K_tissue_S3_XY3.csv
# features_5K_tissue_S3_XY4.csv
# features_5K_tissue_S3_XY5.csv
# features_5K_tissue_S4_XY1.csv
# features_5K_tissue_S4_XY2.csv
# features_5K_tissue_S4_XY3.csv
# features_5K_tissue_S4_XY4.csv
# features_5K_tissue_S4_XY5.csv
# features_5K_tissue_S5_XY1.csv
# features_5K_tissue_S5_XY2.csv
# features_5K_tissue_S5_XY3.csv
# features_5K_tissue_S5_XY4.csv
# features_5K_tissue_S5_XY5.csv
# features_5K_tissue_S6_XY1.csv
# features_5K_tissue_S6_XY2.csv
# features_5K_tissue_S6_XY3.csv
# features_5K_tissue_S6_XY4.csv
# features_5K_tissue_S6_XY5.csv
# features_1K_tissue_S1_XY1.csv
# features_1K_tissue_S1_XY2.csv
# features_1K_tissue_S1_XY3.csv
# features_1K_tissue_S1_XY4.csv
# features_1K_tissue_S1_XY5.csv
# features_1K_tissue_S2_XY1.csv
# features_1K_tissue_S2_XY2.csv
# features_1K_tissue_S2_XY3.csv
# features_1K_tissue_S2_XY4.csv
# features_1K_tissue_S2_XY5.csv
# features_1K_tissue_S3_XY1.csv
# features_1K_tissue_S3_XY2.csv
# features_1K_tissue_S3_XY3.csv
# features_1K_tissue_S3_XY4.csv
# features_1K_tissue_S3_XY5.csv
# features_1K_tissue_S4_XY1.csv
# features_1K_tissue_S4_XY2.csv
# features_1K_tissue_S4_XY3.csv
# features_1K_tissue_S4_XY4.csv
# features_1K_tissue_S4_XY5.csv
# features_1K_tissue_S5_XY1.csv
# features_1K_tissue_S5_XY2.csv
# features_1K_tissue_S5_XY3.csv
# features_1K_tissue_S5_XY4.csv
# features_1K_tissue_S5_XY5.csv
# features_1K_tissue_S6_XY1.csv
# features_1K_tissue_S6_XY2.csv
# features_1K_tissue_S6_XY3.csv
# features_1K_tissue_S6_XY4.csv
# features_1K_tissue_S6_XY5.csv
# features_COOH_tissue_S1_XY1.csv
# features_COOH_tissue_S1_XY2.csv
# features_COOH_tissue_S1_XY3.csv
# features_COOH_tissue_S1_XY4.csv
# features_COOH_tissue_S1_XY5.csv
# features_COOH_tissue_S2_XY1.csv
# features_COOH_tissue_S2_XY2.csv
# features_COOH_tissue_S2_XY3.csv
# features_COOH_tissue_S2_XY4.csv
# features_COOH_tissue_S2_XY5.csv
# features_COOH_tissue_S3_XY1.csv
# features_COOH_tissue_S3_XY2.csv
# features_COOH_tissue_S3_XY3.csv
# features_COOH_tissue_S3_XY4.csv
# features_COOH_tissue_S3_XY5.csv
# features_COOH_tissue_S4_XY1.csv
# features_COOH_tissue_S4_XY2.csv
# features_COOH_tissue_S4_XY3.csv
# features_COOH_tissue_S4_XY4.csv
# features_COOH_tissue_S4_XY5.csv
# features_COOH_tissue_S5_XY1.csv
# features_COOH_tissue_S5_XY2.csv
# features_COOH_tissue_S5_XY3.csv
# features_COOH_tissue_S5_XY4.csv
# features_COOH_tissue_S5_XY5.csv
# features_COOH_tissue_S6_XY1.csv
# features_COOH_tissue_S6_XY2.csv
# features_COOH_tissue_S6_XY3.csv
# features_COOH_tissue_S6_XY4.csv
# features_COOH_tissue_S6_XY5.csv

# %%
fstats_tot['LogDeff2'] = np.log(fstats_tot['Deff2']).replace([np.inf, -np.inf], np.nan)
fstats_tot['LogMeanDeff2'] = np.log(fstats_tot['Mean Deff2']).replace([np.inf, -np.inf], np.nan)
pcadataset.final['LogDeff2'] = np.log(pcadataset.final['Deff2']).replace([np.inf, -np.inf], np.nan)
pcadataset.final['LogMeanDeff2'] = np.log(pcadataset.final['Mean Deff2']).replace([np.inf, -np.inf], np.nan)

fstats_tot['LogDeff1'] = np.log(fstats_tot['Deff1']).replace([np.inf, -np.inf], np.nan)
fstats_tot['LogMeanDeff1'] = np.log(fstats_tot['Mean Deff1']).replace([np.inf, -np.inf], np.nan)
pcadataset.final['LogDeff1'] = np.log(pcadataset.final['Deff1']).replace([np.inf, -np.inf], np.nan)
pcadataset.final['LogMeanDeff1'] = np.log(pcadataset.final['Mean Deff1']).replace([np.inf, -np.inf], np.nan)
# Out:
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log
#
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log
#   import sys
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in log
#
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':

# %%
featofvar = 'Particle Type'
X_train = pcadataset.final[pcadataset.final['Slices'].isin(['2', '3', '4', '5', '6'])]
X_test = pcadataset.final[pcadataset.final['Slices']=='1']
y_train = pcadataset.final[pcadataset.final['Slices'].isin(['2', '3', '4', '5', '6'])][featofvar]
y_test = pcadataset.final[pcadataset.final['Slices']=='1'][featofvar]

# %%
meanD = np.array(means)
meanD.sort()
Dbins = meanD[0:-1] + np.diff(meanD)/2
print(Dbins)
# Out:
# [-2.28302809 -0.46673724  0.85919291]

# %%
types = ['COOH', '1K', '10K', '5K']

# %%
types = ['COOH', '5K', '1K', '10K']

# %%
import matplotlib.pyplot as plt
Dbins = [-10, -2.283, -0.467, 0.859, 10]
bins = np.linspace(-10, 10, 200)
fig, axes = plt.subplots(nrows=4, figsize=(12, 9))
counter = 0
means = []
#types = types_order
for ax in axes:
    means.append(X_train[X_train['Particle Type']==types[counter]]['LogMeanDeff2'].median())
    for i in range(4):
        X_train[(X_train['Particle Type']==types[counter]) & (Dbins[i] < X_train['LogMeanDeff2']) & (X_train['LogMeanDeff2'] < Dbins[i+1])].hist(column='LogMeanDeff2', bins=bins, figsize=(12,3), edgecolor='k', ax=ax, )
        ax.set_xlim([-7.5, 3.5])
        ax.set_ylim([0, 5000])
    ax.axvline(X_train[X_train['Particle Type']==types[counter]]['LogMeanDeff2'].median(), color='k', linestyle='dashed', linewidth=3)
    ax.set_title(types[counter])
    if counter == 3:
        ax.set_xlabel(r'$log(D_{eff})$')
    counter = counter + 1

# %%
#Dbins = [-10, -6.538, -3.754, -0.808, 10]
bins = np.linspace(-10, 10, 200)
fig, axes = plt.subplots(nrows=4, figsize=(12, 9))
counter = 0
means = []
for ax in axes:
    means.append(X_test[X_test['Particle Type']==types[counter]]['LogMeanDeff2'].median())
    for i in range(4):
        X_test[(X_test['Particle Type']==types[counter]) & (Dbins[i] < X_test['LogMeanDeff2']) & (X_test['LogMeanDeff2'] < Dbins[i+1])].hist(column='LogMeanDeff2', bins=bins, figsize=(12,3), edgecolor='k', ax=ax, )
        ax.set_xlim([-7.5, 3.5])
        ax.set_ylim([0, 5000])
    ax.axvline(X_test[X_test['Particle Type']==types[counter]]['LogMeanDeff2'].median(), color='k', linestyle='dashed', linewidth=3)
    ax.set_title(types[counter])
    if counter == 3:
        ax.set_xlabel(r'$log(D_{eff})$')
    counter = counter + 1

# %%
newmap = cm.viridis(np.linspace(0.9, 0.0, 4))
labels3 = ['PS-PEG(1k)', 'PS-PEG(10k)', 'PS-PEG(5k)', 'PS-COOH']
types = ['1K', '10K', '5K', 'COOH']

newmap[2, :] = cm.viridis(np.linspace(0.9, 0.0, 4))[3, :]
newmap[1, :] = cm.viridis(np.linspace(0.9, 0.0, 4))[2, :]
newmap[3, :] = cm.viridis(np.linspace(0.9, 0.0, 4))[1, :]

# %%
for i, mw in enumerate(types):
    plt.plot([0,1], [0,1], c=newmap[i], label=labels3[3-i])
    plt.legend()

# %%
from matplotlib.pyplot import cm
Dbins = [-10, -2.283, -0.467, 0.859, 10]
bins = np.linspace(-10, 10, 300)
fig, axes = plt.subplots(nrows=4, figsize=(15, 14))
counter = 0
means = []
#labels3 = ['PS-PEG in serum', 'PS-COOH', 'PS-COOH in serum', 'PS-PEG']
for ax in axes:
    means.append(X_test[X_test['Particle Type']==types[counter]]['LogMeanDeff2'].median())
    color = iter(newmap)
    for i in range(4):
        c = next(color)
        X_test[(X_test['Particle Type']==types[counter]) & (Dbins[i] < X_test['LogMeanDeff2']) & (X_test['LogMeanDeff2'] < Dbins[i+1])].hist(column='LogMeanDeff2', bins=bins, figsize=(15,3), label = labels3[3-i], color=c, alpha=0.85, edgecolor='k', ax=ax, )
        ax.set_xlim([-7.5, 3.5])
        ax.set_ylim([0, 3200])
        ax.tick_params(labelsize=16)
    ax.axvline(X_test[X_test['Particle Type']==types[counter]]['LogMeanDeff2'].median(), color='k', linestyle='dashed', linewidth=3)
    ax.set_title('')
    if counter == 0:
        ax.legend(fontsize=17)
    #ax.set_yticklabels([])
#     if counter == 3:
#         ax.set_xlabel(r'$log(\bar{D}_{eff})$', fontsize=22)
    if counter != 3:
        ax.set_xticklabels([])
    counter = counter + 1
fig.savefig('./pics/tissue_mw_hist.png', dpi=300, pad_inches=0.1)

# %%
from matplotlib.pyplot import cm
Dbins = [-10, -2.283, -0.467, 0.859, 10]
bins = np.linspace(-10, 10, 300)
fig, axes = plt.subplots(nrows=4, figsize=(9, 14))
counter = 0
means = []
#labels3 = ['PS-PEG in serum', 'PS-COOH', 'PS-COOH in serum', 'PS-PEG']
for ax in axes:
    means.append(X_test[X_test['Particle Type']==types[counter]]['LogMeanDeff2'].median())
    color = iter(newmap)
    for i in range(4):
        c = next(color)
        X_test[(X_test['Particle Type']==types[counter]) & (Dbins[i] < X_test['LogMeanDeff2']) & (X_test['LogMeanDeff2'] < Dbins[i+1])].hist(column='LogMeanDeff2', bins=bins, figsize=(9,3), label = labels3[3-i], color=c, alpha=0.85, edgecolor='k', ax=ax, )
        ax.set_xlim([-7.5, 3.5])
        ax.set_ylim([0, 400])
        ax.tick_params(labelsize=16)
    ax.axvline(X_test[X_test['Particle Type']==types[counter]]['LogMeanDeff2'].median(), color='k', linestyle='dashed', linewidth=3)
    ax.set_title('')
    if counter == 0:
        ax.legend(fontsize=17)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
#     if counter == 3:
#         ax.set_xlabel(r'$log(\bar{D}_{eff})$', fontsize=22)
    if counter != 3:
        ax.set_xticklabels([])
    counter = counter + 1
fig.savefig('./pics/tissue_mw_hist_small.png', dpi=300, pad_inches=0.1)

# %%
from sklearn.metrics import classification_report

# %%
y_pred2 = list(pd.cut(X_train.LogMeanDeff2.values, bins=Dbins, labels=types).astype(str))
y_true2 = X_train['Particle Type'].values

print(classification_report(y_true2, y_pred2, digits=4))
# Out:
#              precision    recall  f1-score   support
#
#         10K     0.1761    0.3247    0.2284     65307
#          1K     0.4109    0.2770    0.3310    131068
#          5K     0.6642    0.3751    0.4794    134334
#        COOH     0.3745    0.6744    0.4816     33812
#         nan     0.0000    0.0000    0.0000         0
#
# avg / total     0.4588    0.3586    0.3813    364521
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
y_pred2 = list(pd.cut(X_test.LogMeanDeff2.values, bins=Dbins, labels=types).astype(str))
y_true2 = X_test['Particle Type'].values

print(classification_report(y_true2, y_pred2, digits=4))
# Out:
#              precision    recall  f1-score   support
#
#         10K     0.3036    0.2230    0.2571      8628
#          1K     0.6577    0.3200    0.4305     85472
#          5K     0.0139    0.1099    0.0247      9165
#        COOH     0.6471    0.4217    0.5107     56022
#         nan     0.0000    0.0000    0.0000         0
#
# avg / total     0.5978    0.3384    0.4260    159287
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
fstats_tot['LogDeff1'] = np.log(fstats_tot.Deff1).replace([np.inf, -np.inf], np.nan)

# %%
axes = fstats_tot.hist(column='LogDeff1', by='Region and Type', layout=(6, 1), bins=100, sharex=True, sharey=True,
                        figsize=(10, 8), edgecolor='k')

means = []
types2 = ['PEG_Cortex', 'PEG_Hippocampus', 'PEG_Thalamus', 'PS_Cortex', 'PS_Hippocampus', 'PS_Thalamus']
for ax, typ in zip(axes, types2):
    ax.set_ylim([0,8000])
    #ax.set_xscale("log", nonposx='clip')
    ax.set_xlim([-7.5,2.5])
    means.append(fstats_tot[fstats_tot['Region and Type']==typ]['LogDeff1'].median())
    ax.axvline(fstats_tot[fstats_tot['Region and Type']==typ]['LogDeff1'].median(), color='k', linestyle='dashed', linewidth=3)

# %%
meanD = np.array(means)
meanD.sort()
Dbins = meanD[0:-1] + np.diff(meanD)/2
print(Dbins)

# %%
import matplotlib.pyplot as plt
Dbins = [-10, -0.842, -0.037, 0.516, 0.891, 1.29, 10]
bins = np.linspace(-10, 10, 300)
fig, ax = plt.subplots(figsize=(10, 4))
for i in range(6):
    fstats_tot[(fstats_tot['Particle Type']=='PEG'(Dbins[i] < fstats_tot['LogDeff1']) & (fstats_tot['LogDeff1'] < Dbins[i+1])].hist(column='LogDeff1', bins=bins, figsize=(4, 8), edgecolor='k', ax=ax)
ax.set_xlim([-7.5, 2.5])

# %%
from sklearn.metrics import classification_report
y_pred2 = list(pd.cut(fstats_tot.LogDeff1, bins=Dbins, labels=types2).astype(str))
y_true = fstats_tot['Region and Type'].tolist()
print(classification_report(y_true, y_pred2, digits=4))

# %%
import matplotlib.pyplot as plt
Dbins = [-10, 0.891, 1.29, 10]
bins = np.linspace(-10, 10, 300)
fig, ax = plt.subplots(figsize=(10, 4))
for i in range(3):
    fstats_tot[(fstats_tot['Particle Type']=='PEG') & (Dbins[i] < fstats_tot['LogDeff1']) & (fstats_tot['LogDeff1'] < Dbins[i+1])].hist(column='LogDeff1', bins=bins, figsize=(4, 8), edgecolor='k', ax=ax)
ax.set_xlim([-7.5, 2.5])

# %%
y_pred2 = list(pd.cut(fstats_tot[fstats_tot['Particle Type']=='PEG'].LogDeff1, bins=Dbins, labels=['Hippocampus', 'Cortex', 'Thalamus']).astype(str))
y_true = fstats_tot[fstats_tot['Particle Type']=='PEG']['Region'].tolist()
print(classification_report(y_true, y_pred2, digits=4))

# %%
import matplotlib.pyplot as plt
Dbins = [-10, -0.842, -0.037, 10]
bins = np.linspace(-10, 10, 300)
fig, ax = plt.subplots(figsize=(10, 4))
for i in range(3):
    fstats_tot[(fstats_tot['Particle Type']=='PS') & (Dbins[i] < fstats_tot['LogDeff1']) & (fstats_tot['LogDeff1'] < Dbins[i+1])].hist(column='LogDeff1', bins=bins, figsize=(4, 8), edgecolor='k', ax=ax)
ax.set_xlim([-7.5, 2.5])

# %%
y_pred2 = list(pd.cut(fstats_tot[fstats_tot['Particle Type']=='PS'].LogDeff1, bins=Dbins, labels=['Hippocampus', 'Cortex', 'Thalamus']).astype(str))
y_true = fstats_tot[fstats_tot['Particle Type']=='PS']['Region'].tolist()
print(classification_report(y_true, y_pred2, digits=4))

# %%
Dbins

# %%
fstats_tot.to_csv('features.csv')

# %%
#with equal sample sizes for each particle type
import random
counter = 0
#mws = ['10k_PEG', '5k_PEG', '1k_PEG', 'PS_COOH']
mws = ['PEG_Cortex', 'PEG_Hippocampus', 'PEG_Thalamus', 'PS_Cortex', 'PS_Hippocampus', 'PS_Thalamus']
for mw in mws:
    fstats_type = fstats_tot[fstats_tot['R Type']==mw].reset_index(drop=True)
    print(fstats_type.shape)
    subset = np.sort(np.array(random.sample(range(fstats_type.shape[0]), 34000)))
    if counter == 0:
        fstats_sub = fstats_type.loc[subset, :].reset_index(drop=True)
    else:
        fstats_sub = fstats_sub.append(fstats_type.loc[subset, :].reset_index(drop=True), ignore_index=True)
    counter = counter + 1

# %%
#fstats = pd.read_csv(filename, encoding = "ISO-8859-1", index_col='Unnamed: 0')
nonnum = ['Particle Type', 'Video Number', 'Track_ID', 'Slices',
          'Mean Mean_Intensity', 'Std Mean_Intensity', 'X', 'Y',
          'Mean X', 'Mean Y', 'Std X', 'Std Y']
fstats_num = fstats_tot.drop(nonnum, axis=1)
fstats_raw = fstats_num.values
#fstats

# %%
mws = ['PEG_Cortex', 'PEG_Hippocampus', 'PEG_Thalamus', 'PS_Cortex', 'PS_Hippocampus', 'PS_Thalamus']
for mw in mws:
    print(fstats_tot[fstats_tot['Region and Type'] == mw].shape)

# %% [markdown]
# ## PCA analysis

# %% [markdown]
# The pca.pca_analysis function provides a completely contained PCA analysis of the input trajectory features dataset. It includes options to impute NaN values (fill in with average values or drop them), and to scale features. Read the docstring for more information.

# %%
ncomp = 14
nonnum = ['Particle Type', 'Video Number', 'Track_ID', 'Slices',
          'Mean Mean_Intensity', 'Std Mean_Intensity', 'X', 'Y',
          'Mean X', 'Mean Y', 'Std X', 'Std Y']
pcadataset = pca.pca_analysis(fstats_tot, dropcols=nonnum, n_components=ncomp)
# Out:
# Cumulative explained variance:
# 0 component: 0.2943047074762938
# 1 component: 0.41974423031832414
# 2 component: 0.4916267310326605
# 3 component: 0.5507682919480987
# 4 component: 0.6056667772705364
# 5 component: 0.6421813597559524
# 6 component: 0.6755929910249859
# 7 component: 0.7020577441794293
# 8 component: 0.7261088646067491
# 9 component: 0.7480718402457309
# 10 component: 0.7686194654536886
# 11 component: 0.7866931377180231
# 12 component: 0.8042895874807542
# 13 component: 0.8206502242732131

# %%
fstats_num.columns
# Out:
# Index(['alpha', 'D_fit', 'kurtosis', 'asymmetry1', 'asymmetry2', 'asymmetry3',
#        'AR', 'elongation', 'boundedness', 'fractal_dim', 'trappedness',
#        'efficiency', 'straightness', 'MSD_ratio', 'frames', 'Quality',
#        'Mean_Intensity', 'SN_Ratio', 'Deff1', 'Deff2', 'Mean alpha',
#        'Std alpha', 'Mean D_fit', 'Std D_fit', 'Mean kurtosis', 'Std kurtosis',
#        'Mean asymmetry1', 'Std asymmetry1', 'Mean asymmetry2',
#        'Std asymmetry2', 'Mean asymmetry3', 'Std asymmetry3', 'Mean AR',
#        'Std AR', 'Mean elongation', 'Std elongation', 'Mean boundedness',
#        'Std boundedness', 'Mean fractal_dim', 'Std fractal_dim',
#        'Mean trappedness', 'Std trappedness', 'Mean efficiency',
#        'Std efficiency', 'Mean straightness', 'Std straightness',
#        'Mean MSD_ratio', 'Std MSD_ratio', 'Mean frames', 'Std frames',
#        'Mean Quality', 'Std Quality', 'Mean SN_Ratio', 'Std SN_Ratio',
#        'Mean Deff1', 'Std Deff1', 'Mean Deff2', 'Std Deff2'],
#       dtype='object')

# %%
pcadataset.components.to_csv('components.csv')
aws.upload_s3('components.csv', '{}/components.csv'.format(remote_folder, filename), bucket_name=bucket)

# %%
pcadataset.prcomps
# Out:
#                 0                 1             2                3   \
# 0       Mean Deff1    Std efficiency    asymmetry2   Std asymmetry2
# 1       Std frames  Std straightness    asymmetry3   Std asymmetry1
# 2       Mean D_fit   Mean efficiency    asymmetry1   Std elongation
# 3  Std fractal_dim        Mean alpha    elongation  Std trappedness
# 4  Mean elongation  Mean trappedness  Mean Quality  Std boundedness
#
#                 4            5             6                 7   \
# 0  Mean asymmetry1  trappedness  straightness       trappedness
# 1  Mean asymmetry2  boundedness    efficiency       boundedness
# 2   Std asymmetry1        alpha        frames  Mean boundedness
# 3   Std asymmetry2        D_fit   boundedness  Mean trappedness
# 4  Mean asymmetry3    MSD_ratio   trappedness   Std boundedness
#
#                8                9               10          11           12  \
# 0   Std MSD_ratio     Std kurtosis   Std MSD_ratio       D_fit     kurtosis
# 1  Mean MSD_ratio    Mean kurtosis  Mean MSD_ratio    kurtosis       Std AR
# 2        SN_Ratio  Std boundedness      Mean Deff2       alpha        Deff2
# 3   Mean SN_Ratio  Std trappedness       Std Deff2   Std Deff2       frames
# 4         Mean AR         kurtosis     Mean frames  Mean Deff2  fractal_dim
#
#               13
# 0         Std AR
# 1       kurtosis
# 2          Deff2
# 3  Std MSD_ratio
# 4          D_fit

# %% [markdown]
# The pca.kmo function calculates the Kaiser-Meyer-Olkin statistic, a measure of sampling adequacy. Check the docstring for more information.

# %%
fstats_tot.shape

# %%
for test in fstats_tot.columns:
    print(test)

# %%
kmostat = pca.kmo(pcadataset.scaled)

# %% [markdown]
# ## Visualization

# %% [markdown]
# Users can then compare average principle component values between subgroups of the data. In this case, all particles were taken from the same sample, so there are no experimental subgroups. I chose to compare short trajectories to long trajectories, as I would expect differences between the two groups.

# %%
import numpy as np
featofvar = 'Particle Type'
dicti = {}
#test = np.exp(np.nanmean(np.log(pcadataset.final[pcadataset.final['Particle Size']==200].as_matrix()), axis=0))[-6:]
#test1 = np.exp(np.nanmean(np.log(pcadataset.final[pcadataset.final['Particle Size']==500].as_matrix()), axis=0))[-6:]
dicti[0] = np.nanmean(pcadataset.final[pcadataset.final[featofvar]=='10K'].values[:, -ncomp:], axis=0)
dicti[1] = np.nanmean(pcadataset.final[pcadataset.final[featofvar]=='5K'].values[:, -ncomp:], axis=0)
dicti[2] = np.nanmean(pcadataset.final[pcadataset.final[featofvar]=='1K'].values[:, -ncomp:], axis=0)
dicti[3] = np.nanmean(pcadataset.final[pcadataset.final[featofvar]=='COOH'].values[:, -ncomp:], axis=0)

# %%
pca.plot_pca(dicti, savefig=True, labels=['10K', '5K', '1K', 'COOH'], rticks=np.linspace(-5, 5, 11), filename='pics/tissue_MW_pcaavg.png')

# %% [markdown]
# The variable pcadataset.prcomps shows the user the major contributions to each of the new principle components. When observing the graph above, users can see that there are some differences between short trajectories and long trajectories in component 0 (asymmetry1 being the major contributor) and component 1 (elongation being the major contributor).

# %%
pcadataset.prcomps

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import cm

def feature_violin(df, label='label', lvals=['yes', 'no'], labels=['yes', 'no'], fsubset=3, **kwargs):
    """Creates violinplot of input feature dataset

    Designed to plot PCA components from pca_analysis.

    Parameters
    ----------
    df : pandas.core.frames.DataFrame
        Must contain a group name column, and numerical feature columns.
    label : string or int
        Name of group column.
    lvals : list of string or int
        All values that group column can take
    fsubset : int or list of int
        Features to be plotted. If integer, will plot range(fsubset).
        If list, will only plot features contained in fsubset.
    **kwargs : variable
        figsize : tuple of int or float
            Dimensions of output figure
        yrange : list of int or float
            Range of y axis
        xlabel : string
            Label of x axis
        labelsize : int or float
            Font size of x label
        ticksize : int or float
            Font size of y tick labels
        fname : None or string
            Name of output file
        legendfontsize : int or float
            Font size of legend
        legendloc : int
            Location of legend in plot e.g. 1, 2, 3, 4

    """

    defaults = {'figsize': (12, 5), 'yrange': [-20, 20], 'xlabel': 'Feature',
                'labelsize': 20, 'ticksize': 16, 'fname': None,
                'legendfontsize': 12, 'legendloc': 1}

    for defkey in defaults.keys():
        if defkey not in kwargs.keys():
            kwargs[defkey] = defaults[defkey]

    # Restacking input data
    groupsize = []
    featcol = []
    valcol = []
    feattype = []

    if isinstance(fsubset, int):
        frange = range(fsubset)
    else:
        frange = fsubset

    for feat in frange:
        groupsize.extend(df[label].values)
        featcol.extend([feat]*df[label].values.shape[0])
        valcol.extend(df[feat].values)

    to_violind = {'label': groupsize, 'Feature': featcol,
                  'Feature Value': valcol}
    to_violin = pd.DataFrame(data=to_violind)

    # Plotting function
    fig, ax = plt.subplots(figsize=kwargs['figsize'])
    sns.violinplot(x="Feature", y="Feature Value", hue="label", data=to_violin,
                   palette=cm.viridis(np.linspace(0, 0.9, 4)), hue_order=lvals,
                   figsize=kwargs['figsize'], linewidth=0)

    # kwargs
    ax.tick_params(axis='both', which='major', labelsize=kwargs['ticksize'])
    plt.xlabel('Feature', fontsize=kwargs['labelsize'])
    plt.ylabel('Normalized\nFeature Space', fontsize=kwargs['labelsize'])
    plt.ylim(kwargs['yrange'])
    plt.setp(ax.collections, alpha=.75)
    L=ax.legend(loc='upper right', prop={'size': 18})
    for item, label in zip(L.get_texts(), labels):
        item.set_text(label)
    #ax.legend(prop={'size': 18})
    
    if kwargs['fname'] is None:
        plt.show()
    else:
        plt.savefig(kwargs['fname'], dpi=300, pad_inches=0.22)

    return to_violin

# %%
labels = types
labels2 = ['PS-PEG(10k)', 'PS-PEG(5k)', 'PS-PEG(1k)', 'PS-COOH']
feats = feature_violin(pcadataset.final, label='Particle Type', lvals=labels, labels=labels2, fsubset=14, yrange=[-15, 15],
                       legendfontsize=21, labelsize=24, fname='./pics/tissue_mw_pcadist.png')

# %%
lvals = ['10K', '5K', '1K', 'COOH']
feats = pca.feature_violin(pcadataset.final, label=featofvar, lvals=lvals, fsubset=ncomp, yrange=[-12, 12])

# %%
#lvals = ['PS_Cortex', 'PS_Hippocampus', 'PS_Thalamus']
fstats1 = pca.feature_plot_3D(pcadataset.final,
                              label=featofvar, lvals=lvals, randcount=400, yrange=[-6, 6],
                              xrange=[-4, 4], alpha=0.45)

# %% [markdown]
# ## Neural Network

# %%
from sklearn.model_selection import GridSearchCV, cross_val_score, KFold, train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report

# %%
test = pcadataset.final.values[:, -ncomp:]
y = pcadataset.final[featofvar].values
for run in range(1):
    X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.4)

    clf = MLPClassifier(hidden_layer_sizes=(900, ), solver='sgd', verbose=True, max_iter=500, tol=0.00001,
                        alpha=0.001, batch_size=100, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))
# Out:
# Iteration 1, loss = 0.48035657
# Validation score: 0.805407
# Iteration 2, loss = 0.42126287
# Validation score: 0.811554
# Iteration 3, loss = 0.40705992
# Validation score: 0.822115
# Iteration 4, loss = 0.39797502
# Validation score: 0.823376
# Iteration 5, loss = 0.39173334
# Validation score: 0.828342
# Iteration 6, loss = 0.38662778
# Validation score: 0.831021
# Iteration 7, loss = 0.38208646
# Validation score: 0.830864
# Iteration 8, loss = 0.37824961
# Validation score: 0.826056
# Iteration 9, loss = 0.37517800
# Validation score: 0.831888
# Iteration 10, loss = 0.37138446
# Validation score: 0.837169
# Iteration 11, loss = 0.36766498
# Validation score: 0.836066
# Iteration 12, loss = 0.36466579
# Validation score: 0.836460
# Iteration 13, loss = 0.36199196
# Validation score: 0.837721
# Iteration 14, loss = 0.35881155
# Validation score: 0.837957
# Iteration 15, loss = 0.35634200
# Validation score: 0.839849
# Iteration 16, loss = 0.35326896
# Validation score: 0.838982
# Iteration 17, loss = 0.35076901
# Validation score: 0.831888
# Iteration 18, loss = 0.34741061
# Validation score: 0.844499
# Iteration 19, loss = 0.34540037
# Validation score: 0.848045
# Iteration 20, loss = 0.34207726
# Validation score: 0.849149
# Iteration 21, loss = 0.33995075
# Validation score: 0.846627
# Iteration 22, loss = 0.33674011
# Validation score: 0.849779
# Iteration 23, loss = 0.33451082
# Validation score: 0.849228
# Iteration 24, loss = 0.33207196
# Validation score: 0.851198
# Iteration 25, loss = 0.32917221
# Validation score: 0.849385
# Iteration 26, loss = 0.32680007
# Validation score: 0.846627
# Iteration 27, loss = 0.32441616
# Validation score: 0.856242
# Iteration 28, loss = 0.32123012
# Validation score: 0.858685
# Iteration 29, loss = 0.31972517
# Validation score: 0.865542
# Iteration 30, loss = 0.31603031
# Validation score: 0.861759
# Iteration 31, loss = 0.31428787
# Validation score: 0.862784
# Iteration 32, loss = 0.31131272
# Validation score: 0.864991
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.001000
# Iteration 33, loss = 0.29829250
# Validation score: 0.871769
# Iteration 34, loss = 0.29635005
# Validation score: 0.872241
# Iteration 35, loss = 0.29527903
# Validation score: 0.873503
# Iteration 36, loss = 0.29445740
# Validation score: 0.875079
# Iteration 37, loss = 0.29390352
# Validation score: 0.871769
# Iteration 38, loss = 0.29313392
# Validation score: 0.873266
# Iteration 39, loss = 0.29266623
# Validation score: 0.874212
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000200
# Iteration 40, loss = 0.28944595
# Validation score: 0.875709
# Iteration 41, loss = 0.28886471
# Validation score: 0.876892
# Iteration 42, loss = 0.28872992
# Validation score: 0.877286
# Iteration 43, loss = 0.28853620
# Validation score: 0.876734
# Iteration 44, loss = 0.28836437
# Validation score: 0.875867
# Iteration 45, loss = 0.28821409
# Validation score: 0.877601
# Iteration 46, loss = 0.28823030
# Validation score: 0.877049
# Iteration 47, loss = 0.28805946
# Validation score: 0.876340
# Iteration 48, loss = 0.28783134
# Validation score: 0.876892
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000040
# Iteration 49, loss = 0.28719073
# Validation score: 0.878153
# Iteration 50, loss = 0.28701919
# Validation score: 0.876813
# Iteration 51, loss = 0.28695448
# Validation score: 0.876261
# Iteration 52, loss = 0.28693384
# Validation score: 0.878153
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000008
# Iteration 53, loss = 0.28676424
# Validation score: 0.877601
# Iteration 54, loss = 0.28674777
# Validation score: 0.877601
# Iteration 55, loss = 0.28673812
# Validation score: 0.877207
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000002
# Iteration 56, loss = 0.28669594
# Validation score: 0.877207
# Iteration 57, loss = 0.28669425
# Validation score: 0.877128
# Iteration 58, loss = 0.28669281
# Validation score: 0.877128
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000000
# Iteration 59, loss = 0.28668281
# Validation score: 0.877049
# Iteration 60, loss = 0.28668255
# Validation score: 0.877049
# Iteration 61, loss = 0.28668226
# Validation score: 0.877049
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Learning rate too small. Stopping.
# Training Results
#              precision    recall  f1-score   support
#
#         10K     0.6587    0.7060    0.6816     15430
#          1K     0.9294    0.9363    0.9329     60106
#          5K     0.6872    0.6225    0.6533     15153
#        COOH     0.9933    0.9897    0.9915     36185
#
# avg / total     0.8858    0.8861    0.8856    126874
#
# Test Results
#
#              precision    recall  f1-score   support
#
#         10K     0.6311    0.6718    0.6508     10386
#          1K     0.9235    0.9299    0.9267     39969
#          5K     0.6499    0.5932    0.6202     10000
#        COOH     0.9916    0.9885    0.9900     24229
#
# avg / total     0.8747    0.8752    0.8747     84584

# %%
test = pcadataset.final.values[:, -ncomp:]
y = pcadataset.final[featofvar].values
for run in range(1):
    X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.4)

    clf = MLPClassifier(hidden_layer_sizes=(600, ), solver='sgd', verbose=True, max_iter=500, tol=0.00001,
                        alpha=0.001, batch_size=100, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))
# Out:
# Iteration 1, loss = 0.47831519
# Validation score: 0.795555
# Iteration 2, loss = 0.42082725
# Validation score: 0.793742
# Iteration 3, loss = 0.40708520
# Validation score: 0.811318
# Iteration 4, loss = 0.39850149
# Validation score: 0.808875
# Iteration 5, loss = 0.39230262
# Validation score: 0.811633
# Iteration 6, loss = 0.38691426
# Validation score: 0.813288
# Iteration 7, loss = 0.38238395
# Validation score: 0.819593
# Iteration 8, loss = 0.37822574
# Validation score: 0.820697
# Iteration 9, loss = 0.37408418
# Validation score: 0.822667
# Iteration 10, loss = 0.37096810
# Validation score: 0.824165
# Iteration 11, loss = 0.36744755
# Validation score: 0.828893
# Iteration 12, loss = 0.36469301
# Validation score: 0.827554
# Iteration 13, loss = 0.36106157
# Validation score: 0.831967
# Iteration 14, loss = 0.35784410
# Validation score: 0.835277
# Iteration 15, loss = 0.35518559
# Validation score: 0.834016
# Iteration 16, loss = 0.35247386
# Validation score: 0.834568
# Iteration 17, loss = 0.35024886
# Validation score: 0.840400
# Iteration 18, loss = 0.34739383
# Validation score: 0.837642
# Iteration 19, loss = 0.34533593
# Validation score: 0.842055
# Iteration 20, loss = 0.34282042
# Validation score: 0.842055
# Iteration 21, loss = 0.34036576
# Validation score: 0.838982
# Iteration 22, loss = 0.33782597
# Validation score: 0.847257
# Iteration 23, loss = 0.33547310
# Validation score: 0.838036
# Iteration 24, loss = 0.33318266
# Validation score: 0.848439
# Iteration 25, loss = 0.33091349
# Validation score: 0.849228
# Iteration 26, loss = 0.32849620
# Validation score: 0.844499
# Iteration 27, loss = 0.32606646
# Validation score: 0.842528
# Iteration 28, loss = 0.32375474
# Validation score: 0.848834
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.001000
# Iteration 29, loss = 0.31224275
# Validation score: 0.861523
# Iteration 30, loss = 0.31066167
# Validation score: 0.857030
# Iteration 31, loss = 0.30988377
# Validation score: 0.859789
# Iteration 32, loss = 0.30915150
# Validation score: 0.861050
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000200
# Iteration 33, loss = 0.30635193
# Validation score: 0.860025
# Iteration 34, loss = 0.30593287
# Validation score: 0.860892
# Iteration 35, loss = 0.30574987
# Validation score: 0.862863
# Iteration 36, loss = 0.30571378
# Validation score: 0.861129
# Iteration 37, loss = 0.30551917
# Validation score: 0.860419
# Iteration 38, loss = 0.30538103
# Validation score: 0.862153
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000040
# Iteration 39, loss = 0.30476968
# Validation score: 0.860971
# Iteration 40, loss = 0.30468200
# Validation score: 0.862311
# Iteration 41, loss = 0.30465914
# Validation score: 0.862232
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000008
# Iteration 42, loss = 0.30449061
# Validation score: 0.862311
# Iteration 43, loss = 0.30447081
# Validation score: 0.862153
# Iteration 44, loss = 0.30446651
# Validation score: 0.862232
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000002
# Iteration 45, loss = 0.30442717
# Validation score: 0.862311
# Iteration 46, loss = 0.30442600
# Validation score: 0.862390
# Iteration 47, loss = 0.30442457
# Validation score: 0.862390
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000000
# Iteration 48, loss = 0.30441663
# Validation score: 0.862311
# Iteration 49, loss = 0.30441632
# Validation score: 0.862311
# Iteration 50, loss = 0.30441602
# Validation score: 0.862311
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Learning rate too small. Stopping.
# Training Results
#              precision    recall  f1-score   support
#
#         10K     0.6337    0.6657    0.6493     15517
#          1K     0.9304    0.9174    0.9239     60079
#          5K     0.6162    0.6262    0.6212     15174
#        COOH     0.9927    0.9876    0.9902     36104
#
# avg / total     0.8743    0.8718    0.8730    126874
#
# Test Results
#
#              precision    recall  f1-score   support
#
#         10K     0.6102    0.6353    0.6225     10299
#          1K     0.9236    0.9117    0.9176     39996
#          5K     0.5877    0.6015    0.5945      9979
#        COOH     0.9913    0.9855    0.9884     24310
#
# avg / total     0.8653    0.8627    0.8639     84584

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots()
ax1.plot(clf.loss_curve_, linewidth=4)
#ax1.set_xlim([0, 60])
#ax1.set_ylim([0.04, 0.18])
ax1.set_ylabel('Loss Curve')

ax2 = ax1.twinx()
ax2.plot(clf.validation_scores_, linewidth=4, c='g')
#ax2.set_ylim([0.65, 0.75])
ax2.set_ylabel('Validation Scores')
# Out:
# Text(0,0.5,'Validation Scores')

# %%
test = pcadataset.final.values[:, -ncomp:]
y = pcadataset.final[featofvar].replace(['10K', '5K'], 'HI')

for run in range(1):
    X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.4)

    clf = MLPClassifier(hidden_layer_sizes=(900, ), solver='sgd', verbose=True, max_iter=500, tol=0.00001,
                        alpha=0.001, batch_size=100, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))
# Out:
# Iteration 1, loss = 0.30981974
# Validation score: 0.886822
# Iteration 2, loss = 0.26150570
# Validation score: 0.895098
# Iteration 3, loss = 0.25052131
# Validation score: 0.896989
# Iteration 4, loss = 0.24294798
# Validation score: 0.900615
# Iteration 5, loss = 0.23768597
# Validation score: 0.900457
# Iteration 6, loss = 0.23291735
# Validation score: 0.904871
# Iteration 7, loss = 0.22932631
# Validation score: 0.903846
# Iteration 8, loss = 0.22564197
# Validation score: 0.909127
# Iteration 9, loss = 0.22210948
# Validation score: 0.908417
# Iteration 10, loss = 0.21964101
# Validation score: 0.912122
# Iteration 11, loss = 0.21706965
# Validation score: 0.909521
# Iteration 12, loss = 0.21485068
# Validation score: 0.911649
# Iteration 13, loss = 0.21254115
# Validation score: 0.915117
# Iteration 14, loss = 0.21047260
# Validation score: 0.913146
# Iteration 15, loss = 0.20839218
# Validation score: 0.915195
# Iteration 16, loss = 0.20630392
# Validation score: 0.919530
# Iteration 17, loss = 0.20446241
# Validation score: 0.916772
# Iteration 18, loss = 0.20282731
# Validation score: 0.916851
# Iteration 19, loss = 0.20025520
# Validation score: 0.919767
# Iteration 20, loss = 0.19868623
# Validation score: 0.921264
# Iteration 21, loss = 0.19681081
# Validation score: 0.921185
# Iteration 22, loss = 0.19519833
# Validation score: 0.915905
# Iteration 23, loss = 0.19309039
# Validation score: 0.923392
# Iteration 24, loss = 0.19172804
# Validation score: 0.924811
# Iteration 25, loss = 0.18908659
# Validation score: 0.924102
# Iteration 26, loss = 0.18746319
# Validation score: 0.924968
# Iteration 27, loss = 0.18627793
# Validation score: 0.918427
# Iteration 28, loss = 0.18411151
# Validation score: 0.917954
# Iteration 29, loss = 0.18298691
# Validation score: 0.923786
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.001000
# Iteration 30, loss = 0.17356897
# Validation score: 0.933323
# Iteration 31, loss = 0.17167458
# Validation score: 0.932692
# Iteration 32, loss = 0.17130842
# Validation score: 0.931037
# Iteration 33, loss = 0.17104691
# Validation score: 0.930801
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000200
# Iteration 34, loss = 0.16861569
# Validation score: 0.932850
# Iteration 35, loss = 0.16818983
# Validation score: 0.933559
# Iteration 36, loss = 0.16812551
# Validation score: 0.932850
# Iteration 37, loss = 0.16800207
# Validation score: 0.932771
# Iteration 38, loss = 0.16792495
# Validation score: 0.933559
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000040
# Iteration 39, loss = 0.16741623
# Validation score: 0.933953
# Iteration 40, loss = 0.16733053
# Validation score: 0.933244
# Iteration 41, loss = 0.16731108
# Validation score: 0.933638
# Iteration 42, loss = 0.16727420
# Validation score: 0.933244
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000008
# Iteration 43, loss = 0.16717002
# Validation score: 0.933480
# Iteration 44, loss = 0.16716531
# Validation score: 0.933402
# Iteration 45, loss = 0.16715837
# Validation score: 0.933402
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000002
# Iteration 46, loss = 0.16712688
# Validation score: 0.933480
# Iteration 47, loss = 0.16712657
# Validation score: 0.933638
# Iteration 48, loss = 0.16712546
# Validation score: 0.933638
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000000
# Iteration 49, loss = 0.16711867
# Validation score: 0.933638
# Iteration 50, loss = 0.16711854
# Validation score: 0.933638
# Iteration 51, loss = 0.16711823
# Validation score: 0.933638
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Learning rate too small. Stopping.
# Training Results
#              precision    recall  f1-score   support
#
#          1K     0.9557    0.9056    0.9300     59917
#        COOH     0.9928    0.9884    0.9906     36267
#          HI     0.8377    0.9279    0.8805     30690
#
# avg / total     0.9378    0.9346    0.9353    126874
#
# Test Results
#
#              precision    recall  f1-score   support
#
#          1K     0.9493    0.8963    0.9220     40158
#        COOH     0.9909    0.9878    0.9893     24147
#          HI     0.8223    0.9162    0.8667     20279
#
# avg / total     0.9307    0.9272    0.9280     84584

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots()
ax1.plot(clf.loss_curve_, linewidth=4)
#ax1.set_xlim([0, 60])
#ax1.set_ylim([0.04, 0.18])
ax1.set_ylabel('Loss Curve')

ax2 = ax1.twinx()
ax2.plot(clf.validation_scores_, linewidth=4, c='g')
#ax2.set_ylim([0.65, 0.75])
ax2.set_ylabel('Validation Scores')
# Out:
# Text(0,0.5,'Validation Scores')

# %%
X_train = pcadataset.final[pcadataset.final['Slices'].isin(['1', '2'])].values[:, -ncomp:] 
X_test = pcadataset.final[pcadataset.final['Slices']=='3'].values[:, -ncomp:]
y_train = pcadataset.final[pcadataset.final['Slices'].isin(['1', '2'])][featofvar].values
y_test = pcadataset.final[pcadataset.final['Slices']=='3'][featofvar].values

for run in range(1):
    #X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.4)

    clf = MLPClassifier(hidden_layer_sizes=(900, ), solver='sgd', verbose=True, max_iter=300, tol=0.00001,
                        alpha=0.001, batch_size=100, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))
# Out:
# Iteration 1, loss = 0.34965550
# Validation score: 0.865543
# Iteration 2, loss = 0.30310785
# Validation score: 0.864628
# Iteration 3, loss = 0.29019164
# Validation score: 0.869097
# Iteration 4, loss = 0.28245434
# Validation score: 0.870389
# Iteration 5, loss = 0.27607092
# Validation score: 0.876851
# Iteration 6, loss = 0.27054647
# Validation score: 0.879974
# Iteration 7, loss = 0.26594311
# Validation score: 0.884820
# Iteration 8, loss = 0.26152420
# Validation score: 0.885520
# Iteration 9, loss = 0.25706855
# Validation score: 0.889128
# Iteration 10, loss = 0.25309249
# Validation score: 0.891444
# Iteration 11, loss = 0.24909851
# Validation score: 0.896398
# Iteration 12, loss = 0.24584880
# Validation score: 0.895536
# Iteration 13, loss = 0.24221001
# Validation score: 0.899844
# Iteration 14, loss = 0.23823679
# Validation score: 0.899305
# Iteration 15, loss = 0.23471503
# Validation score: 0.901405
# Iteration 16, loss = 0.23149891
# Validation score: 0.893167
# Iteration 17, loss = 0.22823615
# Validation score: 0.906790
# Iteration 18, loss = 0.22502431
# Validation score: 0.909536
# Iteration 19, loss = 0.22227681
# Validation score: 0.913036
# Iteration 20, loss = 0.21942708
# Validation score: 0.901567
# Iteration 21, loss = 0.21601068
# Validation score: 0.910667
# Iteration 22, loss = 0.21315942
# Validation score: 0.914706
# Iteration 23, loss = 0.21042599
# Validation score: 0.909698
# Iteration 24, loss = 0.20773339
# Validation score: 0.915729
# Iteration 25, loss = 0.20556301
# Validation score: 0.912336
# Iteration 26, loss = 0.20345619
# Validation score: 0.909375
# Iteration 27, loss = 0.20042840
# Validation score: 0.919552
# Iteration 28, loss = 0.19833104
# Validation score: 0.915837
# Iteration 29, loss = 0.19578737
# Validation score: 0.923052
# Iteration 30, loss = 0.19343646
# Validation score: 0.922729
# Iteration 31, loss = 0.19144616
# Validation score: 0.924398
# Iteration 32, loss = 0.18895088
# Validation score: 0.920898
# Iteration 33, loss = 0.18693901
# Validation score: 0.924667
# Iteration 34, loss = 0.18533666
# Validation score: 0.920252
# Iteration 35, loss = 0.18272047
# Validation score: 0.926929
# Iteration 36, loss = 0.18104511
# Validation score: 0.930483
# Iteration 37, loss = 0.17820462
# Validation score: 0.931129
# Iteration 38, loss = 0.17666419
# Validation score: 0.929029
# Iteration 39, loss = 0.17461908
# Validation score: 0.925583
# Iteration 40, loss = 0.17364099
# Validation score: 0.929406
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.001000
# Iteration 41, loss = 0.15842539
# Validation score: 0.940552
# Iteration 42, loss = 0.15648940
# Validation score: 0.937860
# Iteration 43, loss = 0.15592928
# Validation score: 0.939529
# Iteration 44, loss = 0.15540800
# Validation score: 0.941522
# Iteration 45, loss = 0.15480341
# Validation score: 0.938991
# Iteration 46, loss = 0.15407983
# Validation score: 0.940499
# Iteration 47, loss = 0.15394423
# Validation score: 0.939960
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000200
# Iteration 48, loss = 0.15073677
# Validation score: 0.942114
# Iteration 49, loss = 0.15030619
# Validation score: 0.941576
# Iteration 50, loss = 0.15018069
# Validation score: 0.942383
# Iteration 51, loss = 0.15012414
# Validation score: 0.942868
# Iteration 52, loss = 0.15004019
# Validation score: 0.942491
# Iteration 53, loss = 0.14990272
# Validation score: 0.941737
# Iteration 54, loss = 0.14975960
# Validation score: 0.943137
# Iteration 55, loss = 0.14968653
# Validation score: 0.942706
# Iteration 56, loss = 0.14954993
# Validation score: 0.942060
# Iteration 57, loss = 0.14948216
# Validation score: 0.942868
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000040
# Iteration 58, loss = 0.14876542
# Validation score: 0.943029
# Iteration 59, loss = 0.14869524
# Validation score: 0.942976
# Iteration 60, loss = 0.14866557
# Validation score: 0.942599
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000008
# Iteration 61, loss = 0.14849698
# Validation score: 0.942599
# Iteration 62, loss = 0.14848954
# Validation score: 0.942868
# Iteration 63, loss = 0.14848270
# Validation score: 0.943191
# Iteration 64, loss = 0.14847703
# Validation score: 0.942706
# Iteration 65, loss = 0.14847211
# Validation score: 0.943083
# Iteration 66, loss = 0.14846466
# Validation score: 0.942976
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000002
# Iteration 67, loss = 0.14843051
# Validation score: 0.942922
# Iteration 68, loss = 0.14842637
# Validation score: 0.942976
# Iteration 69, loss = 0.14842431
# Validation score: 0.942922
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000000
# Iteration 70, loss = 0.14841514
# Validation score: 0.942922
# Iteration 71, loss = 0.14841498
# Validation score: 0.942976
# Iteration 72, loss = 0.14841483
# Validation score: 0.942976
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Learning rate too small. Stopping.
# Training Results
#              precision    recall  f1-score   support
#
#         10K     0.7834    0.8351    0.8085     19173
#          1K     0.9782    0.9739    0.9761     92142
#          5K     0.8157    0.7735    0.7940     16172
#        COOH     0.9979    0.9976    0.9977     58214
#
# avg / total     0.9501    0.9495    0.9497    185701
#
# Test Results
#
#              precision    recall  f1-score   support
#
#         10K     0.3524    0.5105    0.4170      6643
#          1K     0.2493    0.1804    0.2093      7933
#          5K     0.3297    0.3471    0.3382      8981
#        COOH     0.9490    0.4064    0.5691      2200
#
# avg / total     0.3637    0.3429    0.3385     25757

# %%
X_train = pcadataset.final[pcadataset.final['Slices'].isin(['1', '3'])].values[:, -ncomp:] 
X_test = pcadataset.final[pcadataset.final['Slices']=='2'].values[:, -ncomp:]
y_train = pcadataset.final[pcadataset.final['Slices'].isin(['1', '3'])][featofvar].values
y_test = pcadataset.final[pcadataset.final['Slices']=='2'][featofvar].values

for run in range(1):
    #X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.4)

    clf = MLPClassifier(hidden_layer_sizes=(900, ), solver='sgd', verbose=True, max_iter=300, tol=0.00001,
                        alpha=0.001, batch_size=100, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))
# Out:
# Iteration 1, loss = 0.36119190
# Validation score: 0.856850
# Iteration 2, loss = 0.30415119
# Validation score: 0.867063
# Iteration 3, loss = 0.28929671
# Validation score: 0.866036
# Iteration 4, loss = 0.28099541
# Validation score: 0.874304
# Iteration 5, loss = 0.27496853
# Validation score: 0.874358
# Iteration 6, loss = 0.27037372
# Validation score: 0.878411
# Iteration 7, loss = 0.26638801
# Validation score: 0.879168
# Iteration 8, loss = 0.26284095
# Validation score: 0.883491
# Iteration 9, loss = 0.25939025
# Validation score: 0.878952
# Iteration 10, loss = 0.25636194
# Validation score: 0.878087
# Iteration 11, loss = 0.25312970
# Validation score: 0.884950
# Iteration 12, loss = 0.25083644
# Validation score: 0.888246
# Iteration 13, loss = 0.24775059
# Validation score: 0.888949
# Iteration 14, loss = 0.24497343
# Validation score: 0.890948
# Iteration 15, loss = 0.24239552
# Validation score: 0.890030
# Iteration 16, loss = 0.23997752
# Validation score: 0.890732
# Iteration 17, loss = 0.23757680
# Validation score: 0.896406
# Iteration 18, loss = 0.23474224
# Validation score: 0.896352
# Iteration 19, loss = 0.23224160
# Validation score: 0.893596
# Iteration 20, loss = 0.22963571
# Validation score: 0.900567
# Iteration 21, loss = 0.22748551
# Validation score: 0.899973
# Iteration 22, loss = 0.22482986
# Validation score: 0.902297
# Iteration 23, loss = 0.22211836
# Validation score: 0.901864
# Iteration 24, loss = 0.21978685
# Validation score: 0.905647
# Iteration 25, loss = 0.21709767
# Validation score: 0.902945
# Iteration 26, loss = 0.21514556
# Validation score: 0.905755
# Iteration 27, loss = 0.21239395
# Validation score: 0.908727
# Iteration 28, loss = 0.21012338
# Validation score: 0.909754
# Iteration 29, loss = 0.20779127
# Validation score: 0.912348
# Iteration 30, loss = 0.20560289
# Validation score: 0.913753
# Iteration 31, loss = 0.20320561
# Validation score: 0.913267
# Iteration 32, loss = 0.20161026
# Validation score: 0.911808
# Iteration 33, loss = 0.19903822
# Validation score: 0.914023
# Iteration 34, loss = 0.19706715
# Validation score: 0.912510
# Iteration 35, loss = 0.19510844
# Validation score: 0.914834
# Iteration 36, loss = 0.19298592
# Validation score: 0.910889
# Iteration 37, loss = 0.19084950
# Validation score: 0.916239
# Iteration 38, loss = 0.18850873
# Validation score: 0.918292
# Iteration 39, loss = 0.18651260
# Validation score: 0.923372
# Iteration 40, loss = 0.18497224
# Validation score: 0.924831
# Iteration 41, loss = 0.18198600
# Validation score: 0.922670
# Iteration 42, loss = 0.18078638
# Validation score: 0.918833
# Iteration 43, loss = 0.17936673
# Validation score: 0.922778
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.001000
# Iteration 44, loss = 0.16316345
# Validation score: 0.932883
# Iteration 45, loss = 0.16164996
# Validation score: 0.936017
# Iteration 46, loss = 0.16066603
# Validation score: 0.931802
# Iteration 47, loss = 0.16034645
# Validation score: 0.933477
# Iteration 48, loss = 0.15939629
# Validation score: 0.936936
# Iteration 49, loss = 0.15900000
# Validation score: 0.936342
# Iteration 50, loss = 0.15844913
# Validation score: 0.937476
# Iteration 51, loss = 0.15805709
# Validation score: 0.935855
# Iteration 52, loss = 0.15754513
# Validation score: 0.935261
# Iteration 53, loss = 0.15700308
# Validation score: 0.935963
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000200
# Iteration 54, loss = 0.15370801
# Validation score: 0.937638
# Iteration 55, loss = 0.15331575
# Validation score: 0.938125
# Iteration 56, loss = 0.15316041
# Validation score: 0.937530
# Iteration 57, loss = 0.15300561
# Validation score: 0.937206
# Iteration 58, loss = 0.15294564
# Validation score: 0.938611
# Iteration 59, loss = 0.15280561
# Validation score: 0.937368
# Iteration 60, loss = 0.15266309
# Validation score: 0.940178
# Iteration 61, loss = 0.15255516
# Validation score: 0.938611
# Iteration 62, loss = 0.15252482
# Validation score: 0.938233
# Iteration 63, loss = 0.15235822
# Validation score: 0.939044
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000040
# Iteration 64, loss = 0.15164282
# Validation score: 0.939044
# Iteration 65, loss = 0.15151456
# Validation score: 0.938449
# Iteration 66, loss = 0.15151859
# Validation score: 0.938773
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000008
# Iteration 67, loss = 0.15134169
# Validation score: 0.938989
# Iteration 68, loss = 0.15132794
# Validation score: 0.939044
# Iteration 69, loss = 0.15132132
# Validation score: 0.938989
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000002
# Iteration 70, loss = 0.15127629
# Validation score: 0.938935
# Iteration 71, loss = 0.15127588
# Validation score: 0.939044
# Iteration 72, loss = 0.15127379
# Validation score: 0.939044
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000000
# Iteration 73, loss = 0.15126433
# Validation score: 0.939044
# Iteration 74, loss = 0.15126391
# Validation score: 0.938989
# Iteration 75, loss = 0.15126365
# Validation score: 0.938989
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Learning rate too small. Stopping.
# Training Results
#              precision    recall  f1-score   support
#
#         10K     0.7885    0.7944    0.7914     15271
#          1K     0.9720    0.9735    0.9727     93405
#          5K     0.8065    0.7998    0.8031     18146
#        COOH     0.9955    0.9937    0.9946     58222
#
# avg / total     0.9480    0.9480    0.9480    185044
#
# Test Results
#
#              precision    recall  f1-score   support
#
#         10K     0.4468    0.3872    0.4149     10545
#          1K     0.2242    0.1226    0.1585      6670
#          5K     0.3102    0.5052    0.3844      7007
#        COOH     0.9847    0.9954    0.9900      2192
#
# avg / total     0.3990    0.4022    0.3898     26414

# %%
X_train = pcadataset.final[pcadataset.final['Slices'].isin(['2', '3'])].values[:, -ncomp:] 
X_test = pcadataset.final[pcadataset.final['Slices']=='1'].values[:, -ncomp:]
y_train = pcadataset.final[pcadataset.final['Slices'].isin(['2', '3'])][featofvar].values
y_test = pcadataset.final[pcadataset.final['Slices']=='1'][featofvar].values

for run in range(1):
    #X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.4)

    clf = MLPClassifier(hidden_layer_sizes=(900, ), solver='sgd', verbose=True, max_iter=300, tol=0.00001,
                        alpha=0.001, batch_size=100, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))
# Out:
# Iteration 1, loss = 1.01784535
# Validation score: 0.517440
# Iteration 2, loss = 0.95550527
# Validation score: 0.532388
# Iteration 3, loss = 0.93691040
# Validation score: 0.536987
# Iteration 4, loss = 0.92365238
# Validation score: 0.550211
# Iteration 5, loss = 0.91231640
# Validation score: 0.547336
# Iteration 6, loss = 0.90133915
# Validation score: 0.560751
# Iteration 7, loss = 0.89176903
# Validation score: 0.561326
# Iteration 8, loss = 0.88226809
# Validation score: 0.572058
# Iteration 9, loss = 0.87205864
# Validation score: 0.583940
# Iteration 10, loss = 0.86276352
# Validation score: 0.584707
# Iteration 11, loss = 0.85367148
# Validation score: 0.587581
# Iteration 12, loss = 0.84481089
# Validation score: 0.598122
# Iteration 13, loss = 0.83676219
# Validation score: 0.610387
# Iteration 14, loss = 0.82568423
# Validation score: 0.603105
# Iteration 15, loss = 0.81795466
# Validation score: 0.626485
# Iteration 16, loss = 0.80785762
# Validation score: 0.634918
# Iteration 17, loss = 0.79984952
# Validation score: 0.636067
# Iteration 18, loss = 0.79092096
# Validation score: 0.630510
# Iteration 19, loss = 0.78210008
# Validation score: 0.650249
# Iteration 20, loss = 0.77219781
# Validation score: 0.638750
# Iteration 21, loss = 0.76355294
# Validation score: 0.651016
# Iteration 22, loss = 0.75602100
# Validation score: 0.650632
# Iteration 23, loss = 0.74605716
# Validation score: 0.667114
# Iteration 24, loss = 0.73961842
# Validation score: 0.676121
# Iteration 25, loss = 0.73066048
# Validation score: 0.669030
# Iteration 26, loss = 0.72193069
# Validation score: 0.672863
# Iteration 27, loss = 0.71149782
# Validation score: 0.691644
# Iteration 28, loss = 0.70435298
# Validation score: 0.694711
# Iteration 29, loss = 0.69598242
# Validation score: 0.697777
# Iteration 30, loss = 0.68964384
# Validation score: 0.696819
# Iteration 31, loss = 0.67922206
# Validation score: 0.711000
# Iteration 32, loss = 0.67182133
# Validation score: 0.719433
# Iteration 33, loss = 0.66660403
# Validation score: 0.693561
# Iteration 34, loss = 0.65640902
# Validation score: 0.721158
# Iteration 35, loss = 0.64968915
# Validation score: 0.732081
# Iteration 36, loss = 0.64239599
# Validation score: 0.721924
# Iteration 37, loss = 0.63394377
# Validation score: 0.732465
# Iteration 38, loss = 0.62751840
# Validation score: 0.746838
# Iteration 39, loss = 0.62051450
# Validation score: 0.737639
# Iteration 40, loss = 0.61216978
# Validation score: 0.714258
# Iteration 41, loss = 0.60554517
# Validation score: 0.717516
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.001000
# Iteration 42, loss = 0.56625724
# Validation score: 0.767344
# Iteration 43, loss = 0.55835737
# Validation score: 0.771560
# Iteration 44, loss = 0.55759079
# Validation score: 0.773668
# Iteration 45, loss = 0.55458358
# Validation score: 0.767727
# Iteration 46, loss = 0.55290403
# Validation score: 0.766577
# Iteration 47, loss = 0.55098281
# Validation score: 0.772327
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000200
# Iteration 48, loss = 0.54138945
# Validation score: 0.781717
# Iteration 49, loss = 0.54018660
# Validation score: 0.784400
# Iteration 50, loss = 0.53951433
# Validation score: 0.784400
# Iteration 51, loss = 0.53909685
# Validation score: 0.783250
# Iteration 52, loss = 0.53877641
# Validation score: 0.783825
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000040
# Iteration 53, loss = 0.53685192
# Validation score: 0.785550
# Iteration 54, loss = 0.53633748
# Validation score: 0.785742
# Iteration 55, loss = 0.53628617
# Validation score: 0.784592
# Iteration 56, loss = 0.53617273
# Validation score: 0.782867
# Iteration 57, loss = 0.53607815
# Validation score: 0.784783
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000008
# Iteration 58, loss = 0.53554815
# Validation score: 0.784400
# Iteration 59, loss = 0.53550322
# Validation score: 0.783634
# Iteration 60, loss = 0.53546332
# Validation score: 0.784400
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000002
# Iteration 61, loss = 0.53535008
# Validation score: 0.784209
# Iteration 62, loss = 0.53534035
# Validation score: 0.784592
# Iteration 63, loss = 0.53533409
# Validation score: 0.784400
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000000
# Iteration 64, loss = 0.53530287
# Validation score: 0.784209
# Iteration 65, loss = 0.53530182
# Validation score: 0.784209
# Iteration 66, loss = 0.53530116
# Validation score: 0.784209
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Learning rate too small. Stopping.
# Training Results
#              precision    recall  f1-score   support
#
#         10K     0.7882    0.8547    0.8201     17188
#          1K     0.7850    0.7425    0.7631     14603
#          5K     0.8049    0.7695    0.7868     15988
#        COOH     0.9703    0.9802    0.9752      4392
#
# avg / total     0.8078    0.8077    0.8070     52171
#
# Test Results
#
#              precision    recall  f1-score   support
#
#         10K     0.0926    0.3885    0.1496      8628
#          1K     0.3884    0.0358    0.0656     85472
#          5K     0.0936    0.3130    0.1441      9165
#        COOH     0.6586    0.9940    0.7923     56022
#
# avg / total     0.4504    0.4079    0.3302    159287

# %%
X_train = pcadataset.final[pcadataset.final['Slices'].isin(['1', '3'])].values[:, -ncomp:] 
X_test = pcadataset.final[pcadataset.final['Slices']=='2'].values[:, -ncomp:]
y_train = pcadataset.final[pcadataset.final['Slices'].isin(['1', '3'])][featofvar].replace(['10K', '5K'], 'HI').values
y_test = pcadataset.final[pcadataset.final['Slices']=='2'][featofvar].replace(['10K', '5K'], 'HI').values

for run in range(1):
    #X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.4)

    clf = MLPClassifier(hidden_layer_sizes=(900, ), solver='sgd', verbose=True, max_iter=300, tol=0.00001,
                        alpha=0.001, batch_size=100, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))
# Out:
# Iteration 1, loss = 0.23305137
# Validation score: 0.918076
# Iteration 2, loss = 0.18334301
# Validation score: 0.926452
# Iteration 3, loss = 0.17039439
# Validation score: 0.929857
# Iteration 4, loss = 0.16338765
# Validation score: 0.931424
# Iteration 5, loss = 0.15825223
# Validation score: 0.933099
# Iteration 6, loss = 0.15484778
# Validation score: 0.933694
# Iteration 7, loss = 0.15162888
# Validation score: 0.938773
# Iteration 8, loss = 0.14904857
# Validation score: 0.938773
# Iteration 9, loss = 0.14640739
# Validation score: 0.940394
# Iteration 10, loss = 0.14435227
# Validation score: 0.939746
# Iteration 11, loss = 0.14208013
# Validation score: 0.940394
# Iteration 12, loss = 0.14039998
# Validation score: 0.944610
# Iteration 13, loss = 0.13861709
# Validation score: 0.943799
# Iteration 14, loss = 0.13679877
# Validation score: 0.941475
# Iteration 15, loss = 0.13458675
# Validation score: 0.946177
# Iteration 16, loss = 0.13339190
# Validation score: 0.944772
# Iteration 17, loss = 0.13147280
# Validation score: 0.945907
# Iteration 18, loss = 0.12982587
# Validation score: 0.943907
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.001000
# Iteration 19, loss = 0.12329973
# Validation score: 0.950608
# Iteration 20, loss = 0.12230018
# Validation score: 0.950878
# Iteration 21, loss = 0.12173195
# Validation score: 0.951256
# Iteration 22, loss = 0.12136895
# Validation score: 0.952553
# Iteration 23, loss = 0.12088390
# Validation score: 0.952715
# Iteration 24, loss = 0.12032864
# Validation score: 0.952824
# Iteration 25, loss = 0.11998753
# Validation score: 0.952878
# Iteration 26, loss = 0.11947671
# Validation score: 0.953094
# Iteration 27, loss = 0.11919011
# Validation score: 0.952932
# Iteration 28, loss = 0.11863740
# Validation score: 0.952391
# Iteration 29, loss = 0.11831440
# Validation score: 0.952229
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000200
# Iteration 30, loss = 0.11678524
# Validation score: 0.954012
# Iteration 31, loss = 0.11650167
# Validation score: 0.954283
# Iteration 32, loss = 0.11641499
# Validation score: 0.954066
# Iteration 33, loss = 0.11634437
# Validation score: 0.953580
# Iteration 34, loss = 0.11624357
# Validation score: 0.953958
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000040
# Iteration 35, loss = 0.11587415
# Validation score: 0.954175
# Iteration 36, loss = 0.11584560
# Validation score: 0.954391
# Iteration 37, loss = 0.11582248
# Validation score: 0.954012
# Iteration 38, loss = 0.11579681
# Validation score: 0.954337
# Iteration 39, loss = 0.11577623
# Validation score: 0.954229
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000008
# Iteration 40, loss = 0.11570590
# Validation score: 0.954121
# Iteration 41, loss = 0.11569432
# Validation score: 0.954066
# Iteration 42, loss = 0.11568818
# Validation score: 0.954175
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000002
# Iteration 43, loss = 0.11566784
# Validation score: 0.954175
# Iteration 44, loss = 0.11566665
# Validation score: 0.954175
# Iteration 45, loss = 0.11566558
# Validation score: 0.954066
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000000
# Iteration 46, loss = 0.11566104
# Validation score: 0.954012
# Iteration 47, loss = 0.11566095
# Validation score: 0.954012
# Iteration 48, loss = 0.11566068
# Validation score: 0.954012
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Learning rate too small. Stopping.
# Training Results
#              precision    recall  f1-score   support
#
#          1K     0.9622    0.9517    0.9569     93405
#        COOH     0.9929    0.9887    0.9908     58222
#          HI     0.8771    0.9103    0.8934     33417
#
# avg / total     0.9565    0.9559    0.9561    185044
#
# Test Results
#
#              precision    recall  f1-score   support
#
#          1K     0.2040    0.0879    0.1228      6670
#        COOH     0.9900    0.9964    0.9932      2192
#          HI     0.7150    0.8691    0.7846     17552
#
# avg / total     0.6088    0.6824    0.6348     26414

# %%
featofvar = 'Particle Type'
X_train = pcadataset.final[pcadataset.final['Slices'].isin(['2', '3'])].values[:, -ncomp:] 
X_test = pcadataset.final[pcadataset.final['Slices']=='1'].values[:, -ncomp:]
y_train = pcadataset.final[pcadataset.final['Slices'].isin(['2', '3'])][featofvar].replace(['10K', '5K'], 'HI').values
y_test = pcadataset.final[pcadataset.final['Slices']=='1'][featofvar].replace(['10K', '5K'], 'HI').values

for run in range(1):
    #X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.4)

    clf = MLPClassifier(hidden_layer_sizes=(900, ), solver='sgd', verbose=True, max_iter=300, tol=0.00001,
                        alpha=0.001, batch_size=100, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))
# Out:
# Iteration 1, loss = 0.60303263
# Validation score: 0.725182
# Iteration 2, loss = 0.55769182
# Validation score: 0.725374
# Iteration 3, loss = 0.54775922
# Validation score: 0.736297
# Iteration 4, loss = 0.54094368
# Validation score: 0.733039
# Iteration 5, loss = 0.53555842
# Validation score: 0.735914
# Iteration 6, loss = 0.53097359
# Validation score: 0.729207
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.001000
# Iteration 7, loss = 0.52384093
# Validation score: 0.739939
# Iteration 8, loss = 0.52163238
# Validation score: 0.741855
# Iteration 9, loss = 0.52059371
# Validation score: 0.742238
# Iteration 10, loss = 0.51939573
# Validation score: 0.739747
# Iteration 11, loss = 0.51814910
# Validation score: 0.745305
# Iteration 12, loss = 0.51717036
# Validation score: 0.746838
# Iteration 13, loss = 0.51604789
# Validation score: 0.749138
# Iteration 14, loss = 0.51493541
# Validation score: 0.747604
# Iteration 15, loss = 0.51388778
# Validation score: 0.746646
# Iteration 16, loss = 0.51283726
# Validation score: 0.748563
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000200
# Iteration 17, loss = 0.51068095
# Validation score: 0.749138
# Iteration 18, loss = 0.51023576
# Validation score: 0.747030
# Iteration 19, loss = 0.51009180
# Validation score: 0.751054
# Iteration 20, loss = 0.50981992
# Validation score: 0.747221
# Iteration 21, loss = 0.50961086
# Validation score: 0.748946
# Iteration 22, loss = 0.50937470
# Validation score: 0.749138
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000040
# Iteration 23, loss = 0.50885042
# Validation score: 0.749521
# Iteration 24, loss = 0.50878712
# Validation score: 0.749521
# Iteration 25, loss = 0.50873958
# Validation score: 0.749521
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000008
# Iteration 26, loss = 0.50862068
# Validation score: 0.749138
# Iteration 27, loss = 0.50861170
# Validation score: 0.749138
# Iteration 28, loss = 0.50859579
# Validation score: 0.749138
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000002
# Iteration 29, loss = 0.50856910
# Validation score: 0.749713
# Iteration 30, loss = 0.50856772
# Validation score: 0.749713
# Iteration 31, loss = 0.50856575
# Validation score: 0.749713
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000000
# Iteration 32, loss = 0.50855968
# Validation score: 0.749713
# Iteration 33, loss = 0.50855917
# Validation score: 0.749713
# Iteration 34, loss = 0.50855895
# Validation score: 0.749521
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Learning rate too small. Stopping.
# Training Results
#              precision    recall  f1-score   support
#
#          1K     0.6561    0.2739    0.3865     14603
#        COOH     0.9604    0.9556    0.9580      4392
#          HI     0.7433    0.9344    0.8279     33176
#
# avg / total     0.7371    0.7513    0.7153     52171
#
# Test Results
#
#              precision    recall  f1-score   support
#
#          1K     0.1375    0.0045    0.0087     85472
#        COOH     0.7280    0.9995    0.8424     56022
#          HI     0.1923    0.8601    0.3144     17793
#
# avg / total     0.3513    0.4500    0.3361    159287

# %%
featofvar = 'Particle Type'
X_train = pcadataset.final[pcadataset.final['Slices'].isin(['2', '1'])].values[:, -ncomp:] 
X_test = pcadataset.final[pcadataset.final['Slices']=='3'].values[:, -ncomp:]
y_train = pcadataset.final[pcadataset.final['Slices'].isin(['2', '1'])][featofvar].replace(['10K', '5K'], 'HI').values
y_test = pcadataset.final[pcadataset.final['Slices']=='3'][featofvar].replace(['10K', '5K'], 'HI').values

for run in range(1):
    #X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.4)

    clf = MLPClassifier(hidden_layer_sizes=(900, ), solver='sgd', verbose=True, max_iter=300, tol=0.00001,
                        alpha=0.001, batch_size=100, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))
# Out:
# Iteration 1, loss = 0.21757584
# Validation score: 0.928975
# Iteration 2, loss = 0.17832665
# Validation score: 0.935922
# Iteration 3, loss = 0.16813908
# Validation score: 0.937537
# Iteration 4, loss = 0.16145795
# Validation score: 0.939906
# Iteration 5, loss = 0.15626056
# Validation score: 0.939852
# Iteration 6, loss = 0.15170548
# Validation score: 0.942168
# Iteration 7, loss = 0.14765302
# Validation score: 0.945291
# Iteration 8, loss = 0.14374095
# Validation score: 0.948791
# Iteration 9, loss = 0.14060552
# Validation score: 0.945237
# Iteration 10, loss = 0.13715347
# Validation score: 0.946530
# Iteration 11, loss = 0.13431309
# Validation score: 0.949599
# Iteration 12, loss = 0.13170297
# Validation score: 0.946691
# Iteration 13, loss = 0.12904146
# Validation score: 0.954660
# Iteration 14, loss = 0.12628190
# Validation score: 0.956384
# Iteration 15, loss = 0.12377986
# Validation score: 0.951430
# Iteration 16, loss = 0.12177071
# Validation score: 0.954714
# Iteration 17, loss = 0.11957971
# Validation score: 0.957945
# Iteration 18, loss = 0.11714368
# Validation score: 0.960584
# Iteration 19, loss = 0.11511308
# Validation score: 0.956653
# Iteration 20, loss = 0.11361152
# Validation score: 0.958322
# Iteration 21, loss = 0.11133013
# Validation score: 0.959022
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.001000
# Iteration 22, loss = 0.10459510
# Validation score: 0.961391
# Iteration 23, loss = 0.10346403
# Validation score: 0.964191
# Iteration 24, loss = 0.10285633
# Validation score: 0.963491
# Iteration 25, loss = 0.10239575
# Validation score: 0.963384
# Iteration 26, loss = 0.10183282
# Validation score: 0.962468
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000200
# Iteration 27, loss = 0.10039747
# Validation score: 0.964568
# Iteration 28, loss = 0.10017780
# Validation score: 0.964838
# Iteration 29, loss = 0.10001580
# Validation score: 0.965268
# Iteration 30, loss = 0.09992406
# Validation score: 0.964407
# Iteration 31, loss = 0.09983336
# Validation score: 0.964730
# Iteration 32, loss = 0.09969110
# Validation score: 0.965161
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000040
# Iteration 33, loss = 0.09936160
# Validation score: 0.964945
# Iteration 34, loss = 0.09932705
# Validation score: 0.964838
# Iteration 35, loss = 0.09930132
# Validation score: 0.964568
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000008
# Iteration 36, loss = 0.09922481
# Validation score: 0.964730
# Iteration 37, loss = 0.09921358
# Validation score: 0.964891
# Iteration 38, loss = 0.09920689
# Validation score: 0.964676
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000002
# Iteration 39, loss = 0.09918634
# Validation score: 0.964730
# Iteration 40, loss = 0.09918546
# Validation score: 0.964838
# Iteration 41, loss = 0.09918427
# Validation score: 0.964784
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000000
# Iteration 42, loss = 0.09918004
# Validation score: 0.964838
# Iteration 43, loss = 0.09917981
# Validation score: 0.964838
# Iteration 44, loss = 0.09917966
# Validation score: 0.964838
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Learning rate too small. Stopping.
# Training Results
#              precision    recall  f1-score   support
#
#          1K     0.9800    0.9515    0.9655     92142
#        COOH     0.9972    0.9967    0.9969     58214
#          HI     0.8857    0.9536    0.9184     35345
#
# avg / total     0.9674    0.9660    0.9664    185701
#
# Test Results
#
#              precision    recall  f1-score   support
#
#          1K     0.2235    0.1165    0.1531      7933
#        COOH     0.9346    0.3573    0.5169      2200
#          HI     0.6467    0.8602    0.7383     15624
#
# avg / total     0.5410    0.5882    0.5392     25757

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots()
ax1.plot(clf.loss_curve_, linewidth=4)
#ax1.set_xlim([0, 60])
#ax1.set_ylim([0.04, 0.18])
ax1.set_ylabel('Loss Curve')

ax2 = ax1.twinx()
ax2.plot(clf.validation_scores_, linewidth=4, c='g')
#ax2.set_ylim([0.65, 0.75])
ax2.set_ylabel('Validation Scores')
# Out:
# Text(0,0.5,'Validation Scores')

# %%
X_train = pcadataset.final[pcadataset.final['Slices'].isin(['1', '3'])].values[:, -ncomp:] 
X_test = pcadataset.final[pcadataset.final['Slices']=='2'].values[:, -ncomp:]
y_train = pcadataset.final[pcadataset.final['Slices'].isin(['1', '3'])][featofvar].replace(['1K', '5K'], 'MID').values
y_test = pcadataset.final[pcadataset.final['Slices']=='2'][featofvar].replace(['1K', '5K'], 'MID').values

for run in range(1):
    #X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.4)

    clf = MLPClassifier(hidden_layer_sizes=(900, ), solver='sgd', verbose=True, max_iter=300, tol=0.00001,
                        alpha=0.001, batch_size=100, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))
# Out:
# Iteration 1, loss = 0.23008825
# Validation score: 0.907268
# Iteration 2, loss = 0.19715399
# Validation score: 0.908241
# Iteration 3, loss = 0.19002165
# Validation score: 0.908998
# Iteration 4, loss = 0.18536089
# Validation score: 0.911591
# Iteration 5, loss = 0.18146011
# Validation score: 0.914239
# Iteration 6, loss = 0.17820713
# Validation score: 0.912132
# Iteration 7, loss = 0.17523376
# Validation score: 0.914888
# Iteration 8, loss = 0.17274548
# Validation score: 0.915644
# Iteration 9, loss = 0.17039610
# Validation score: 0.915050
# Iteration 10, loss = 0.16783102
# Validation score: 0.919535
# Iteration 11, loss = 0.16549746
# Validation score: 0.920292
# Iteration 12, loss = 0.16357235
# Validation score: 0.923210
# Iteration 13, loss = 0.16142061
# Validation score: 0.922886
# Iteration 14, loss = 0.15917245
# Validation score: 0.922616
# Iteration 15, loss = 0.15694512
# Validation score: 0.924507
# Iteration 16, loss = 0.15485230
# Validation score: 0.924777
# Iteration 17, loss = 0.15305720
# Validation score: 0.927587
# Iteration 18, loss = 0.15119908
# Validation score: 0.928344
# Iteration 19, loss = 0.14905660
# Validation score: 0.930938
# Iteration 20, loss = 0.14694777
# Validation score: 0.932072
# Iteration 21, loss = 0.14512274
# Validation score: 0.935315
# Iteration 22, loss = 0.14323116
# Validation score: 0.935207
# Iteration 23, loss = 0.14145076
# Validation score: 0.928560
# Iteration 24, loss = 0.13958611
# Validation score: 0.939206
# Iteration 25, loss = 0.13815957
# Validation score: 0.942448
# Iteration 26, loss = 0.13604283
# Validation score: 0.939368
# Iteration 27, loss = 0.13419055
# Validation score: 0.941800
# Iteration 28, loss = 0.13253192
# Validation score: 0.942448
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.001000
# Iteration 29, loss = 0.12392811
# Validation score: 0.946123
# Iteration 30, loss = 0.12283494
# Validation score: 0.946285
# Iteration 31, loss = 0.12216066
# Validation score: 0.947798
# Iteration 32, loss = 0.12190005
# Validation score: 0.946447
# Iteration 33, loss = 0.12131442
# Validation score: 0.945420
# Iteration 34, loss = 0.12084980
# Validation score: 0.948014
# Iteration 35, loss = 0.12032405
# Validation score: 0.947690
# Iteration 36, loss = 0.11997800
# Validation score: 0.947095
# Iteration 37, loss = 0.11941772
# Validation score: 0.950446
# Iteration 38, loss = 0.11887259
# Validation score: 0.948933
# Iteration 39, loss = 0.11859133
# Validation score: 0.947636
# Iteration 40, loss = 0.11810462
# Validation score: 0.950176
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000200
# Iteration 41, loss = 0.11617807
# Validation score: 0.950230
# Iteration 42, loss = 0.11585757
# Validation score: 0.950770
# Iteration 43, loss = 0.11574245
# Validation score: 0.951905
# Iteration 44, loss = 0.11562119
# Validation score: 0.950284
# Iteration 45, loss = 0.11556195
# Validation score: 0.950230
# Iteration 46, loss = 0.11542995
# Validation score: 0.949527
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000040
# Iteration 47, loss = 0.11503631
# Validation score: 0.950878
# Iteration 48, loss = 0.11496077
# Validation score: 0.951040
# Iteration 49, loss = 0.11494024
# Validation score: 0.951040
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000008
# Iteration 50, loss = 0.11483334
# Validation score: 0.950716
# Iteration 51, loss = 0.11482524
# Validation score: 0.950932
# Iteration 52, loss = 0.11481822
# Validation score: 0.950824
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000002
# Iteration 53, loss = 0.11479272
# Validation score: 0.950770
# Iteration 54, loss = 0.11479170
# Validation score: 0.950824
# Iteration 55, loss = 0.11479072
# Validation score: 0.950716
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Setting learning rate to 0.000000
# Iteration 56, loss = 0.11478518
# Validation score: 0.950716
# Iteration 57, loss = 0.11478491
# Validation score: 0.950716
# Iteration 58, loss = 0.11478467
# Validation score: 0.950716
# Validation score did not improve more than tol=0.000010 for two consecutive epochs. Learning rate too small. Stopping.
# Training Results
#              precision    recall  f1-score   support
#
#         10K     0.7958    0.6624    0.7230     15271
#        COOH     0.9943    0.9929    0.9936     58222
#         MID     0.9517    0.9742    0.9628    111551
#
# avg / total     0.9522    0.9544    0.9527    185044
#
# Test Results
#
#              precision    recall  f1-score   support
#
#         10K     0.4220    0.2937    0.3463     10545
#        COOH     0.9878    0.9954    0.9916      2192
#         MID     0.5585    0.6887    0.6168     13677
#
# avg / total     0.5396    0.5564    0.5399     26414

# %%
fig, ax1 = plt.subplots()
ax1.plot(clf.loss_curve_, linewidth=4)
#ax1.set_xlim([0, 60])
#ax1.set_ylim([0.04, 0.18])
ax1.set_ylabel('Loss Curve')

ax2 = ax1.twinx()
ax2.plot(clf.validation_scores_, linewidth=4, c='g')
#ax2.set_ylim([0.65, 0.75])
ax2.set_ylabel('Validation Scores')

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots()
ax1.plot(clf.loss_curve_, linewidth=4)
#ax1.set_xlim([0, 60])
#ax1.set_ylim([0.04, 0.18])
ax1.set_ylabel('Loss Curve')

ax2 = ax1.twinx()
ax2.plot(clf.validation_scores_, linewidth=4, c='g')
#ax2.set_ylim([0.65, 0.75])
ax2.set_ylabel('Validation Scores')

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots()
ax1.plot(clf.loss_curve_, linewidth=4)
#ax1.set_xlim([0, 60])
#ax1.set_ylim([0.04, 0.18])
ax1.set_ylabel('Loss Curve')

ax2 = ax1.twinx()
ax2.plot(clf.validation_scores_, linewidth=4, c='g')
ax2.set_ylim([0.65, 0.75])
ax2.set_ylabel('Validation Scores')

# %%
ncomp = 16
featofvar = 'Region'
test = pcadataset.final[pcadataset.final['Particle Type'] == 'PEG'].values[:, -ncomp:]
y = pcadataset.final[pcadataset.final['Particle Type'] == 'PEG'][featofvar].values
for run in range(1):
    X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.4)

    clf = MLPClassifier(hidden_layer_sizes=(600, ), solver='sgd', verbose=True, max_iter=500, tol=0.00001,
                        alpha=0.001, batch_size=50, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots()
ax1.plot(clf.loss_curve_, linewidth=4)
#ax1.set_xlim([0, 60])
#ax1.set_ylim([0.04, 0.18])
ax1.set_ylabel('Loss Curve')

ax2 = ax1.twinx()
ax2.plot(clf.validation_scores_, linewidth=4, c='g')
#ax2.set_ylim([0.65, 0.75])
ax2.set_ylabel('Validation Scores')

# %%
ncomp = 16
featofvar = 'Region'
test = pcadataset.final[pcadataset.final['Particle Type'] == 'PS'].values[:, -ncomp:]
y = pcadataset.final[pcadataset.final['Particle Type'] == 'PS'][featofvar].values
for run in range(1):
    X_train, X_test, y_train, y_test = train_test_split(test, y, test_size=0.4)

    clf = MLPClassifier(hidden_layer_sizes=(600, ), solver='sgd', verbose=True, max_iter=500, tol=0.00001,
                        alpha=0.001, batch_size=50, learning_rate_init=0.005, learning_rate='adaptive',
                        early_stopping=True, validation_fraction=0.1)

    clf.fit(X_train, y_train)
    
    print('Training Results')
    y_true1, y_pred1 = y_train, clf.predict(X_train)
    print(classification_report(y_true1, y_pred1, digits=4))
    
    print('Test Results')
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred, digits=4))

# %%
fig, ax1 = plt.subplots()
ax1.plot(clf.loss_curve_, linewidth=4)
#ax1.set_xlim([0, 60])
#ax1.set_ylim([0.04, 0.18])
ax1.set_ylabel('Loss Curve')

ax2 = ax1.twinx()
ax2.plot(clf.validation_scores_, linewidth=4, c='g')
#ax2.set_ylim([0.65, 0.75])
ax2.set_ylabel('Validation Scores')

# %%
pcadataset.final.hist(column=0, by='Region and Type', sharex=True, bins=np.linspace(-12, 12, 100),
                figsize=(9, 7), grid=False, layout=(6,1), sharey=True, )

# %%
y_true2 = fstats_tot['Region and Type'].values
labels3 = ['PEG_Cortex', 'PEG_']

size3 = np.random.rand(len(y_true2))
y_pred2 = list(pd.cut(size3, bins=[0, 0.1667, 0.3333, 0.5, 0.66667, 0.83333, 10], labels=mws).astype(str))
print(classification_report(y_true2, y_pred2, digits=4))

# %%
0.75/0.16667
