# %% [markdown]
# # Experiment Initialization

# %% [markdown]
# Here, I define the terms of my experiment, among them the location of the files in S3 (bucket and folder name), and each of the video prefixes (everything before the file extension) that I want to track.
#
# Note that these videos should be similar-ish: while we can account for differences in mean intensities between videos, particle sizes should be approximately the same, and (slightly less important) particles should be moving at about the same order of magnitude speed. In this experiment, these videos were taken in 0.4% agarose gel at 100x magnification and 100.02 fps shutter speeds with nanoparticles of about 100nm in diameter.

# %%
to_track = []
result_futures = {}
start_knot = 12 #Must be unique number for every run on Cloudknot.

remote_folder = '08_28_18_varying_PEG_redo' #Folder in AWS S3 containing files to be analyzed
bucket = 'evanepst.data'
vids = 10
covers = ['COOH', 'pt10xs', 'pt15xs', 'pt25xs', 'pt40xs']
for cover in covers:
    for num in range(1, vids+1):
        #to_track.append('100x_0_4_1_2_gel_{}_bulk_vid_{}'.format(vis, num))
        to_track.append('3mM_100_{}_XY{}'.format(cover, '%02d' % num))

# %%
to_track[5:]

# %% [markdown]
# The videos used with this analysis are fairly large (2048 x 2048 pixels and 651 frames), and in cases like this, the tracking algorithm can quickly eat up RAM. In this case, we chose to crop the videos to 512 x 512 images such that we can run our jobs on smaller EC2 instances with 16GB of RAM.
#
# Note that larger jobs can be made with user-defined functions such that splitting isn't necessary-- or perhaps an intermediate amount of memory that contains splitting, tracking, and msd calculation functions all performed on a single EC2 instance.
#
# The compiled functions in the knotlets module require access to buckets on AWS. In this case, we will be using a publicly (read-only) bucket. If users want to run this notebook on their own, will have to transfer files from nancelab.publicfiles to their own bucket, as it requires writing to S3 buckets.

# %%
import diff_classifier.knotlets as kn

# %%
for prefix in to_track[5:]:
    kn.split(prefix, remote_folder=remote_folder, bucket=bucket)

# %% [markdown]
# ## Tracking predictor

# %% [markdown]
# Tracking normally requires user input in the form of tracking parameters e.g. particle radius, linking max distance, max frame gap etc. When large datasets aren't required, each video can be manageably manually tracked using the TrackMate GUI. However, when datasets get large e.g. >20 videos, this can become extremely arduous. For videos that are fairly similar, you can get away with using similar tracking parameters across all videos. However, one parameter that is a little more noisy that the others is the quality filter value. Quality is a numerical value that approximate how likely a particle is to be "real."
#
# In this case, I built a predictor that estimates the quality filter value based on intensity distributions from the input images. Using a relatively small training dataset (5-20 videos), users can get fairly good estimates of quality filter values that can be used in parallelized tracking workflows.
#
# Note: in the current setup, the predictor should be run in Python 3. While the code will run in Python 3, there are differences between the random number generators in Python2 and Python3 that I was not able to control for.

# %%
import os
import diff_classifier.imagej as ij
import boto3
import os.path as op
import diff_classifier.aws as aws
import diff_classifier.knotlets as kn
import numpy as np
from sklearn.externals import joblib

# %% [markdown]
# The regress_sys function should be run twice. When have_output is set to False, it generates a list of files that the user should manually track using Trackmate. Once the quality filter values are found, they can be used as input (y) to generate a regress object that can predict quality filter values for additional videos. Once y is assigned, set have_output to True and re-run the cell.

# %%
tnum=12 #number of training datasets
pref = []
for num in to_track:                    
    for row in range(0, 4):
        for col in range(0, 4):
            pref.append("{}_{}_{}".format(num, row, col))

y = np.array([17.91, 23.53, 16.7, 18.5, 23, 25.12, 18.03, 16.4, 18.9, 28.58, 18.45, 22.5])

# Creates regression object based of training dataset composed of input images and manually
# calculated quality cutoffs from tracking with GUI interface.
regress = ij.regress_sys(remote_folder, pref, y, tnum, have_output=True, bucket_name=bucket)
#Read up on how regress_sys works before running.

# %%
#Pickle object
filename = 'regress.obj'
with open(filename,'wb') as fp:
    joblib.dump(regress,fp)

import boto3
s3 = boto3.client('s3')
aws.upload_s3(filename, remote_folder+'/'+filename, bucket_name=bucket)

# %% [markdown]
# Users should input all tracking parameters into the tparams object. Note that the quality value will be overwritten by values found using the quality predictor found above.

# %%
tparams = {'radius': 3.5, 'threshold': 0.0, 'do_median_filtering': False,
           'quality': 10.0, 'xdims': (0, 511), 'ydims': (1, 511),
           'median_intensity': 300.0, 'snr': 0.0, 'linking_max_distance': 12.0,
           'gap_closing_max_distance': 20.0, 'max_frame_gap': 6,
           'track_duration': 20.0}

# %% [markdown]
# ## Cloudknot setup

# %% [markdown]
# Cloudknot requires the user to define a function that will be sent to multiple computers to run. In this case, the function knotlets.tracking will be used. We create a docker image that has the required installations (defined by the requirements.txt file from diff_classifier on Github, and the base Docker Image below that has Fiji pre-installed in the correct location.
#
# Note that I modify the Docker image below such that the correct version of boto3 is installed. For some reason, versions later than 1.5.28 error out, so I specified 5.28 as the correct version. Run my_image.build below to double-check that the Docker image is successfully built prior to submitting the job to Cloudknot.

# %%
import cloudknot as ck
import os.path as op

github_installs=('https://github.com/ccurtis7/diff_classifier.git@Chad')
#my_image = ck.DockerImage(func=kn.tracking, base_image='arokem/python3-fiji:0.3', github_installs=github_installs)
my_image = ck.DockerImage(func=kn.tracking, base_image='arokem/python3-fiji:0.3', github_installs=github_installs)
docker_file = open(my_image.docker_path)
docker_string = docker_file.read()
docker_file.close()

req = open(op.join(op.split(my_image.docker_path)[0], 'requirements.txt'))
req_string = req.read()
req.close()

#Make sure to double-check that the cloudknot requirements file has boto3 version 1.5.28
new_req = req_string[0:req_string.find('\n')-3]+'5.28'+ req_string[req_string.find('\n'):]
req_overwrite = open(op.join(op.split(my_image.docker_path)[0], 'requirements.txt'), 'w')
req_overwrite.write(new_req)
req_overwrite.close()

# %%
my_image.build("0.1", image_name="test_image")

# %% [markdown]
# The object all_maps is an iterable containing all the inputs sent to Cloudknot. This is useful, because if the user needs to modify some of the tracking parameters for a single video, this can be done prior to submission to Cloudknot.

# %%
names = []
all_maps = []
for prefix in to_track:    
    for i in range(0, 4):
        for j in range(0, 4):
            names.append('{}_{}_{}'.format(prefix, i, j))
            all_maps.append(('{}_{}_{}'.format(prefix, i, j), remote_folder, bucket, 'regress.obj',
                             4, 4, (512, 512), tparams))

all_maps
# Out:
# [('3mM_100_COOH_XY01_0_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY01_0_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY01_0_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY01_0_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY01_1_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY01_1_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY01_1_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY01_1_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY01_2_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY01_2_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY01_2_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY01_2_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY01_3_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY01_3_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY01_3_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY01_3_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY02_0_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY02_0_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY02_0_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY02_0_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY02_1_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY02_1_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY02_1_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY02_1_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY02_2_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY02_2_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY02_2_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY02_2_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY02_3_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY02_3_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY02_3_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY02_3_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY03_0_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY03_0_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY03_0_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY03_0_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY03_1_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY03_1_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY03_1_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY03_1_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY03_2_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY03_2_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY03_2_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY03_2_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY03_3_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY03_3_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY03_3_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY03_3_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY04_0_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY04_0_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY04_0_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY04_0_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY04_1_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY04_1_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY04_1_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY04_1_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY04_2_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY04_2_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY04_2_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY04_2_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY04_3_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY04_3_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY04_3_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY04_3_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY05_0_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY05_0_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY05_0_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY05_0_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY05_1_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY05_1_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY05_1_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY05_1_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY05_2_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY05_2_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY05_2_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY05_2_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY05_3_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY05_3_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY05_3_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY05_3_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY06_0_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY06_0_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY06_0_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY06_0_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY06_1_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY06_1_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY06_1_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY06_1_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY06_2_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY06_2_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY06_2_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY06_2_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY06_3_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY06_3_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY06_3_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY06_3_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY07_0_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY07_0_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY07_0_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY07_0_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY07_1_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY07_1_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY07_1_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY07_1_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY07_2_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY07_2_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY07_2_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY07_2_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY07_3_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY07_3_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY07_3_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY07_3_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY08_0_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_COOH_XY08_0_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
# ...
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY08_2_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY08_3_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY08_3_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY08_3_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY08_3_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY09_0_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY09_0_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY09_0_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY09_0_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY09_1_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY09_1_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY09_1_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY09_1_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY09_2_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY09_2_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY09_2_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY09_2_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY09_3_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY09_3_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY09_3_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY09_3_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY10_0_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY10_0_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY10_0_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY10_0_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY10_1_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY10_1_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY10_1_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY10_1_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY10_2_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY10_2_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY10_2_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY10_2_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY10_3_0',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY10_3_1',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY10_3_2',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)}),
#  ('3mM_100_pt40xs_XY10_3_3',
#   '08_28_18_varying_PEG_redo',
#   'evanepst.data',
#   'regress.obj',
#   4,
#   4,
#   (512, 512),
#   {'do_median_filtering': False,
#    'gap_closing_max_distance': 20.0,
#    'linking_max_distance': 12.0,
#    'max_frame_gap': 6,
#    'median_intensity': 300.0,
#    'quality': 10.0,
#    'radius': 3.5,
#    'snr': 0.0,
#    'threshold': 0.0,
#    'track_duration': 20.0,
#    'xdims': (0, 511),
#    'ydims': (1, 511)})]

# %% [markdown]
# The Cloudknot knot object sets up the compute environment which will run the code. Note that the name must be unique. Every time you submit a new knot, you should change the name. I do this with the variable start_knot, which I vary for each run.
#
# If larger jobs are anticipated, users can adjust both RAM and storage with the memory and image_id variables. Memory specifies the amount of RAM to be used. Users can build a customized AMI with as much space as they need, and enter the ID into image_ID. Read the Cloudknot documentation for more details.

# %%
knot = ck.Knot(name='download_and_track_{}_b{}'.format('evan1', start_knot),
               docker_image = my_image,
               memory = 16000,
               resource_type = "SPOT",
               bid_percentage = 100,
               #image_id = 'ami-0e00afdf500081a0d', #May need to change this line
               pars_policies=('AmazonS3FullAccess',))

# %%
result_futures = knot.map(all_maps, starmap=True)

# %%
result_futures = knot.map(all_maps2, starmap=True)

# %%
knot.clobber()

# %%
tparams2 = {'radius': 3.5, 'threshold': 0.0, 'do_median_filtering': False,
           'quality': 10.0, 'xdims': (0, 511), 'ydims': (1, 511),
           'median_intensity': 300.0, 'snr': 0.0, 'linking_max_distance': 12.0,
           'gap_closing_max_distance': 18.0, 'max_frame_gap': 3,
           'track_duration': 20.0}

# %%
missing = []
all_maps2 = []
import boto3
import botocore

s3 = boto3.resource('s3')


for name in names:
    try:
        s3.Object(bucket, '{}/Traj_{}.csv'.format(remote_folder, name)).load()
    except botocore.exceptions.ClientError as e:
        if e.response['Error']['Code'] == "404":
            missing.append(name)
            all_maps2.append((name, remote_folder, bucket, 'regress.obj',
                             4, 4, (512, 512), tparams2))
        else:
            print('Something else has gone wrong')

# %%
import diff_classifier.aws as aws

# %%
old_folder = 'Gel_Studies/08_14_18_gel_validation/old_msds2'

for name in missing:
    filename = 'Traj_{}.csv'.format(name)
    aws.download_s3('{}/{}'.format(old_folder, filename), filename, bucket_name=bucket)
    aws.upload_s3(filename, '{}/{}'.format(remote_folder, filename), bucket_name=bucket)

# %% [markdown]
# Users can monitor the progress of their job in the Batch interface. Once the code is complete, users should clobber their knot to make sure that all AWS resources are removed.

# %%
knot.clobber()

# %% [markdown]
# ## Downstream analysis and visualization

# %% [markdown]
# The knotlet.assemble_msds function (which can also potentially be submitted to Cloudknot as well for large jobs) calculates the mean squared displacements and trajectory features from the raw trajectory csv files found from the Cloudknot submission. It accesses them from the S3 bucket to which they were saved.

# %%
for prefix in to_track[5:7]:
    kn.assemble_msds(prefix, remote_folder, bucket='ccurtis.data')
    print('Successfully output msds for {}'.format(prefix))

# %%
for prefix in to_track[5:7]:
    kn.assemble_msds(prefix, remote_folder, bucket='ccurtis.data')
    print('Successfully output msds for {}'.format(prefix))

# %%
all_maps2 = []
for prefix in to_track:    
    all_maps2.append((prefix, remote_folder, bucket, 'regress100.obj',
                     4, 4, (512, 512), tparams))

# %%
knot = ck.Knot(name='download_and_track_{}_b{}'.format('chad', start_knot),
               docker_image = my_image,
               memory = 16000,
               resource_type = "SPOT",
               bid_percentage = 100,
               #image_id = 'ami-0e00afdf500081a0d', #May need to change this line
               pars_policies=('AmazonS3FullAccess',))

# %% [markdown]
# Diff_classifier includes some useful imaging tools as well, including checking trajectories, plotting heatmaps of trajectory features, distributions of diffusion coefficients, and MSD plots.

# %%
import diff_classifier.heatmaps as hm
import diff_classifier.aws as aws

# %%
prefix = to_track[1]

msds = 'msd_{}.csv'.format(prefix)
feat = 'features_{}.csv'.format(prefix)
aws.download_s3('{}/{}'.format(remote_folder, msds), msds, bucket_name=bucket)
aws.download_s3('{}/{}'.format(remote_folder, feat), feat, bucket_name=bucket)

# %%
hm.plot_trajectories(prefix, upload=False, figsize=(8, 8))

# %%
geomean, geoSEM = hm.plot_individual_msds(prefix, x_range=10, y_range=300, umppx=1, fps=1, upload=False)

# %%
hm.plot_heatmap(prefix, upload=False)

# %%
hm.plot_particles_in_frame(prefix, y_range=6000, upload=False)
