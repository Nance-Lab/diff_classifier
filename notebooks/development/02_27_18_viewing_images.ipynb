# %%
images = !ls *P3_S1_R_0004.png

# %%
images
# Out:
# ['hist_P3_S1_R_0004.png',
#  'hm_alpha_P3_S1_R_0004.png',
#  'hm_AR_P3_S1_R_0004.png',
#  'hm_asymmetry1_P3_S1_R_0004.png',
#  'hm_asymmetry2_P3_S1_R_0004.png',
#  'hm_asymmetry3_P3_S1_R_0004.png',
#  'hm_boundedness_P3_S1_R_0004.png',
#  'hm_D_fit_P3_S1_R_0004.png',
#  'hm_efficiency_P3_S1_R_0004.png',
#  'hm_elongation_P3_S1_R_0004.png',
#  'hm_fractal_dim_P3_S1_R_0004.png',
#  'hm_frames_P3_S1_R_0004.png',
#  'hm_kurtosis_P3_S1_R_0004.png',
#  'hm_MSD_ratio_P3_S1_R_0004.png',
#  'hm_straightness_P3_S1_R_0004.png',
#  'hm_Track_ID_P3_S1_R_0004.png',
#  'hm_trappedness_P3_S1_R_0004.png',
#  'hm_X_P3_S1_R_0004.png',
#  'hm_Y_P3_S1_R_0004.png',
#  'in_frame_P3_S1_R_0004.png',
#  'msds_P3_S1_R_0004.png',
#  'scatter_P3_S1_R_0004.png',
#  'traj_P3_S1_R_0004.png']

# %%
num=15

from IPython.display import Image
Image(filename=images[num])
