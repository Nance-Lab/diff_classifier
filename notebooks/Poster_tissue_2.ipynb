# %% [markdown]
# Welcome to the example docs for diff_classifier.  This example will walk you through using diff_classifier to track particle trajectories from a video collected via fluorescence microscopy, or some other imaging technique.

# %% [markdown]
# # Loading and checking video

# %% [markdown]
# In order to properly track the video, the user must enter the following relevant information regarding the video to be tracked:
# * **prefix**: the name of the file to be tracked, minus the file extension.  Typically tif files are the best to track.
# * **local_folder**: the location of the video to be tracked.
# * **ires**: the desired resolution of sub-videos to be tracked.  Since the images to be tracked may be too large to analyze all at once, the user may need to crop images to perform correctly.  512 x 512 pixels is the standard size.
# * **frames**: number of frames contained in the video.

# %%
import os.path as op
from diff_classifier import aws as aws

# %%
prefix = '100nm_PS_PEG_vid_2'
local_folder = '.'
rfolder = '06_26_28_practice_tracking_tissue'
aws.download_s3('{}/{}.tif'.format(rfolder, prefix), '{}/{}.tif'.format(local_folder, prefix), bucket_name = 'hpontes.data')

ires = 512
frames = 651

# %%
import skimage.io as sio
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
local_name = '{}.tif'.format(prefix)
example = sio.imread(local_name)

# %%
fig, ax = plt.subplots(figsize=(9, 9))
ax.imshow(example[20, :, :], cmap='gray', vmin=20, vmax=15000)
ax.axis('off')
# Out:
# (-0.5, 2047.5, 2043.5, -0.5)

# %% [markdown]
# # Splitting images prior to analysis

# %% [markdown]
# There is an upper limit on image resolution depending on the available RAM on your machine.  I typically limit analyses to images less than 1024 x 1024 pixels, and usually use 512 x 512 pixel images to be consistent.  The large images from the microscope in our lab are 2048 x 2044, resulting in 16 512 x 512 images, with a black band of 0s of the bottom 4 images.

# %%
import diff_classifier.imagej as ij

names = ij.partition_im(local_name)
for name in names:
    aws.upload_s3(name, op.join(rfolder, name), bucket_name='hpontes.data')
    print("Done with splitting.  Should output file of name {}".format(local_folder+'/'+name))
# Out:
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: 100nm_PS_PEG_vid_2_0_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: 100nm_PS_PEG_vid_2_0_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: 100nm_PS_PEG_vid_2_0_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: 100nm_PS_PEG_vid_2_0_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: 100nm_PS_PEG_vid_2_1_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: 100nm_PS_PEG_vid_2_1_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: 100nm_PS_PEG_vid_2_1_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: 100nm_PS_PEG_vid_2_1_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: 100nm_PS_PEG_vid_2_2_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: 100nm_PS_PEG_vid_2_2_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: 100nm_PS_PEG_vid_2_2_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: 100nm_PS_PEG_vid_2_2_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: 100nm_PS_PEG_vid_2_3_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: 100nm_PS_PEG_vid_2_3_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: 100nm_PS_PEG_vid_2_3_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: 100nm_PS_PEG_vid_2_3_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# Done with splitting.  Should output file of name ./100nm_PS_PEG_vid_2_0_0.tif
# Done with splitting.  Should output file of name ./100nm_PS_PEG_vid_2_0_1.tif
# Done with splitting.  Should output file of name ./100nm_PS_PEG_vid_2_0_2.tif
# Done with splitting.  Should output file of name ./100nm_PS_PEG_vid_2_0_3.tif
# Done with splitting.  Should output file of name ./100nm_PS_PEG_vid_2_1_0.tif
# Done with splitting.  Should output file of name ./100nm_PS_PEG_vid_2_1_1.tif
# Done with splitting.  Should output file of name ./100nm_PS_PEG_vid_2_1_2.tif
# Done with splitting.  Should output file of name ./100nm_PS_PEG_vid_2_1_3.tif
# Done with splitting.  Should output file of name ./100nm_PS_PEG_vid_2_2_0.tif
# Done with splitting.  Should output file of name ./100nm_PS_PEG_vid_2_2_1.tif
# Done with splitting.  Should output file of name ./100nm_PS_PEG_vid_2_2_2.tif
# Done with splitting.  Should output file of name ./100nm_PS_PEG_vid_2_2_3.tif
# Done with splitting.  Should output file of name ./100nm_PS_PEG_vid_2_3_0.tif
# Done with splitting.  Should output file of name ./100nm_PS_PEG_vid_2_3_1.tif
# Done with splitting.  Should output file of name ./100nm_PS_PEG_vid_2_3_2.tif
# Done with splitting.  Should output file of name ./100nm_PS_PEG_vid_2_3_3.tif

# %%
names = []
for i in range(0, 4):
    for j in range(0, 4):
        names.append('{}_{}_{}.tif'.format(prefix, i, j))

# %% [markdown]
# # Particle tracking

# %% [markdown]
# Particle tracking is performed with a Trackmate script as exemplified [here](https://imagej.net/Scripting_TrackMate).  The function track allows the user to select relevant tracking parameters.  Current iteration of the code limits tracking to the DoG detector and the Sparse LAP tracker.  The following tracking parameters must be specified for tracking:
# * **template**: location of template file containing Trackmate script. Default Trackmate script is used if set to None.
# * **fiji_bin**: location of Fiji bin.  Fiji is required for tracking.
#
# * **radius**: estimated particle radius in pixels. Can take half values.
# * **threshold**: detection cutoff.  Default is 0.
# * **do_median_filtering**: if set to True, will perform a median filter before tracking.
# * **quality**: quality cutoff level.
# * **x**: Upper x coordinate threshold.  If used, will exclude spots that have x coordinate greater than specified value.
# * **y**: Upper y coordinate threshold.
# * **ylo**: Lower y coordinate threshold.
# * **median_intensity**: currently not used.
# * **snr**: Signal-to-noise ratio cutoff.  Default is 0.
# * **linking_max_distance**: max distance in pixels a particle can travel in a single frame.
# * **gap_closing_max_distance**: max distance in pixels a particle can travel and be picked up by detector when a frame is skipped.
# * **max_frame_gap**: number of frames a particle can disappear and still be linked.
# * **track_displacement**: lower duration cutoff in frames. Tracks must be this many frames long to be included in final dataset.
#
# Quality is the trickiest parameter to select, and can make or break a successful tracking iteration.  The key benefit to this software package is the ability to track large numbers of files at once.  If your files are similar enough, you can get away with using a single quality value for all videos.  In this case, I used two quality values depending on the mean intensity of the input image, which I found correlated with the best quality values for the tracking settings. In another notebook, I use a training dataset to predict quality based on the input mean intensity of the image to be tracked.

# %%
for name in names:
    outfile = 'Traj_' + name.split('.')[0] + '.csv'
    local_im = op.join(local_folder, name)
    
    row = int(name.split('.')[0].split('_')[4])
    col = int(name.split('.')[0].split('_')[5])

#     try:
#         aws.download_s3(remote_folder+'/'+outfile, outfile)
#     except:
    test_intensity = ij.mean_intensity(local_im)
    quality = 1
        
    if row==3:
        y = 485
    else:
        y = 511

    ij.track(local_im, outfile, template=None, fiji_bin=None, radius=3.5, threshold=0.5, 
          do_median_filtering=False, quality=quality, x=511, y=y, ylo=1, median_intensity=300.0, snr=0.0, 
          linking_max_distance=4.0, gap_closing_max_distance=7.0, max_frame_gap=2,
          track_displacement=20.0)

    print("Done with tracking.  Should output file of name {}".format(local_folder+'/'+outfile))
# Out:
# /home/ubuntu/Fiji.app/ImageJ-linux64 --ij2 --headless --run /tmp/tmpeu70e_6f.py
# Done with tracking.  Should output file of name ./Traj_100nm_PS_PEG_vid_2_0_0.csv
# /home/ubuntu/Fiji.app/ImageJ-linux64 --ij2 --headless --run /tmp/tmpqua68eau.py
# Done with tracking.  Should output file of name ./Traj_100nm_PS_PEG_vid_2_0_1.csv
# /home/ubuntu/Fiji.app/ImageJ-linux64 --ij2 --headless --run /tmp/tmp_e06dy7u.py
# Done with tracking.  Should output file of name ./Traj_100nm_PS_PEG_vid_2_0_2.csv
# /home/ubuntu/Fiji.app/ImageJ-linux64 --ij2 --headless --run /tmp/tmpslczohkz.py
# Done with tracking.  Should output file of name ./Traj_100nm_PS_PEG_vid_2_0_3.csv
# /home/ubuntu/Fiji.app/ImageJ-linux64 --ij2 --headless --run /tmp/tmpu_yre_ag.py
# Done with tracking.  Should output file of name ./Traj_100nm_PS_PEG_vid_2_1_0.csv
# /home/ubuntu/Fiji.app/ImageJ-linux64 --ij2 --headless --run /tmp/tmp54cderrq.py
# Done with tracking.  Should output file of name ./Traj_100nm_PS_PEG_vid_2_1_1.csv
# /home/ubuntu/Fiji.app/ImageJ-linux64 --ij2 --headless --run /tmp/tmpu65uhimd.py
# Done with tracking.  Should output file of name ./Traj_100nm_PS_PEG_vid_2_1_2.csv
# /home/ubuntu/Fiji.app/ImageJ-linux64 --ij2 --headless --run /tmp/tmpcqpyh91q.py
# Done with tracking.  Should output file of name ./Traj_100nm_PS_PEG_vid_2_1_3.csv
# /home/ubuntu/Fiji.app/ImageJ-linux64 --ij2 --headless --run /tmp/tmp5rp564kt.py
# Done with tracking.  Should output file of name ./Traj_100nm_PS_PEG_vid_2_2_0.csv
# /home/ubuntu/Fiji.app/ImageJ-linux64 --ij2 --headless --run /tmp/tmpwipo_7t3.py
# Done with tracking.  Should output file of name ./Traj_100nm_PS_PEG_vid_2_2_1.csv
# /home/ubuntu/Fiji.app/ImageJ-linux64 --ij2 --headless --run /tmp/tmp8wd9yop8.py
# Done with tracking.  Should output file of name ./Traj_100nm_PS_PEG_vid_2_2_2.csv
# /home/ubuntu/Fiji.app/ImageJ-linux64 --ij2 --headless --run /tmp/tmp6s5bqds8.py
# Done with tracking.  Should output file of name ./Traj_100nm_PS_PEG_vid_2_2_3.csv
# /home/ubuntu/Fiji.app/ImageJ-linux64 --ij2 --headless --run /tmp/tmpyrse_hkq.py
# Done with tracking.  Should output file of name ./Traj_100nm_PS_PEG_vid_2_3_0.csv
# /home/ubuntu/Fiji.app/ImageJ-linux64 --ij2 --headless --run /tmp/tmpu169wu2a.py
# Done with tracking.  Should output file of name ./Traj_100nm_PS_PEG_vid_2_3_1.csv
# /home/ubuntu/Fiji.app/ImageJ-linux64 --ij2 --headless --run /tmp/tmpunz4df3o.py
# Done with tracking.  Should output file of name ./Traj_100nm_PS_PEG_vid_2_3_2.csv
# /home/ubuntu/Fiji.app/ImageJ-linux64 --ij2 --headless --run /tmp/tmppv2f_c9q.py
# Done with tracking.  Should output file of name ./Traj_100nm_PS_PEG_vid_2_3_3.csv

# %%
int(name.split('.')[0].split('_')[4])
# Out:
# 2

# %% [markdown]
# # Calculating MSDs and features

# %% [markdown]
# This package uses pandas dataframes to perform MSD and feature calculations.  The first dataframe contains the xy coordinates and the MSDs of each trajectory at each frame.  The second dataframe contains a single row for each trajectory and associated features of each trajectory.
#
# This bit of code also only creates a single dataframe for each original input video, rather than creating one for each sub-video after splitting up the images.  They're a lot easier to keep track of that way and minimized total files created.

# %%
import diff_classifier.utils as ut
import diff_classifier.msd as msd
import diff_classifier.features as ft

msd_file = 'msd_{}.csv'.format(prefix)
ft_file = 'features_{}.csv'.format(prefix)

counter = 0
for name in names:
    row = int(name.split('.')[0].split('_')[4])
    col = int(name.split('.')[0].split('_')[5])

    filename = "Traj_{}_{}_{}.csv".format(prefix, row, col)
    local_name = filename

    if counter == 0:
        to_add = ut.csv_to_pd(local_name)
        to_add['X'] = to_add['X'] + ires*col
        to_add['Y'] = ires - to_add['Y'] + ires*(3-row)
        merged = msd.all_msds2(to_add, frames=frames)
    else: 

        if merged.shape[0] > 0:
            to_add = ut.csv_to_pd(local_name)
            to_add['X'] = to_add['X'] + ires*col
            to_add['Y'] = ires - to_add['Y'] + ires*(3-row)
            to_add['Track_ID'] = to_add['Track_ID'] + max(merged['Track_ID']) + 1
        else:
            to_add = ut.csv_to_pd(local_name)
            to_add['X'] = to_add['X'] + ires*col
            to_add['Y'] = ires - to_add['Y'] + ires*(3-row)
            to_add['Track_ID'] = to_add['Track_ID']

        merged = merged.append(msd.all_msds2(to_add, frames=frames))
        print('Done calculating MSDs for row {} and col {}'.format(row, col))
    counter = counter + 1
# Out:
# Done calculating MSDs for row 2 and col 0
# Done calculating MSDs for row 2 and col 0
# Done calculating MSDs for row 2 and col 0
# Done calculating MSDs for row 2 and col 1
# Done calculating MSDs for row 2 and col 1
# Done calculating MSDs for row 2 and col 1
# Done calculating MSDs for row 2 and col 1
# Done calculating MSDs for row 2 and col 2
# Done calculating MSDs for row 2 and col 2
# Done calculating MSDs for row 2 and col 2
# Done calculating MSDs for row 2 and col 2
# Done calculating MSDs for row 2 and col 3
# Done calculating MSDs for row 2 and col 3
# Done calculating MSDs for row 2 and col 3
# Done calculating MSDs for row 2 and col 3

# %%
merged.to_csv(msd_file)
aws.upload_s3(msd_file, rfolder+'/'+msd_file, bucket_name='hpontes.data')
merged_ft = ft.calculate_features(merged)
merged_ft.to_csv(ft_file)
aws.upload_s3(ft_file, rfolder+'/'+ft_file, bucket_name='hpontes.data')
# Out:
# /home/ubuntu/source/diff-classifier/diff_classifier/features.py:478: RuntimeWarning: divide by zero encountered in double_scalars
#   ar = width/height
# Optimal parameters not found. Print NaN instead.
# /home/ubuntu/source/diff-classifier/diff_classifier/features.py:671: RuntimeWarning: divide by zero encountered in double_scalars
#   ratio = (df['MSDs'][n1]/df['MSDs'][n2]) - (df['Frame'][n1]/df['Frame'][n2])
# Optimal parameters not found. Print NaN instead.
# Optimal parameters not found. Print NaN instead.
# Optimal parameters not found. Print NaN instead.
# Optimal parameters not found. Print NaN instead.
# Optimal parameters not found. Print NaN instead.
# Optimal parameters not found. Print NaN instead.
# Optimal parameters not found. Print NaN instead.
# Optimal parameters not found. Print NaN instead.
# Optimal parameters not found. Print NaN instead.
# Optimal parameters not found. Print NaN instead.
# Optimal parameters not found. Print NaN instead.
# Optimal parameters not found. Print NaN instead.
# Optimal parameters not found. Print NaN instead.
# Optimal parameters not found. Print NaN instead.
# Optimal parameters not found. Print NaN instead.
# Optimal parameters not found. Print NaN instead.
# Optimal parameters not found. Print NaN instead.
# Optimal parameters not found. Print NaN instead.
# Optimal parameters not found. Print NaN instead.

# %%
merged.head()
# Out:
#    Frame     Gauss       MSDs  Track_ID          X            Y
# 0    0.0  0.000000   0.000000       0.0        NaN          NaN
# 1    1.0  1.084501   5.362031       0.0  65.576845  1013.325785
# 2    2.0  1.396827   7.902432       0.0  66.811350  1015.590352
# 3    3.0  1.111244  11.732670       0.0  66.899127  1013.942285
# 4    4.0  0.981414  13.979844       0.0  67.098516  1012.594494

# %%
merged_ft.head()
# Out:
#          AR     D_fit  MSD_ratio  Track_ID           X            Y     alpha  \
# 0  1.709406  2.115444   0.032137       0.0   72.829106  1008.774593  0.614744
# 1  1.200108  0.010878   0.983170       1.0   70.341057   982.774423  0.041448
# 2  1.742930  0.724180   0.029200       2.0  237.670982   569.632993  1.121974
# 3  1.929914  0.581433   0.022274       3.0   25.208697   959.814390  0.869950
# 4  1.505316  2.074353   0.612962       4.0   53.270542  1007.344400  0.119831
#
#    asymmetry1  asymmetry2  asymmetry3  boundedness  efficiency  elongation  \
# 0    0.693969    0.301793    0.155288     0.026310    0.282568    0.415001
# 1    0.047057    0.802174    0.006043     0.059642    0.001266    0.166742
# 2    0.734859    0.277249    0.174474     0.100616    0.601634    0.426253
# 3    0.745130    0.270955    0.179749     0.029545    0.496501    0.481842
# 4    0.664283    0.319228    0.142887     0.136395    0.236875    0.335688
#
#    fractal_dim  frames  kurtosis  straightness  trappedness
# 0     1.889179    61.0  2.195260      0.080086    -0.219196
# 1     4.171201   651.0  3.145914      0.001569    -0.209032
# 2     1.917810    24.0  1.733965      0.189146    -0.196653
# 3     1.766348    48.0  3.267114      0.125010    -0.218206
# 4     2.312518    26.0  1.908414      0.106490    -0.185947

# %% [markdown]
# # Trajectory visualization

# %% [markdown]
# Diff_classifier includes several visualization tools for trajectories and features.  First is a map of the trajectories as they appear in the video

# %%
import diff_classifier.heatmaps as hm


#hm.plot_trajectories(prefix)

# %% [markdown]
# Next, the user can plot heatmaps of the trajectories with colormaps scaled to a particular feature.  In this case, the heatmap is scaled to the boundedness of the trajectories.

# %%
feature = 'boundedness'
hm.plot_heatmap(prefix, feature=feature, vmin=merged_ft[feature].quantile(0.1), vmax=merged_ft[feature].quantile(0.9))

# %% [markdown]
# This information can also be displayed in the form of a scatterplot:

# %%
hm.plot_scatterplot(prefix, feature=feature, vmin=merged_ft[feature].quantile(0.1), vmax=merged_ft[feature].quantile(0.9))

# %% [markdown]
# The user can also plot a distribution of the diffusion coefficients:

# %%
hm.plot_histogram(prefix)
# Out:
# /home/ubuntu/source/diff-classifier/diff_classifier/heatmaps.py:363: RuntimeWarning: divide by zero encountered in log
#   dist = np.log(umppx*umppx*merged.loc[merged.Frame == i, 'MSDs'].dropna()/factor)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-73c248e2b797> in <module>()
# ----> 1 hm.plot_histogram(prefix)
#
# ~/source/diff-classifier/diff_classifier/heatmaps.py in plot_histogram(prefix, xlabel, ylabel, fps, umppx, frames, y_range, frame_interval, frame_range, analysis, theta, upload, remote_folder, bucket)
#     367             test_bins = np.linspace(0, 20, 76)
#     368
# --> 369         histogram, test_bins = np.histogram(dist, bins=test_bins)
#     370
#     371         # Plot_general_histogram_code
#
# ~/miniconda3/lib/python3.6/site-packages/numpy/lib/function_base.py in histogram(a, bins, range, normed, weights, density)
#     668     if not np.all(np.isfinite([mn, mx])):
#     669         raise ValueError(
# --> 670             'range parameter must be finite.')
#     671     if mn == mx:
#     672         mn -= 0.5
#
# ValueError: range parameter must be finite.

# %% [markdown]
# One useful check for data quality is the number of particles per frame.  Inevitably, this is a decreating function with respect to time lag.  However, if the linking step was performed successfully, the curve shouldn't be too steep.

# %%
hm.plot_particles_in_frame(prefix, 1000, 8000)

# %% [markdown]
# Finally, the user can plot the MSDs of the individual trajectories.  This function also calculates the geometrically averaged MSDs and the standard deviation of the logs of the MSDs.

# %%
gmean1, gSEM1 = hm.plot_individual_msds(prefix, alpha=0.05)
