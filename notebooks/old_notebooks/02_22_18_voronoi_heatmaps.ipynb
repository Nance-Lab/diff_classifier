# %%
import numpy as np
import numpy.ma as ma
import pandas as pd
import matplotlib.pyplot as plt
from scipy.spatial import Voronoi
import diff_classifier.heatmaps as hm
import diff_classifier.aws as aws
import matplotlib as mpl
import matplotlib.cm as cm
import os
import os.path as op
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon
# %matplotlib inline

# %%
remote_folder = "01_18_Experiment/P1"
local_folder = os.getcwd()
ires = 512
prefix = 'P1_S1_L_0001'
frames = 651

local_name = 'features_{}.csv'.format(prefix)
remote_name = '{}/{}'.format(remote_folder, local_name)
aws.download_s3(remote_name, local_name)

# %%
merged_ft = pd.read_csv('features_{}.csv'.format(prefix))

# %%
hm.plot_scatterplot(prefix, feature='efficiency')
# Out:
# /home/ubuntu/source/diff-classifier/diff_classifier/heatmaps.py:176: RuntimeWarning: invalid value encountered in less_equal
#   zs = ma.masked_where(zs <= t_min, zs)
# /home/ubuntu/source/diff-classifier/diff_classifier/heatmaps.py:177: RuntimeWarning: invalid value encountered in greater_equal
#   zs = ma.masked_where(zs >= t_max, zs)
# Plotted P1_S1_L_0001 scatterplot successfully.

# %%
hm.plot_heatmap(prefix, feature='efficiency')
# Out:
# /home/ubuntu/source/diff-classifier/diff_classifier/heatmaps.py:116: RuntimeWarning: invalid value encountered in less_equal
#   zs = ma.masked_where(zs <= t_min, zs)
# /home/ubuntu/source/diff-classifier/diff_classifier/heatmaps.py:117: RuntimeWarning: invalid value encountered in greater_equal
#   zs = ma.masked_where(zs >= t_max, zs)
# Plotted P1_S1_L_0001 heatmap successfully.

# %%
from IPython.display import Image
Image("heatmap_{}.png".format(prefix))
