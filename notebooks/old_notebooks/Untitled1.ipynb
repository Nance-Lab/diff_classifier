# %%
import diff_classifier.msd as msd

# %%
bucket = 'evanepst.data'
folder = '08_03_18_varying_PEG_excess'

# %%
msd.plot_all_experiments(['100_4xs', '100_3xs', '100_2xs', '100_1xs', '100_pt75xs',
                          '100_pt50xs', '100_pt25xs', '100_pt1xs', '100_PSCOOH'],
                         yrange=(10**-3, 10**1), bucket=bucket, folder=folder)
